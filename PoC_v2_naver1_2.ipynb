# %%
import os
import pandas as pd

# '공유폴더(딥테크)' 폴더 내에서 CSV 파일 리스트업 및 유형(뉴스/댓글)별로 분류 후 개수 요약

data_folder = "공유폴더(딥테크)"
files = [f for f in os.listdir(data_folder) if f.endswith('.csv')]

# GS_뉴스, GS_comments 형태로 분류
news_files = []
comment_files = []

for f in files:
    if '뉴스' in f:
        base = f.replace("_뉴스_", "")
        issue = base.replace(".csv", "")
        news_files.append(f"{issue}_뉴스")
    if 'comments' in f or '댓글' in f:
        base = f.replace("_comments_2", "").replace("_댓글_", "").replace(".csv", "")
        comment_files.append(f"{base}_comments")

print(f"📰 '공유폴더(딥테크)' 폴더 내 뉴스 파일(GS_뉴스 형식): {news_files}")
print(f"💬 '공유폴더(딥테크)' 폴더 내 댓글 파일(GS_comments 형식): {comment_files}")

summary = []

for file in files:
    file_path = os.path.join(data_folder, file)
    # GS_뉴스, GS_comments로 유형 분류
    if '뉴스' in file:
        base = file.replace("_뉴스_", "")
        issue_type = f"{base.replace('.csv','')}_뉴스"
    elif 'comments' in file or '댓글' in file:
        base = file.replace("_comments_2", "").replace("_댓글_", "").replace(".csv", "")
        issue_type = f"{base}_comments"
    else:
        issue_type = file.replace(".csv", "")

    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        count = len(df)
    else:
        count = 0
    summary.append({"이슈_유형": issue_type, "데이터수": count})

summary_df = pd.DataFrame(summary)
print("이슈별(GS_뉴스/GS_comments) 데이터 개수 요약:")
print(summary_df)
# Out:
# 📰 '공유폴더(딥테크)' 폴더 내 뉴스 파일(GS_뉴스 형식): ['GS20241223-20250406_뉴스', 'KT20250901-20251031_뉴스', 'SKT20250401-20250531_뉴스', '롯데카드20250819-20251016_뉴스']
# 💬 '공유폴더(딥테크)' 폴더 내 댓글 파일(GS_comments 형식): ['GS_comments', 'KT_comments', 'lotte_comments', 'SKT_comments']
# 이슈별(GS_뉴스/GS_comments) 데이터 개수 요약:
#                       이슈_유형   데이터수
# 0               GS_comments    593
# 1    GS20241223-20250406_뉴스    186
# 2               KT_comments   2248
# 3    KT20250901-20251031_뉴스    436
# 4            lotte_comments   2287
# 5              SKT_comments  15388
# 6   SKT20250401-20250531_뉴스    881
# 7  롯데카드20250819-20251016_뉴스    340

# %%
import os
import pandas as pd

# ------------------------------------------------------------
# 1️⃣ 폴더 및 외부 뉴스 파일 경로 지정
# ------------------------------------------------------------
data_folder = "공유폴더(딥테크)"
news_script_path = r"C:\Users\user\Desktop\PoC_v2\공유폴더(딥테크)\script\gs_script.csv"

# ------------------------------------------------------------
# 2️⃣ 기존 CSV 파일 로드 (댓글 중심)
# ------------------------------------------------------------
files = [f for f in os.listdir(data_folder) if f.endswith('.csv')]

comment_files = []
for f in files:
    if 'comments' in f or '댓글' in f:
        base = f.replace("_comments_2", "").replace("_댓글_", "").replace(".csv", "")
        comment_files.append(f"{base}_comments")

# ------------------------------------------------------------
# 3️⃣ 외부 뉴스 데이터 로드
# ------------------------------------------------------------
if os.path.exists(news_script_path):
    news_df = pd.read_csv(news_script_path)
    issues = news_df['issue'].unique().tolist() if 'issue' in news_df.columns else news_df.columns.tolist()
    # 소문자 기준으로 뉴스 파일명 생성
    news_files = [f"{i.lower()}_뉴스" for i in issues]
else:
    news_files = []

print(f"📰 외부 뉴스 파일에서 이슈명 추출: {news_files}")
print(f"💬 '공유폴더(딥테크)' 내 댓글 파일 목록: {comment_files}")

# ------------------------------------------------------------
# 4️⃣ 각 파일별 데이터 개수 요약
# ------------------------------------------------------------
summary = []

# (1) 외부 뉴스 파일 건수 (한 파일 전체 카운트)
if os.path.exists(news_script_path):
    count = len(news_df)
    for issue in news_files:
        summary.append({"이슈_유형": issue, "데이터수": count})

# (2) 댓글 파일 개수
for file in files:
    file_path = os.path.join(data_folder, file)
    if 'comments' in file or '댓글' in file:
        base = file.replace("_comments_2", "").replace("_댓글_", "").replace(".csv", "")
        issue_type = f"{base}_comments"
        if os.path.exists(file_path):
            df = pd.read_csv(file_path)
            count = len(df)
        else:
            count = 0
        summary.append({"이슈_유형": issue_type, "데이터수": count})

# ------------------------------------------------------------
# 5️⃣ 요약 결과 출력
# ------------------------------------------------------------
summary_df = pd.DataFrame(summary)
print("✅ 이슈별(뉴스/댓글) 데이터 개수 요약")
print(summary_df)
# Out:
# 📰 외부 뉴스 파일에서 이슈명 추출: ['키워드_뉴스', '언론사_뉴스', '게시일_뉴스', '뉴스제목_뉴스', 'url_뉴스', 'content_뉴스']
# 💬 '공유폴더(딥테크)' 내 댓글 파일 목록: ['GS_comments', 'KT_comments', 'lotte_comments', 'SKT_comments']
# ✅ 이슈별(뉴스/댓글) 데이터 개수 요약
#             이슈_유형   데이터수
# 0          키워드_뉴스    186
# 1          언론사_뉴스    186
# 2          게시일_뉴스    186
# 3         뉴스제목_뉴스    186
# 4          url_뉴스    186
# 5      content_뉴스    186
# 6     GS_comments    593
# 7     KT_comments   2248
# 8  lotte_comments   2287
# 9    SKT_comments  15388
