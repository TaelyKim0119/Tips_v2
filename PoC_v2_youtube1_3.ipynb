# %%
from googleapiclient.discovery import build
import pandas as pd
from datetime import datetime
import os
from time import sleep

# ---------------------------------------
# 1️⃣ 환경설정 및 API 초기화
# ---------------------------------------
API_KEY = ""

def get_youtube():
    return build("youtube", "v3", developerKey=API_KEY)

youtube = get_youtube()

def safe_execute(request, retry=3):
    """API 요청 실행 (에러 발생 시 재시도 및 스킵)"""
    for attempt in range(retry):
        try:
            return request.execute()
        except Exception as e:
            msg = str(e)
            if "commentsDisabled" in msg:
                print("🚫 댓글 비활성화 영상 건너뜀")
                return {"items": []}
            elif "notFound" in msg:
                print("⚠️ 삭제/비공개 영상 건너뜀")
                return {"items": []}
            elif "quotaExceeded" in msg:
                print("❌ API 쿼터 초과 — 키 교체 필요")
                raise e
            else:
                print(f"❌ 오류 ({attempt+1}/{retry})회차 재시도 중: {e}")
                sleep(1)
    return {"items": []}


# ---------------------------------------
# 2️⃣ 영상 수집 함수 (최대 500건)
# ---------------------------------------
def collect_youtube_videos(query, start_date, end_date, max_total=500):
    all_videos = []
    next_page_token = None
    fetched = 0

    print(f"\n🚀 [{query}] 영상 수집 시작 ({start_date} ~ {end_date})")

    while fetched < max_total:
        req = youtube.search().list(
            part="snippet",
            q=query,
            type="video",
            order="viewCount",
            maxResults=50,
            publishedAfter=f"{start_date}T00:00:00Z",
            publishedBefore=f"{end_date}T23:59:59Z",
            pageToken=next_page_token
        )
        res = safe_execute(req)
        items = res.get("items", [])
        if not items:
            print("⚠️ 더 이상 영상 없음.")
            break

        for item in items:
            vid = item["id"]["videoId"]
            snippet = item["snippet"]
            all_videos.append({
                "videoId": vid,
                "title": snippet["title"],
                "description": snippet.get("description", ""),
                "channelTitle": snippet["channelTitle"],
                "channelId": snippet["channelId"],
                "publishedAt": snippet["publishedAt"],
                "url": f"https://www.youtube.com/watch?v={vid}"
            })

        fetched += len(items)
        print(f"✅ 누적 {fetched}건 수집 완료")

        next_page_token = res.get("nextPageToken")
        if not next_page_token:
            break

        sleep(0.3)  # API 요청 간 간격

    print(f"🎯 총 {len(all_videos)}건 영상 수집 완료\n")

    # ▶️ 영상 통계 및 채널 구독자 수 추가
    all_videos = enrich_video_stats(all_videos)
    return pd.DataFrame(all_videos)


# ---------------------------------------
# 3️⃣ 영상 통계 + 구독자 수
# ---------------------------------------
def enrich_video_stats(all_videos):
    for i in range(0, len(all_videos), 50):
        ids = [v["videoId"] for v in all_videos[i:i+50]]
        stats_req = youtube.videos().list(part="statistics,snippet", id=",".join(ids))
        stats_res = safe_execute(stats_req)
        stats_dict = {item["id"]: item for item in stats_res.get("items", [])}

        # 채널 ID 모으기
        channel_ids = []
        video_to_channel = {}
        for v in all_videos[i:i+50]:
            vid_stat = stats_dict.get(v["videoId"], {})
            cid = vid_stat.get("snippet", {}).get("channelId", "")
            video_to_channel[v["videoId"]] = cid
            if cid and cid not in channel_ids:
                channel_ids.append(cid)

        # 채널 구독자 수 조회
        channel_subs_dict = {}
        for j in range(0, len(channel_ids), 50):
            c_batch = channel_ids[j:j+50]
            channel_req = youtube.channels().list(part="statistics", id=",".join(c_batch))
            channel_res = safe_execute(channel_req)
            for item in channel_res.get("items", []):
                channel_subs_dict[item["id"]] = int(item["statistics"].get("subscriberCount", 0))

        # 통계 값 추가
        for v in all_videos[i:i+50]:
            stat = stats_dict.get(v["videoId"], {}).get("statistics", {})
            v["viewCount"] = int(stat.get("viewCount", 0))
            v["likeCount"] = int(stat.get("likeCount", 0))
            v["commentCount"] = int(stat.get("commentCount", 0))
            cid = video_to_channel.get(v["videoId"], "")
            v["subscriberCount"] = channel_subs_dict.get(cid, 0)

        sleep(0.3)
    return all_videos


# ---------------------------------------
# 4️⃣ 댓글 수집 (영상당 최대 100개)
# ---------------------------------------
def collect_comments(video_id, max_comments=100):
    comments = []
    next_page_token = None
    total = 0

    while True:
        req = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            pageToken=next_page_token,
            textFormat="plainText"
        )
        res = safe_execute(req)
        if not res.get("items"):
            break

        for item in res["items"]:
            snippet = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "videoId": video_id,
                "author": snippet.get("authorDisplayName", ""),
                "text": snippet.get("textDisplay", ""),
                "publishedAt": snippet.get("publishedAt", "")
            })
            total += 1
            if total >= max_comments:
                return comments

        next_page_token = res.get("nextPageToken")
        if not next_page_token:
            break
        sleep(0.3)

    return comments


# ---------------------------------------
# 5️⃣ 실행부
# ---------------------------------------
topic = {
    "name": "KT_펨토셀_해킹",
    "query": "(KT OR 케이티) AND (펨토셀 OR femtocell OR 기지국 OR 소형기지국) AND (해킹 OR 공격 OR 보안사고 OR 침해)",
    "start": "2025-08-26",
    "end": "2025-10-24"
}

os.makedirs("YouTube_결과", exist_ok=True)

df_videos = collect_youtube_videos(topic["query"], topic["start"], topic["end"], max_total=500)
print(f"✅ 영상 {len(df_videos)}건 수집 완료")

# 💬 댓글 수집
all_comments = []
print(f"\n💬 총 {len(df_videos)}개 영상 댓글 수집 시작 (영상당 최대 100개)")

for idx, row in df_videos.iterrows():
    vid = row["videoId"]
    title = row["title"][:40]
    print(f"\n▶️ [{idx+1}/{len(df_videos)}] {title}")
    comments = collect_comments(vid, max_comments=100)
    print(f"   └ 댓글 {len(comments)}개 수집")
    all_comments.extend(comments)
    print(f"   → 누적 댓글 {len(all_comments)}개")

# 저장
ts = datetime.now().strftime("%Y%m%d_%H%M%S")
df_videos.to_excel(f"YouTube_결과/{topic['name']}_videos_{ts}.xlsx", index=False)
pd.DataFrame(all_comments).to_excel(f"YouTube_결과/{topic['name']}_comments_{ts}.xlsx", index=False)

print(f"\n🎯 완료 — 영상 {len(df_videos)}건, 댓글 {len(all_comments)}건 저장됨.")
# Out:
# 🚀 [(KT OR 케이티) AND (펨토셀 OR femtocell OR 기지국 OR 소형기지국) AND (해킹 OR 공격 OR 보안사고 OR 침해)] 영상 수집 시작 (2025-08-26 ~ 2025-10-24)
# ✅ 누적 50건 수집 완료
# ✅ 누적 100건 수집 완료
# ✅ 누적 150건 수집 완료
# ✅ 누적 200건 수집 완료
# ✅ 누적 250건 수집 완료
# ✅ 누적 300건 수집 완료
# ✅ 누적 349건 수집 완료
# 🎯 총 349건 영상 수집 완료
#
# ✅ 영상 349건 수집 완료
#
# 💬 총 349개 영상 댓글 수집 시작 (영상당 최대 100개)
#
# ▶️ [1/349] 결제 막히자 1분 뒤..KT 해커가 직접 쓴 글 &#39;충격&#39;
#    └ 댓글 100개 수집
#    → 누적 댓글 100개
#
# ▶️ [2/349] &quot;아~~어떡해!&quot; KT어플 들어갔다 &#39;경악&#3
#    └ 댓글 100개 수집
#    → 누적 댓글 200개
#
# ▶️ [3/349] [자막뉴스] 알아차린 카이스트, KT에 알렸다…뒤늦게 밝혀진 사실 / J
#    └ 댓글 100개 수집
#    → 누적 댓글 300개
#
# ▶️ [4/349] KT 대표 고개 숙였다…&quot;유심 전면 교체·전액 보상할 것&quo
#    └ 댓글 100개 수집
#    → 누적 댓글 400개
#
# ▶️ [5/349] [단독] &quot;유령 기지국 만들어 KT망 해킹‥다른 지역으로 이동도
#    └ 댓글 100개 수집
#    → 누적 댓글 500개
#
# ▶️ [6/349] 해커 모니터 봤더니 &quot;와..&quot; KT 약점 제대로 노렸다
#    └ 댓글 100개 수집
#    → 누적 댓글 600개
#
# ▶️ [7/349] 아니 또 털려? 해킹 맛집 대한민국
#    └ 댓글 100개 수집
#    → 누적 댓글 700개
#
# ▶️ [8/349] &#39;112&#39; 찍힌 전화 받은 후 줄줄이 결제 &#39;멘붕&
#    └ 댓글 100개 수집
#    → 누적 댓글 800개
#
# ▶️ [9/349] 유령 기지국? 펨토셀? 이번 KT 해킹 사태 딱 정리해 드림｜크랩
#    └ 댓글 100개 수집
#    → 누적 댓글 900개
#
# ▶️ [10/349] &#39;털린 게 더 있습니다&#39;..소액결제 난리난 KT 유저들 &
#    └ 댓글 100개 수집
#    → 누적 댓글 1000개
#
# ▶️ [11/349] 불법 기지국 &#39;펨토셀&#39;에 278건, 1억 7천만 원이나 털
#    └ 댓글 100개 수집
#    → 누적 댓글 1100개
#
# ▶️ [12/349] KT 해킹은 ‘빙산의 일각’…“나라가 털렸다” [뉴스in뉴스] / KBS
#    └ 댓글 100개 수집
#    → 누적 댓글 1200개
#
# ▶️ [13/349] [단독] 인천 KT 피해자, 동선 보니…&quot;그곳 매일 지나가&qu
#    └ 댓글 100개 수집
#    → 누적 댓글 1300개
#
# ▶️ [14/349] KT, 정부 다 털렸습니다. 한국 보안 어쩌다 이 지경까지 (고려대 정보
#    └ 댓글 100개 수집
#    → 누적 댓글 1400개
#
# ▶️ [15/349] KT발 해킹 공포 무차별 확산 &quot;알고 보니 신종수법이었다&quo
#    └ 댓글 100개 수집
#    → 누적 댓글 1500개
#
# ▶️ [16/349] 그냥 스쳐도 다 털리는 KT 해킹 상황;;
#    └ 댓글 100개 수집
#    → 누적 댓글 1600개
#
# ▶️ [17/349] [속보] `KT 소액결제` 사건 40대 중국교포 용의자 2명 검거 - [
#    └ 댓글 100개 수집
#    → 누적 댓글 1700개
#
# ▶️ [18/349] KT 소액 결제 해킹 사건. 원인은 무엇일까? 유령기지국?
#    └ 댓글 100개 수집
#    → 누적 댓글 1800개
#
# ▶️ [19/349] KT 해킹 사용 추정 장비 펨토셀, 이미 10년전 위험 노출... 음성·
#    └ 댓글 100개 수집
#    → 누적 댓글 1900개
#
# ▶️ [20/349] &quot;20m 반경서 다 털렸다&quot;…KT이어 SKT·LGU+도
#    └ 댓글 100개 수집
#    → 누적 댓글 2000개
#
# ▶️ [21/349] 초유의 해킹 사고, KT 유령 기지국으로 개인정보 빼내. 해당 지역에 들
#    └ 댓글 100개 수집
#    → 누적 댓글 2100개
#
# ▶️ [22/349] &#39;초소형 기지국&#39; 통신 3사 모두 쓰는데…왜 KT 가입자만
#    └ 댓글 100개 수집
#    → 누적 댓글 2200개
#
# ▶️ [23/349] &#39;유령 기지국&#39;에 KT 뚫렸다‥초소형 기지국 해킹해 개인정
#    └ 댓글 100개 수집
#    → 누적 댓글 2300개
#
# ▶️ [24/349] [단독] 불법 기지국 2개 더 찾았다…소액결제 피해자 늘듯 / SBS
#    └ 댓글 100개 수집
#    → 누적 댓글 2400개
#
# ▶️ [25/349] KT사태 사실 서버도 털렸다 | 어떤 정보가 유출 됐는지 모른다 | (
#    └ 댓글 100개 수집
#    → 누적 댓글 2500개
#
# ▶️ [26/349] 노말틱이 보는 KT 사태 &quot;내부자 소행 가능성도....&quot
#    └ 댓글 100개 수집
#    → 누적 댓글 2600개
#
# ▶️ [27/349] &#39;유령 기지국&#39; 통해 &#39;몰래 출금&#39;…&quo
#    └ 댓글 100개 수집
#    → 누적 댓글 2700개
#
# ▶️ [28/349] 한달 동안 &#39;전혀 모른&#39; KT &quot;헉 기지국이..&
#    └ 댓글 100개 수집
#    → 누적 댓글 2800개
#
# ▶️ [29/349] [자막뉴스] &#39;원인불명&#39; KT 소액결제 해킹…전문가들 &#
#    └ 댓글 100개 수집
#    → 누적 댓글 2900개
#
# ▶️ [30/349] &#39;KT 소액결제&#39; 2명 구속영장‥&quot;소형 기지국 장
#    └ 댓글 100개 수집
#    → 누적 댓글 3000개
#
# ▶️ [31/349] &#39;해킹 피해&#39; 경찰 통보에도 &quot;KT는 뚫릴수 없다
#    └ 댓글 35개 수집
#    → 누적 댓글 3035개
#
# ▶️ [32/349] [단독] &quot;펨토셀, 해킹 취약한 장비&quot; 2014년 KT
#    └ 댓글 100개 수집
#    → 누적 댓글 3135개
#
# ▶️ [33/349] &quot;사실 서버도 털렸다&quot; 또 말 바꾼 KT..어떤 정보가
#    └ 댓글 100개 수집
#    → 누적 댓글 3235개
#
# ▶️ [34/349] KT 무단 소액결제, &#39;불법 초소형 기지국&#39; 활용 정황 /
#    └ 댓글 100개 수집
#    → 누적 댓글 3335개
#
# ▶️ [35/349] 중국 동포 &#39;신종 수법 새벽 침공&#39;... &#39;움직이는
#    └ 댓글 100개 수집
#    → 누적 댓글 3435개
#
# ▶️ [36/349] ￼사태 점점 심각... KT 해킹 공식 사과, 1억7천만원 손해 | 불법
#    └ 댓글 100개 수집
#    → 누적 댓글 3535개
#
# ▶️ [37/349] [속보] 서버까지? KT 기지국 해킹 추가. 엄청난 국민 피해. 중국서
#    └ 댓글 100개 수집
#    → 누적 댓글 3635개
#
# ▶️ [38/349] [자막뉴스] ＂중국서도 원격조종＂…새벽 침공한 KT 해킹에 &#39;발칵
#    └ 댓글 100개 수집
#    → 누적 댓글 3735개
#
# ▶️ [39/349] 소액결제 해킹 완벽 차단! (KT, SK, LG 모두 방어하는 법)
#    └ 댓글 20개 수집
#    → 누적 댓글 3755개
#
# ▶️ [40/349] &#39;유령 기지국&#39; 떠돈다‥KT도 몰랐다 &#39;발칵&#39
#    └ 댓글 100개 수집
#    → 누적 댓글 3855개
#
# ▶️ [41/349] &#39;KT 소액결제 해킹&#39; 40대 중국교포 인천공항에서 검거
#    └ 댓글 100개 수집
#    → 누적 댓글 3955개
#
# ▶️ [42/349] &#39;유령 기지국&#39; 떠돈다‥KT도 몰랐다 &#39;발칵&#39
#    └ 댓글 100개 수집
#    → 누적 댓글 4055개
#
# ▶️ [43/349] [생생경제] 전문가 &quot;KT 소액결제 사태, 외부 해커 아닌듯..
#    └ 댓글 88개 수집
#    → 누적 댓글 4143개
#
# ▶️ [44/349] 왜 KT 가입자들만 당했나…소액결제 피해 막을 방법은 / SBS 8뉴스
#    └ 댓글 58개 수집
#    → 누적 댓글 4201개
#
# ▶️ [45/349] [이슈+] 얼마나 털렸나‥KT &#39;가짜 기지국&#39; 만들어 소액
#    └ 댓글 45개 수집
#    → 누적 댓글 4246개
#
# ▶️ [46/349] 국내 최초로 피해 사례 나온 유령기지국｜크랩
#    └ 댓글 11개 수집
#    → 누적 댓글 4257개
#
# ▶️ [47/349] KT 가입자 소액결제로 4580만원 털리다 | KT 해킹 아니다 주장,
#    └ 댓글 100개 수집
#    → 누적 댓글 4357개
#
# ▶️ [48/349] KT 소액결제 피해 일파만파…복제폰? 중계기 해킹? / SBS / 편상욱
#    └ 댓글 55개 수집
#    → 누적 댓글 4412개
#
# ▶️ [49/349] KT 소액결제 해킹 용의자 잡고보니 &#39;꼬리&#39;..아직 범행
#    └ 댓글 98개 수집
#    → 누적 댓글 4510개
#
# ▶️ [50/349] &quot;시켜서 했다&quot; 중국에 배후?…&#39;KT 소액결제&
#    └ 댓글 100개 수집
#    → 누적 댓글 4610개
#
# ▶️ [51/349] [단독] &quot;펨토셀, 해킹 취약한 장비&quot; 2014년 KT
#    └ 댓글 61개 수집
#    → 누적 댓글 4671개
#
# ▶️ [52/349] &#39;KT 무단 소액결제&#39; 용의자 2명 검거…소형 기지국 장비
#    └ 댓글 100개 수집
#    → 누적 댓글 4771개
#
# ▶️ [53/349] KT, 내부 해킹은 없다는데…나흘 만에 신고한 이유가 / SBS 8뉴스
#    └ 댓글 82개 수집
#    → 누적 댓글 4853개
#
# ▶️ [54/349] &quot;KT 소액결제 해킹 사건, 엘리베이터가 의심돼&quot; 김한
#    └ 댓글 7개 수집
#    → 누적 댓글 4860개
#
# ▶️ [55/349] &#39;유령 기지국&#39;에 당했다? 이러면 다른 통신사도... #s
#    └ 댓글 53개 수집
#    → 누적 댓글 4913개
#
# ▶️ [56/349] KT “유심 정보 유출 정황”…“유령 기지국은 KT망 쓰던 장비인 듯”
#    └ 댓글 56개 수집
#    → 누적 댓글 4969개
#
# ▶️ [57/349] &quot;초소형 기지국으로 해킹&quot;‥&#39;가짜&#39; 차단
#    └ 댓글 58개 수집
#    → 누적 댓글 5027개
#
# ▶️ [58/349] [김태현의 정치쇼] 김용대 교수 &quot;KT 해킹 사태, SKT 보다
#    └ 댓글 42개 수집
#    → 누적 댓글 5069개
#
# ▶️ [59/349] [🔴속보] &#39;KT 무단 해킹&#39; 중국 교포 2명 구속영장심사
#    └ 댓글 100개 수집
#    → 누적 댓글 5169개
#
# ▶️ [60/349] [에디터픽] “가짜 기지국 세워 위장”…KT, 초소형 기지국 접속 제한
#    └ 댓글 27개 수집
#    → 누적 댓글 5196개
#
# ▶️ [61/349] KT해킹이 무서운 이유
#    └ 댓글 30개 수집
#    → 누적 댓글 5226개
#
# ▶️ [62/349] [이슈] KT &#39;해킹 의심 서버&#39; 없앴다더니…허위보고 다음
#    └ 댓글 35개 수집
#    → 누적 댓글 5261개
#
# ▶️ [63/349] 승합차에 기지국 싣고 KT폰 해킹
#    └ 댓글 30개 수집
#    → 누적 댓글 5291개
#
# ▶️ [64/349] KT 유령 기지국의 진실! 소액결제 해킹 사건의 배경｜크랩
#    └ 댓글 9개 수집
#    → 누적 댓글 5300개
#
# ▶️ [65/349] KT 해킹 사태의 가짜기지국이 일본에도 나타났던 사건
#    └ 댓글 38개 수집
#    → 누적 댓글 5338개
#
# ▶️ [66/349] &#39;KT 소액결제&#39; 2명 영장…&quot;승합차에 소형 기지
#    └ 댓글 100개 수집
#    → 누적 댓글 5438개
#
# ▶️ [67/349] 유령 기지국? 복제폰?…‘KT 소액결제 사건’ 미스터리 / KBS  20
#    └ 댓글 22개 수집
#    → 누적 댓글 5460개
#
# ▶️ [68/349] [자막] 과기부 KT 무단 소액결제 침해 사고 브리핑
#    └ 댓글 36개 수집
#    → 누적 댓글 5496개
#
# ▶️ [69/349] [단독] 인천서도 피해…&#39;가상 기지국&#39; 세워 해킹 정황 /
#    └ 댓글 42개 수집
#    → 누적 댓글 5538개
#
# ▶️ [70/349] [단독] &quot;유령 기지국 만들어 KT망 해킹‥다른 지역으로 이동도
#    └ 댓글 33개 수집
#    → 누적 댓글 5571개
#
# ▶️ [71/349] [현장영상] &quot;펨토셀, 이게 문제인거죠?&quot; KT대표 면
#    └ 댓글 25개 수집
#    → 누적 댓글 5596개
#
# ▶️ [72/349] KT, 유령 기지국에 뚫렸다?
#    └ 댓글 8개 수집
#    → 누적 댓글 5604개
#
# ▶️ [73/349] &quot;펨토셀, 해킹취약 장비&quot; 2014년 KT에 알렸다 #
#    └ 댓글 13개 수집
#    → 누적 댓글 5617개
#
# ▶️ [74/349] 통신 3사 모두 쓰는 &#39;초소형 기지국&#39; 근데 왜 KT만?
#    └ 댓글 1개 수집
#    → 누적 댓글 5618개
#
# ▶️ [75/349] 유령 기지국에 싹 털린 한국 근황
#    └ 댓글 17개 수집
#    → 누적 댓글 5635개
#
# ▶️ [76/349] &#39;KT 무단 소액결제&#39; 중국 교포 일당 검거  [와이숏츠]
#    └ 댓글 17개 수집
#    → 누적 댓글 5652개
#
# ▶️ [77/349] [이슈] 군에도 납품한 초소형 기지국…안심해도 되나/2025년 9월 10
#    └ 댓글 25개 수집
#    → 누적 댓글 5677개
#
# ▶️ [78/349] KT 소액결제 해킹! 충격적인 원인 밝혀져
#    └ 댓글 11개 수집
#    → 누적 댓글 5688개
#
# ▶️ [79/349] [LIVE] &#39;KT 무단 소액결제&#39; 사고 관련 과기정통부
#    └ 댓글 9개 수집
#    → 누적 댓글 5697개
#
# ▶️ [80/349] 금천, 광명 아니어도 털릴 수 있다?! #사건사고 #shorts #스브스
#    └ 댓글 2개 수집
#    → 누적 댓글 5699개
#
# ▶️ [81/349] KT 해킹 사태 확산.. 중국 교포 검거·서버까지 유출됐다 (구글 결제
#    └ 댓글 100개 수집
#    → 누적 댓글 5799개
#
# ▶️ [82/349] [LIVE] KT &quot;불법 기지국 발견&quot; 추가 피해 속출
#    └ 댓글 0개 수집
#    → 누적 댓글 5799개
#
# ▶️ [83/349] 임종인 교수 “KT 소액결제 사태, 내부사정 밝은 인물 소행일듯” “KT
#    └ 댓글 18개 수집
#    → 누적 댓글 5817개
#
# ▶️ [84/349] &#39;KT 해킹 통로&#39; 가능성…&quot;초소형 기지국 설치해
#    └ 댓글 8개 수집
#    → 누적 댓글 5825개
#
# ▶️ [85/349] [자막뉴스] &quot;일반적인 해커 아냐&quot;...KT 소액결제
#    └ 댓글 19개 수집
#    → 누적 댓글 5844개
#
# ▶️ [86/349] [속보] KT 점입가경 &quot;5,500명 정보도 털렸다&quot;.
#    └ 댓글 11개 수집
#    → 누적 댓글 5855개
#
# ▶️ [87/349] KT털어간 유령기지국 범인 드디어 잡혔다＃KT해킹＃중국＃초소형기지국＃이슈
#    └ 댓글 38개 수집
#    → 누적 댓글 5893개
#
# ▶️ [88/349] [단독] KT &quot;서버교체 폐기&quot; 허위보고…뻥 뚫린 &#
#    └ 댓글 6개 수집
#    → 누적 댓글 5899개
#
# ▶️ [89/349] [에디터픽] KT 소액결제 피해 원인?…&#39;유령 기지국&#39; 떠
#    └ 댓글 11개 수집
#    → 누적 댓글 5910개
#
# ▶️ [90/349] &quot;초소형 기지국으로 해킹&quot;‥&#39;가짜&#39; 차단
#    └ 댓글 10개 수집
#    → 누적 댓글 5920개
#
# ▶️ [91/349] [🔴생중계] &#39;해킹 현황&#39; KT 기자회견 | 불법 기지국,
#    └ 댓글 1개 수집
#    → 누적 댓글 5921개
#
# ▶️ [92/349] [자막뉴스] KT &#39;소액결제&#39; 피해 가상기지국 정황…어떻게
#    └ 댓글 16개 수집
#    → 누적 댓글 5937개
#
# ▶️ [93/349] KT ‘소액결제’ 피해 가상기지국 정황…“추가 조사 필요” / KBS
#    └ 댓글 16개 수집
#    → 누적 댓글 5953개
#
# ▶️ [94/349] &quot;이상 거래 탐지·초기 대응 미흡&quot;…&#39;소액결제
#    └ 댓글 12개 수집
#    → 누적 댓글 5965개
#
# ▶️ [95/349] KT 뚫은 &#39;초소형 기지국&#39;…&quot;국내 전례 없는 방
#    └ 댓글 4개 수집
#    → 누적 댓글 5969개
#
# ▶️ [96/349] “‘KT 소액결제 피해’ 불법 기지국 원인 가능성…현재 전면 차단” /
#    └ 댓글 14개 수집
#    → 누적 댓글 5983개
#
# ▶️ [97/349] 초등학생 유괴사건, KT해킹 이재명대통령이 직접 언급했다
#    └ 댓글 38개 수집
#    → 누적 댓글 6021개
#
# ▶️ [98/349] KT이용자와 알뜰폰이용자까지 털렸다?
#    └ 댓글 5개 수집
#    → 누적 댓글 6026개
#
# ▶️ [99/349] 불법 기지국 추가 확인…&quot;362명, 2억 4천 피해&quot;
#    └ 댓글 20개 수집
#    → 누적 댓글 6046개
#
# ▶️ [100/349] &quot;유령 기지국 만들어 KT망 해킹..다른 지역으로 이동도 가능&
#    └ 댓글 2개 수집
#    → 누적 댓글 6048개
#
# ▶️ [101/349] [이슈 직진] &#39;유령 기지국&#39; 만들어 KT 해킹, 사상 초
#    └ 댓글 16개 수집
#    → 누적 댓글 6064개
#
# ▶️ [102/349] &quot;&#39;애플 포함&#39; 해킹 불가능한 컴퓨터는 없습니다&
#    └ 댓글 1개 수집
#    → 누적 댓글 6065개
#
# ▶️ [103/349] &#39;불법 초소형 기지국&#39; 파고들었다…무단 결제 피해 1.7억
#    └ 댓글 3개 수집
#    → 누적 댓글 6068개
#
# ▶️ [104/349] 서버까지 뚫린 KT…‘복제폰’ 우려 현실화되나? [9시 뉴스] / KBS
#    └ 댓글 16개 수집
#    → 누적 댓글 6084개
#
# ▶️ [105/349] &#39;KT소액결제&#39; 중국동포 2명 검거…&#39;소형 기지국&
#    └ 댓글 66개 수집
#    → 누적 댓글 6150개
#
# ▶️ [106/349] 유령기지국? 가짜 기지국에 당한 KT, 내정보는 안전한가?#오늘핵심#개인
#    └ 댓글 3개 수집
#    → 누적 댓글 6153개
#
# ▶️ [107/349] 🔴[李 정부 첫 국감 | 과방위] KT 기지국 해킹 등 통신 3사 사이버
#    └ 댓글 1개 수집
#    → 누적 댓글 6154개
#
# ▶️ [108/349] KT 이용자 새벽마다 털렸다…패스·카톡까지 해킹 &#39;충격&#39;
#    └ 댓글 10개 수집
#    → 누적 댓글 6164개
#
# ▶️ [109/349] KT 해킹에 활용된, ‘불법 기지국’ ID 4개 발견 #shorts
#    └ 댓글 0개 수집
#    → 누적 댓글 6164개
#
# ▶️ [110/349] “KT 단순 해킹 아냐..내부 연관 가능성“ | 전문가도 ‘유령기지국 침
#    └ 댓글 4개 수집
#    → 누적 댓글 6168개
#
# ▶️ [111/349] 펨토셀? 워드라이빙?…KT 소액결제 사태 미스터리 [뉴스와] / 연합뉴스
#    └ 댓글 9개 수집
#    → 누적 댓글 6177개
#
# ▶️ [112/349] [자막뉴스] &quot;SKT서 KT로 옮겼는데&quot; 발칵…5500
#    └ 댓글 28개 수집
#    → 누적 댓글 6205개
#
# ▶️ [113/349] [핫라인] KT, 경찰 통보에도 나흘 뭉갰다···&#39;유령 기지국&#
#    └ 댓글 6개 수집
#    → 누적 댓글 6211개
#
# ▶️ [114/349] [시선집중] 불법 활용될 수 있는 KT 펨토셀 3천대 미회수, 관리부실
#    └ 댓글 8개 수집
#    → 누적 댓글 6219개
#
# ▶️ [115/349] KT 소액결제 해킹 수법 &#39;가짜 기지국&#39;보다 더 위험한 이
#    └ 댓글 2개 수집
#    → 누적 댓글 6221개
#
# ▶️ [116/349] KT펨토셀 해킹의 진실⚓️ 300만원짜리 유령 기지국
#    └ 댓글 3개 수집
#    → 누적 댓글 6224개
#
# ▶️ [117/349] 점점 심각해지고 있는 KT해킹사태...
#    └ 댓글 7개 수집
#    → 누적 댓글 6231개
#
# ▶️ [118/349] KT ‘펨토셀’ 중고 제품이 불법 기지국 역할? ‘풀리지 않는 의문’ [
#    └ 댓글 13개 수집
#    → 누적 댓글 6244개
#
# ▶️ [119/349] KT 무단 소액결제…&#39;유령 기지국’ 정황 포착 #KT #SKT #
#    └ 댓글 8개 수집
#    → 누적 댓글 6252개
#
# ▶️ [120/349] &#39;KT 소액결제&#39; 2명 영장…&quot;소형 기지국으로 해
#    └ 댓글 25개 수집
#    → 누적 댓글 6277개
#
# ▶️ [121/349] &quot;불법 기지국으로 해킹&quot;…&#39;KT 소액결제 사태&
#    └ 댓글 14개 수집
#    → 누적 댓글 6291개
#
# ▶️ [122/349] &#39;KT 해킹 통로&#39; 가능성…&quot;초소형 기지국 설치해
#    └ 댓글 22개 수집
#    → 누적 댓글 6313개
#
# ▶️ [123/349] KT 소액결제 피해 충격적인 내용 확인. 가상의 기지국이?  #kt소액결
#    └ 댓글 0개 수집
#    → 누적 댓글 6313개
#
# ▶️ [124/349] (25.9.10.) KT 고객 무단 소액결제 침해 사고 관련 과학기술정보
#    └ 댓글 3개 수집
#    → 누적 댓글 6316개
#
# ▶️ [125/349] KT 소액결제 피해, &#39;가상 기지국&#39; 해킹 정황 / 연합뉴
#    └ 댓글 4개 수집
#    → 누적 댓글 6320개
#
# ▶️ [126/349] “‘KT 소액결제 피해’ 불법 기지국 원인 가능성…현재 전면 차단” /
#    └ 댓글 8개 수집
#    → 누적 댓글 6328개
#
# ▶️ [127/349] KT 해킹 사태 최신 상황...위약금 면제 가능할까? #shorts
#    └ 댓글 6개 수집
#    → 누적 댓글 6334개
#
# ▶️ [128/349] 회수 안 해 불법 거래된다 펨토셀 관리 잘못했단 지적에 #쇼츠 #kt #
#    └ 댓글 0개 수집
#    → 누적 댓글 6334개
#
# ▶️ [129/349] &#39;KT 소액결제 주범&#39; 中 가짜 기지국 장비…수입 통계도
#    └ 댓글 0개 수집
#    → 누적 댓글 6334개
#
# ▶️ [130/349] 중국 불법시장서 “가짜 기지국 판매”…차량용 장비도 버젓이 팔아 [9시
#    └ 댓글 23개 수집
#    → 누적 댓글 6357개
#
# ▶️ [131/349] 🔴이시각 과방위 국감 | KT 기지국 해킹 등 통신 3사 사이버보안, 개
#    └ 댓글 1개 수집
#    → 누적 댓글 6358개
#
# ▶️ [132/349] KT 불법 기지국 20여 개 추가‥피해자도 늘어 (2025.10.16/1
#    └ 댓글 5개 수집
#    → 누적 댓글 6363개
#
# ▶️ [133/349] KT “가짜 기지국 2곳 추가 확인…단말기 식별번호도 유출 정황” / K
#    └ 댓글 12개 수집
#    → 누적 댓글 6375개
#
# ▶️ [134/349] 펨토셀 경고 무시에 빡친 박정훈 “KT 조직문화 한심 뭐 하는 회사?”
#    └ 댓글 7개 수집
#    → 누적 댓글 6382개
#
# ▶️ [135/349] KT 유령기지국 해킹, 1억 7천 피해! 지금 당장 원천차단하세요 (통신
#    └ 댓글 2개 수집
#    → 누적 댓글 6384개
#
# ▶️ [136/349] [현장영상+] &quot;불법 기지국 통한 비정상 통신 흔적 확인...재
#    └ 댓글 4개 수집
#    → 누적 댓글 6388개
#
# ▶️ [137/349] [이슈] KT망 뚫은 &#39;유령기지국&#39;… KT 무단 소액결제
#    └ 댓글 0개 수집
#    → 누적 댓글 6388개
#
# ▶️ [138/349] KT 소액결제 사건, &#39;유령 기지국&#39; 세운 해커 범행?
#    └ 댓글 1개 수집
#    → 누적 댓글 6389개
#
# ▶️ [139/349] KT는 안전하다며!!!!!! 소액결제 해킹 대처법 1분 요약  [휙]
#    └ 댓글 2개 수집
#    → 누적 댓글 6391개
#
# ▶️ [140/349] 도쿄 한복판, 휴대폰이 동시에 먹통?! 정체는 가짜 기지국 #뉴스#이슈#
#    └ 댓글 1개 수집
#    → 누적 댓글 6392개
#
# ▶️ [141/349] KT 소액결제 피해! 유령 기지국의 진실과 예방 방법｜크랩
#    └ 댓글 2개 수집
#    → 누적 댓글 6394개
#
# ▶️ [142/349] KT “가짜 기지국 2곳 추가 확인…단말기 식별번호 유출 정황” / KB
#    └ 댓글 9개 수집
#    → 누적 댓글 6403개
#
# ▶️ [143/349] KT 가입자 유령 기지국 해킹… 소액결제 피해 8천만 원!
#    └ 댓글 0개 수집
#    → 누적 댓글 6403개
#
# ▶️ [144/349] KT &quot;관리부실 인정&quot;…KT·롯데카드 해킹 청문회 /
#    └ 댓글 6개 수집
#    → 누적 댓글 6409개
#
# ▶️ [145/349] KT 가짜기지국 해킹…199명 피해, 배후 추적
#    └ 댓글 4개 수집
#    → 누적 댓글 6413개
#
# ▶️ [146/349] [단독] 펨토셀 취약성 경고에도…15년간 방치된 ‘보안 허점’ / 연합뉴
#    └ 댓글 4개 수집
#    → 누적 댓글 6417개
#
# ▶️ [147/349] 펨토셀⚓️보안 구멍 뚫린 장비 #이슈 #올바른정보 #뉴스 #통신장비 #
#    └ 댓글 0개 수집
#    → 누적 댓글 6417개
#
# ▶️ [148/349] KT도 뚫렸다! 소액결제 해킹 아니라더니…유령 기지국에 5561명 개인정
#    └ 댓글 4개 수집
#    → 누적 댓글 6421개
#
# ▶️ [149/349] KT 해킹으로 털린 거 아시죠? 이 설정을 당장 바꿔야 합니다
#    └ 댓글 0개 수집
#    → 누적 댓글 6421개
#
# ▶️ [150/349] KT해킹⚓️펨토셀이 뭘까? #이슈 #올바른 정보 #뉴스 #통신사 #해킹
#    └ 댓글 3개 수집
#    → 누적 댓글 6424개
#
# ▶️ [151/349] KT 해킹 중국인 용의자 2명 검거... 불법 기지국으로 소액결제
#    └ 댓글 5개 수집
#    → 누적 댓글 6429개
#
# ▶️ [152/349] KT 사용자만 노린 역대급 유령결제 사건 발생 경찰조차 원인 몰라 완전
#    └ 댓글 0개 수집
#    → 누적 댓글 6429개
#
# ▶️ [153/349] [긴급] KT도 털렸다! 가짜 기지국으로 소액결제 해킹! 더 무서운 건
#    └ 댓글 4개 수집
#    → 누적 댓글 6433개
#
# ▶️ [154/349] “초소형 기지국 유효기간 10년”…KT “관리 부실 맞다” / KBS
#    └ 댓글 1개 수집
#    → 누적 댓글 6434개
#
# ▶️ [155/349] KT “가짜 기지국 2곳 추가 확인…단말기 식별번호도 유출 정황” / K
#    └ 댓글 2개 수집
#    → 누적 댓글 6436개
#
# ▶️ [156/349] &quot;KT, 중국동포 해커들 표적된 이유는 바로...&quot; f
#    └ 댓글 1개 수집
#    → 누적 댓글 6437개
#
# ▶️ [157/349] KT 소액결제 해킹, 불법 기지국도 설명 못하는 미스터리
#    └ 댓글 0개 수집
#    → 누적 댓글 6437개
#
# ▶️ [158/349] KT 대표, 결국 인정했다… ‘기지국 관리 부실!&#39; 내 폰은 안전
#    └ 댓글 4개 수집
#    → 누적 댓글 6441개
#
# ▶️ [159/349] KT 소액결제 해킹의 전말 &quot;움직이는 도청기가 저지른 거죠&qu
#    └ 댓글 1개 수집
#    → 누적 댓글 6442개
#
# ▶️ [160/349] [속보] 휴대폰만 켰는데… KT 해킹 피해자의 충격 증언
#    └ 댓글 0개 수집
#    → 누적 댓글 6442개
#
# ▶️ [161/349] &quot;KT 사장 잘 모르시는 눈치라서..&quot;... &#39;
#    └ 댓글 1개 수집
#    → 누적 댓글 6443개
#
# ▶️ [162/349] 새벽에 갑자기 100만원이 사라졌다! KT 유령 기지국 해킹의 충격적 실
#    └ 댓글 1개 수집
#    → 누적 댓글 6444개
#
# ▶️ [163/349] KT 대참사! 가상 기지국 해킹에 수천만 원 날아갔다
#    └ 댓글 2개 수집
#    → 누적 댓글 6446개
#
# ▶️ [164/349] KT만 해킹당한 충격적 이유, 보안 구멍 파헤치기
#    └ 댓글 0개 수집
#    → 누적 댓글 6446개
#
# ▶️ [165/349] KT 유령 기지국 해킹… 전례 없는 수법으로 소액결제 피해 #KT #해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 6446개
#
# ▶️ [166/349] “정부 보안 무너졌다”… KT 해킹·롯데카드 유출 폭로｜국회 청문회, 관
#    └ 댓글 2개 수집
#    → 누적 댓글 6448개
#
# ▶️ [167/349] 유령기지국에 털린 KT 이제야 해킹 신고 #shorts
#    └ 댓글 2개 수집
#    → 누적 댓글 6450개
#
# ▶️ [168/349] kt 유령 기지국 해킹 스미싱 예방 (Prevention of KT Fa
#    └ 댓글 0개 수집
#    → 누적 댓글 6450개
#
# ▶️ [169/349] “KT도 서버 털렸다”… KISA에 침해 정황 신고  #KT #KISA
#    └ 댓글 2개 수집
#    → 누적 댓글 6452개
#
# ▶️ [170/349] &#39;유령 기지국&#39;의 등장? KT 휴대폰 소액 결제 사기의 충
#    └ 댓글 1개 수집
#    → 누적 댓글 6453개
#
# ▶️ [171/349] KT 해킹 사태 총정리: 10분 만에 100만원 털린 이유와 막는 법
#    └ 댓글 1개 수집
#    → 누적 댓글 6454개
#
# ▶️ [172/349] [단비뉴스 소나기] KT 이용자 노린 초소형 기지국 &#39;펨토셀&#3
#    └ 댓글 0개 수집
#    → 누적 댓글 6454개
#
# ▶️ [173/349] [9월 10일] 쇼츠뉴스_오늘 이슈｜KT 유령기지국 해킹, 소액결제 피해
#    └ 댓글 1개 수집
#    → 누적 댓글 6455개
#
# ▶️ [174/349] kt기지국 근처 걸어만 다녀도 해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 6456개
#
# ▶️ [175/349] 15만 대 깔린 펨토셀, 해커의 관문이었다 (예견된 KT사태?!)
#    └ 댓글 0개 수집
#    → 누적 댓글 6456개
#
# ▶️ [176/349] [돌직구 강력반]한밤중 소액결제 미스터리…해커가 세운 유령 기지국? /
#    └ 댓글 3개 수집
#    → 누적 댓글 6459개
#
# ▶️ [177/349] KT 해킹의 배후, 중국산 가짜 기지국(IMSI 캐처)의 충격 실태
#    └ 댓글 1개 수집
#    → 누적 댓글 6460개
#
# ▶️ [178/349] KT &#39;소액결제 해킹&#39; 확산에 일본 &#39;유령기지국 의
#    └ 댓글 0개 수집
#    → 누적 댓글 6460개
#
# ▶️ [179/349] KT 소액결제 해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 6460개
#
# ▶️ [180/349] 쉿! 소액결제 해킹 방지법 알려줌!
#    └ 댓글 1개 수집
#    → 누적 댓글 6461개
#
# ▶️ [181/349] KT에 이어 롯데카드 까지 해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 6462개
#
# ▶️ [182/349] KT 5,561명 개인정보 유출 ⚠️ 펨토셀 해킹과 소액결제 피해까지
#    └ 댓글 2개 수집
#    → 누적 댓글 6464개
#
# ▶️ [183/349] &quot;KT 소액결제 해킹 1달이나 알아채지 못한 이유는...&quo
#    └ 댓글 1개 수집
#    → 누적 댓글 6465개
#
# ▶️ [184/349] “KT 소액결제 해킹!  바로 바꾸세요”
#    └ 댓글 0개 수집
#    → 누적 댓글 6465개
#
# ▶️ [185/349] 유령 기지국의 습격! 내 휴대폰도 털릴 수 있다? #KT해킹 #유령기지국
#    └ 댓글 0개 수집
#    → 누적 댓글 6465개
#
# ▶️ [186/349] KT•알뜰폰 휴대폰 소액결제 사기! 가짜 기지국 해킹피해, 중장년층•시니
#    └ 댓글 0개 수집
#    → 누적 댓글 6465개
#
# ▶️ [187/349] 내 폰이 나도 모르게 결제 💸 KT 유령 기지국 해킹 실체!
#    └ 댓글 0개 수집
#    → 누적 댓글 6465개
#
# ▶️ [188/349] KT 소액결제 해킹 확산 비밀! #KT #소액결제 #펨토셀 #가짜 기지국
#    └ 댓글 0개 수집
#    → 누적 댓글 6465개
#
# ▶️ [189/349] KT, 유령 기지국 해킹 알고도 ‘이상 없다’? 늑장 대응 논란 #KT
#    └ 댓글 0개 수집
#    → 누적 댓글 6465개
#
# ▶️ [190/349] 🚨 최신 KT 유령 기지국 해킹 사건으로 알아보는 휴대폰 소액결제 완벽
#    └ 댓글 2개 수집
#    → 누적 댓글 6467개
#
# ▶️ [191/349] KT 불법 기지국 아이디 20여 개 추가 발견 / YTN
#    └ 댓글 1개 수집
#    → 누적 댓글 6468개
#
# ▶️ [192/349] 영화 속 장면 현실화~ KT 기지국 해킹 첫 확인!.
#    └ 댓글 0개 수집
#    → 누적 댓글 6468개
#
# ▶️ [193/349] KT 소액결제 피해, 가상 기지국 해킹 정황
#    └ 댓글 1개 수집
#    → 누적 댓글 6469개
#
# ▶️ [194/349] KT, 불법 기지국 접속으로 278건 무단 결제…1억7천만 원 피해
#    └ 댓글 2개 수집
#    → 누적 댓글 6471개
#
# ▶️ [195/349] &quot;펨토셀, 해킹 취약한 장비&quot; 2014년 KT에 경고했
#    └ 댓글 2개 수집
#    → 누적 댓글 6473개
#
# ▶️ [196/349] KT 펨토셀 해킹, 실제 운영 방식 전격 해부
#    └ 댓글 2개 수집
#    → 누적 댓글 6475개
#
# ▶️ [197/349] “KT 해킹… 내 돈이 사라졌다??🔥 분노주의”
#    └ 댓글 0개 수집
#    → 누적 댓글 6475개
#
# ▶️ [198/349] KT 유령 기지국? 내휴대폰, 해킹당할 수도 있다! #궁금증해결 #호기심
#    └ 댓글 0개 수집
#    → 누적 댓글 6475개
#
# ▶️ [199/349] [킹받는뉴스] KT 이용자 대상 유령기지국 해킹 피해 사례 속출! #뉴스
#    └ 댓글 0개 수집
#    → 누적 댓글 6475개
#
# ▶️ [200/349] KT 소액결제 해킹 사건! 원인은 바로 이것이었습니다. 해킹 예방법 공개
#    └ 댓글 1개 수집
#    → 누적 댓글 6476개
#
# ▶️ [201/349] KT 소액결제 해킹, 유령 기지국의 비밀 공개!
#    └ 댓글 2개 수집
#    → 누적 댓글 6478개
#
# ▶️ [202/349] KT 해킹 피해 범죄 방식 펨토셀, KT의 빠른 대처
#    └ 댓글 0개 수집
#    → 누적 댓글 6478개
#
# ▶️ [203/349] &quot;왜 KT만 털렸나&quot;… 무단 결제 사건의 미스터리 #K
#    └ 댓글 0개 수집
#    → 누적 댓글 6478개
#
# ▶️ [204/349] KT, 펨토셀 사태에 또 사과…하지만 위약금은 끝내 ‘보류’ #KT #위
#    └ 댓글 0개 수집
#    → 누적 댓글 6478개
#
# ▶️ [205/349] 불법 기지국, 4개서 20개로…KT &#39;늑장 대응&#39;에 사태
#    └ 댓글 0개 수집
#    → 누적 댓글 6478개
#
# ▶️ [206/349] KT 해킹 후폭풍, &#39;ICTK&#39; 급등 주목! 복제 불가 칩
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 6478개
#
# ▶️ [207/349] 승합차에 불법 기지국…KT 휴대폰 대규모 해킹 사건 #더퍼블릭 #케이티
#    └ 댓글 1개 수집
#    → 누적 댓글 6479개
#
# ▶️ [208/349] [현장연결] 과기정통부, KT 고객 무단 소액결제 침해사고 관련 브리핑
#    └ 댓글 4개 수집
#    → 누적 댓글 6483개
#
# ▶️ [209/349] KT 소액결제 해킹, 중국인 용의자들! 기지국의 비밀은?
#    └ 댓글 2개 수집
#    → 누적 댓글 6485개
#
# ▶️ [210/349] KT 소액결제 74건 피해… 유령 기지국 가능성 제기 #이슈 #kt #뉴
#    └ 댓글 0개 수집
#    → 누적 댓글 6485개
#
# ▶️ [211/349] 소형 기지국 싣고 다니며… / #채널A #shorts #뉴스A라이브
#    └ 댓글 1개 수집
#    → 누적 댓글 6486개
#
# ▶️ [212/349] kt해킹 범인 인천공항에서 긴급체포, 40대 중국인 두
#    └ 댓글 3개 수집
#    → 누적 댓글 6489개
#
# ▶️ [213/349] KT 가짜 기지국 등장? 😱 사상 초유의 해킹 수법 ⚠️ #KT #가짜기
#    └ 댓글 0개 수집
#    → 누적 댓글 6489개
#
# ▶️ [214/349] KT 해킹사고, 간 큰 해커 피해자 명의로 항의글까지…
#    └ 댓글 0개 수집
#    → 누적 댓글 6489개
#
# ▶️ [215/349] 👉 KT 이용자 해킹, 불법 펨토셀로 2억4천만 원 피해#KT해킹 #펨토
#    └ 댓글 2개 수집
#    → 누적 댓글 6491개
#
# ▶️ [216/349] 차량에 기지국 싣고 다니며 해킹 KT폰 278명 털렸다
#    └ 댓글 1개 수집
#    → 누적 댓글 6492개
#
# ▶️ [217/349] 유령 기지국 등장KT망 해킹!!! #소액결제 #알뜰폰 #기지국 #대규모
#    └ 댓글 0개 수집
#    → 누적 댓글 6492개
#
# ▶️ [218/349] 김영섭 KT 대표 &quot;펨토셀 관리 부실 인정&quot;...해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 6492개
#
# ▶️ [219/349] KT 소액결제 해킹, 불법 기지국, 그리고 대책
#    └ 댓글 0개 수집
#    → 누적 댓글 6492개
#
# ▶️ [220/349] KT도 털렸다! 5,561명 개인정보 유출의 충격적 진실
#    └ 댓글 0개 수집
#    → 누적 댓글 6492개
#
# ▶️ [221/349] KT 소액결제 해킹, 초기 대응 실패 왜? 20개 불법 기지국 충격!
#    └ 댓글 0개 수집
#    → 누적 댓글 6492개
#
# ▶️ [222/349] KT 소액결제 범인 검거! 불법 기지국 장비까지 확보…내부자 연루?
#    └ 댓글 0개 수집
#    → 누적 댓글 6492개
#
# ▶️ [223/349] KT 소액결제 피해, 불법 기지국 해킹 파장
#    └ 댓글 0개 수집
#    → 누적 댓글 6492개
#
# ▶️ [224/349] KT 해킹 시발점은 다름 아닌 &#39;펨토셀&#39;!! 관리 미흡 인
#    └ 댓글 1개 수집
#    → 누적 댓글 6493개
#
# ▶️ [225/349] ‘불법 기지국’ 소액결제 사태, KT 피해 속출한 이유는 무엇일까
#    └ 댓글 0개 수집
#    → 누적 댓글 6493개
#
# ▶️ [226/349] ‘무단 소액결제’ 의혹 더 커졌다…KT 펨토셀 아닌 불법 장비 사용, 인
#    └ 댓글 0개 수집
#    → 누적 댓글 6493개
#
# ▶️ [227/349] “차량에 펨토셀 싣고 이동” KT 해커, 수도권 돌며 수천만 원 빼갔다
#    └ 댓글 0개 수집
#    → 누적 댓글 6493개
#
# ▶️ [228/349] KT 유령 기지국 해킹, 소액결제 차단 지금 꼭 하세요#휴대폰해킹#소액결
#    └ 댓글 1개 수집
#    → 누적 댓글 6494개
#
# ▶️ [229/349] [킹받는뉴스] KT 기지국 해킹, 취약점은 &quot;펨토셀&quot;?
#    └ 댓글 0개 수집
#    → 누적 댓글 6494개
#
# ▶️ [230/349] 휴대폰만 켰는데 결제가? KT 소액결제 피해
#    └ 댓글 2개 수집
#    → 누적 댓글 6496개
#
# ▶️ [231/349] KT 대참사! 소액결제 피해 문의 9만 건 폭발 #KT #소액결제피해 #
#    └ 댓글 0개 수집
#    → 누적 댓글 6496개
#
# ▶️ [232/349] KT. PASS, 카톡도 해킹 당했다. 통장 지키는 방안.
#    └ 댓글 0개 수집
#    → 누적 댓글 6496개
#
# ▶️ [233/349] KT, 불법 기지국에 뚫렸다… 5천명 피해 가능성! #KT #소액결제사고
#    └ 댓글 0개 수집
#    → 누적 댓글 6496개
#
# ▶️ [234/349] 통신 3사 덮친 해킹 공포 “아무도 안전하지 않다”
#    └ 댓글 1개 수집
#    → 누적 댓글 6497개
#
# ▶️ [235/349] KT 소액결제 유령기지국 사기, 당신도 노출됐을 수 있습니다! [긴급 보
#    └ 댓글 1개 수집
#    → 누적 댓글 6498개
#
# ▶️ [236/349] KT소액결제 #기지국 #해킹 #해커 #내부자 #외부자
#    └ 댓글 0개 수집
#    → 누적 댓글 6498개
#
# ▶️ [237/349] KT망 유령 기지국 확산 중?! 내 폰이 해킹 당한다?! 🎙️
#    └ 댓글 0개 수집
#    → 누적 댓글 6498개
#
# ▶️ [238/349] KT 해킹 정황 속보, 가상 기지국 해킹 의혹 #shorts
#    └ 댓글 0개 수집
#    → 누적 댓글 6498개
#
# ▶️ [239/349] [이슈&amp;피플] KT 소액결제 해킹 사태, 불법 펨토셀이 원인? /
#    └ 댓글 1개 수집
#    → 누적 댓글 6499개
#
# ▶️ [240/349] KT 펨토셀 부실 인정…정부 ‘수사 의뢰’ 경고 🚨
#    └ 댓글 0개 수집
#    → 누적 댓글 6499개
#
# ▶️ [241/349] &quot;유령기지국??이게 가능해??&quot;#유령기지국#KT소액결제
#    └ 댓글 0개 수집
#    → 누적 댓글 6499개
#
# ▶️ [242/349] KT 초소형 기지국 해킹, 소액결제 피해 2억4천만 원! 당신의 정보는
#    └ 댓글 1개 수집
#    → 누적 댓글 6500개
#
# ▶️ [243/349] KT 유령 기지국 소액결제 피해사례 정리 KT해킹? KT직원일탈? #KT
#    └ 댓글 1개 수집
#    → 누적 댓글 6501개
#
# ▶️ [244/349] 휴대폰 문자 폭탄 KT 유령 기지국 해킹, 이미 털렸을 수 있습니다
#    └ 댓글 0개 수집
#    → 누적 댓글 6501개
#
# ▶️ [245/349] [Google AI가 분석한] KT 소액결제 해킹 사건의 모든 것
#    └ 댓글 0개 수집
#    → 누적 댓글 6501개
#
# ▶️ [246/349] 해커도 두손두발 다들었다 소액결제 절대 못뚫는 휴대폰
#    └ 댓글 2개 수집
#    → 누적 댓글 6503개
#
# ▶️ [247/349] 📌 KT 소액결제 해킹, 내 폰도 털렸을까? (충격 수법 공개)
#    └ 댓글 0개 수집
#    → 누적 댓글 6503개
#
# ▶️ [248/349] 유령 기지국으로 인한 KT 소액결제 피해, 내가 피해자인지 확인하는 법
#    └ 댓글 0개 수집
#    → 누적 댓글 6503개
#
# ▶️ [249/349] KT 무단 소액결제 침해사고 278건…피해액 1억7000만원!!!
#    └ 댓글 1개 수집
#    → 누적 댓글 6504개
#
# ▶️ [250/349] “KT 또 털렸다? 불법 기지국 20개 추가 발견! 😱 #KT #해킹사건
#    └ 댓글 0개 수집
#    → 누적 댓글 6504개
#
# ▶️ [251/349] “초소형 기지국 유효기간 10년”…KT “관리 부실 맞다” [9시 뉴스]
#    └ 댓글 0개 수집
#    → 누적 댓글 6504개
#
# ▶️ [252/349] &#39;유령 기지국&#39;에 KT 뚫렸다..초소형 기지국 해킹해 개인
#    └ 댓글 2개 수집
#    → 누적 댓글 6506개
#
# ▶️ [253/349] KT 소액결제 피해, 불법 기지국·복제폰까지? 정부 합동조사 착수
#    └ 댓글 1개 수집
#    → 누적 댓글 6507개
#
# ▶️ [254/349] KT 불법 기지국 20여개 추가 적발 / 연합뉴스TV (Yonhapnew
#    └ 댓글 2개 수집
#    → 누적 댓글 6509개
#
# ▶️ [255/349] &#39;KT 무단 소액결제&#39; 중국 교포 일당 오늘 영장심사 /
#    └ 댓글 5개 수집
#    → 누적 댓글 6514개
#
# ▶️ [256/349] [자막뉴스] &#39;KT 소액결제 해킹&#39; 용의자 2명 검거, 정
#    └ 댓글 1개 수집
#    → 누적 댓글 6515개
#
# ▶️ [257/349] KT &quot;세부조사 중 수상한 기지국 ID 발견...3일 걸려&qu
#    └ 댓글 0개 수집
#    → 누적 댓글 6515개
#
# ▶️ [258/349] KT 해킹 피해 늘어… 추가 피해자 6명, 불법 펨토셀 20개 / 머니투
#    └ 댓글 0개 수집
#    → 누적 댓글 6515개
#
# ▶️ [259/349] KT 소액 무단 결제의 비밀과 예방법 - 펨토셀의 취약점
#    └ 댓글 1개 수집
#    → 누적 댓글 6516개
#
# ▶️ [260/349] 불법 기지국·해킹 장비 버젓이 판매… 충격에 빠진 과방위 #이정헌
#    └ 댓글 0개 수집
#    → 누적 댓글 6516개
#
# ▶️ [261/349] 유령 기지국 해킹 의심… 소액결제 대란 #이슈#뉴스#소액결제#kt
#    └ 댓글 0개 수집
#    → 누적 댓글 6516개
#
# ▶️ [262/349] &quot;펨토셀 어디서 만들어?&quot; KT 답 듣자 신성범, 김현
#    └ 댓글 0개 수집
#    → 누적 댓글 6516개
#
# ▶️ [263/349] KT 소액결제 해킹, 가짜 기지국 첫 확인”“KT Micro-Paymen
#    └ 댓글 0개 수집
#    → 누적 댓글 6516개
#
# ▶️ [264/349] KT, 해킹 통로 초소형 기지국…통신사 차단 나서나
#    └ 댓글 0개 수집
#    → 누적 댓글 6516개
#
# ▶️ [265/349] KT 소액결제 해킹 시발은 펨토셀?...관리 부실 집중 타격한 이상휘
#    └ 댓글 0개 수집
#    → 누적 댓글 6516개
#
# ▶️ [266/349] 클릭도 안 했는데 털렸습니다 역대급 KT 해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 6517개
#
# ▶️ [267/349] &quot;유령 기지국 만들어 KT망 해킹..다른 지역으로 이동도 가능&
#    └ 댓글 1개 수집
#    → 누적 댓글 6518개
#
# ▶️ [268/349] &quot;휴대폰 그냥 썼는데… 개인정보 유출 KT 충격 발표!!&quo
#    └ 댓글 0개 수집
#    → 누적 댓글 6518개
#
# ▶️ [269/349] kt까지 털렸다! 펨토셀 해킹의 충격
#    └ 댓글 1개 수집
#    → 누적 댓글 6519개
#
# ▶️ [270/349] 긴급속보🚨KT 소액결제 해킹사례 예방 방법
#    └ 댓글 0개 수집
#    → 누적 댓글 6519개
#
# ▶️ [271/349] [스팟Live] *풀영상* 과기정통부 &quot;KT 불법 기지국 침해
#    └ 댓글 0개 수집
#    → 누적 댓글 6519개
#
# ▶️ [272/349] &quot;펨토셀, 정부 정보보호 관리체계서 제외&quot; / 연합뉴스
#    └ 댓글 0개 수집
#    → 누적 댓글 6519개
#
# ▶️ [273/349] “KT, ‘가상 기지국’ 통한 소액결제 해킹 정황…74건 피해 발생”
#    └ 댓글 0개 수집
#    → 누적 댓글 6519개
#
# ▶️ [274/349] “진짜보다 더 무서운 가짜… KT 해킹 사태의 진짜 정체” #kt해킹 #
#    └ 댓글 0개 수집
#    → 누적 댓글 6519개
#
# ▶️ [275/349] &#39;유령 기지국&#39;에 KT 뚫렸다..초소형 기지국 해킹해 개인
#    └ 댓글 0개 수집
#    → 누적 댓글 6519개
#
# ▶️ [276/349] KT 사용자 필독! &#39;유령 기지국&#39; 소액결제 사기, 지금
#    └ 댓글 0개 수집
#    → 누적 댓글 6519개
#
# ▶️ [277/349] KT 무단 소액결제, &#39;불법 초소형 기지국&#39; 활용 정황 /
#    └ 댓글 0개 수집
#    → 누적 댓글 6519개
#
# ▶️ [278/349] KT 해킹 사태 - 펨토셀/피코셀 보안취약점과 IMSI 캐쳐 대응 기술
#    └ 댓글 0개 수집
#    → 누적 댓글 6519개
#
# ▶️ [279/349] &quot;펨토셀 허점 인정&quot;…KT 대표 발언에 국회 &#39;
#    └ 댓글 0개 수집
#    → 누적 댓글 6519개
#
# ▶️ [280/349] KT 해킹 강원도까지 번졌다   불법 접속 91건 20251019
#    └ 댓글 1개 수집
#    → 누적 댓글 6520개
#
# ▶️ [281/349] “초소형 기지국 유효기간 10년”…KT “관리 부실 맞다” / KBS
#    └ 댓글 1개 수집
#    → 누적 댓글 6521개
#
# ▶️ [282/349] KT “무단 결제 기지국 2개 추가 확인…피해자 362명” / KBS
#    └ 댓글 0개 수집
#    → 누적 댓글 6521개
#
# ▶️ [283/349] KT 해킹, 펨토셀·심스와핑까지? 충격의 수법 정리
#    └ 댓글 0개 수집
#    → 누적 댓글 6521개
#
# ▶️ [284/349] &quot;KT 해킹범 인천공항서 덜미! 중국인 2명 체포&quot; #
#    └ 댓글 0개 수집
#    → 누적 댓글 6521개
#
# ▶️ [285/349] KT 해킹 충격! 불법 기지국으로 개인정보 탈취 #KT해킹 #소액결제 #
#    └ 댓글 1개 수집
#    → 누적 댓글 6522개
#
# ▶️ [286/349] [스팟Live] 이상휘 &quot;펨토셀, 이게 문제죠?&quot;...
#    └ 댓글 0개 수집
#    → 누적 댓글 6522개
#
# ▶️ [287/349] KT 소액결제 해킹 사태, 그 수법이 드러났습니다.  #shorts #K
#    └ 댓글 0개 수집
#    → 누적 댓글 6522개
#
# ▶️ [288/349] KT 소액결제 해킹 비상 | 가짜 기지국 해킹의 충격과 내 돈을 지키는
#    └ 댓글 0개 수집
#    → 누적 댓글 6522개
#
# ▶️ [289/349] KT 유령 기지국 또 적발… 소액결제 피해자 계속 늘어난다  #KT해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 6522개
#
# ▶️ [290/349] 승합차에 불법 기지국…KT 휴대폰 대규모 해킹 사건
#    └ 댓글 0개 수집
#    → 누적 댓글 6522개
#
# ▶️ [291/349] KT 소액결제 피해 급증! &#39;유령 기지국&#39; 해킹 사기, 지
#    └ 댓글 0개 수집
#    → 누적 댓글 6522개
#
# ▶️ [292/349] KT 해킹 - 어떻게 불법 기지국을 만들었나?
#    └ 댓글 1개 수집
#    → 누적 댓글 6523개
#
# ▶️ [293/349] KT 장민 CFO 어깨가 무겁다, &#39;유령 기지국&#39; 보안 심
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [294/349] KT 불법 기지국 아이디 20여 개 추가 발견 / YTN 사이언스
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [295/349] KT 소액 결제 해킹.. 유령 기지국 활용 #KT #해킹 #소액결제 #유
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [296/349] KT 유령 기지국 해킹 사건으로 알아보는 휴대폰 소액결제 완벽 차단법#휴
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [297/349] 유령 기지국 KT 사건 발생 관련 해외 사례와 예방법 유령 기지국 Kt
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [298/349] [DUBS Audio] 주간 뉴스 피드 | ‘KT 유령 기지국 해킹’
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [299/349] 일파만파 커진 소액결제 피해... 통신사 중 KT만 해킹당한 이유는?
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [300/349] 소액결제 털린 362명, 범죄 무기는 펨토셀!#펨토셀 #해킹사건 #KT해
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [301/349] &quot;소 잃고 외양간 고쳐서 뭐합니까!&quot;... 한심한 KT
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [302/349] 유령기지국
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [303/349] KT소액결제 해킹! 내 폰도 털렸다? 피해 막는 보안 설정 7가지 총정리
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [304/349] #KT#유심유출#가입자식별정보#IMSI#SK#해킹#유심#개인정보#유심교체
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [305/349] “광명·금천 집중 피해… 펨토셀 고정 설치?”
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [306/349] &quot;펨토셀 어디 갔는지도 모르잖아요&quot;... 윤석열 정부
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [307/349] KT 해킹한 &#39;가짜 기지국&#39; 중국 알리서 거래되고 있다?
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [308/349] 👨‍💻👥 KT 뚫은 영화 속 ‘가짜 기지국’…통신보안 대책 시급
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [309/349] #개인정보유출 #해킹사건 #KT소액결제 #KT망해킹 #KT유령기지국 #K
#    └ 댓글 0개 수집
#    → 누적 댓글 6523개
#
# ▶️ [310/349] KT 가짜 기지국 해킹 일당 검거! 피해 막는 소액결제 보안법 총정리 내
#    └ 댓글 1개 수집
#    → 누적 댓글 6524개
#
# ▶️ [311/349] KT 소액결제 해킹, 피해 1억7천만 원 #KT해킹 #소액결제피해 #유령
#    └ 댓글 0개 수집
#    → 누적 댓글 6524개
#
# ▶️ [312/349] 두번 운 KT 소액결제 피해자... 개인정보 유출까지..대책은 없는 건가
#    └ 댓글 0개 수집
#    → 누적 댓글 6524개
#
# ▶️ [313/349] “KT 이용자들 주의! 유령 기지국 해킹 실제 사례”
#    └ 댓글 0개 수집
#    → 누적 댓글 6524개
#
# ▶️ [314/349] kt 소액결제 해킹 대규모 발생 #kt소액결제 #가짜기지국 #소액결제차단
#    └ 댓글 0개 수집
#    → 누적 댓글 6524개
#
# ▶️ [315/349] KT 소액결제 사건 중국인 용의자 2명 체포, 승합차에 기지국 장비 싣고
#    └ 댓글 1개 수집
#    → 누적 댓글 6525개
#
# ▶️ [316/349] &#39;KT 해킹사고&#39; 어떻게 발생했나?, 불법 기지국으로 소액
#    └ 댓글 0개 수집
#    → 누적 댓글 6525개
#
# ▶️ [317/349] 해킹 대응 관련 합동 브리핑 해킹 kt 롯데카드 무상 유심 전화번호 가입
#    └ 댓글 0개 수집
#    → 누적 댓글 6525개
#
# ▶️ [318/349] KT 펨토셀 해킹, 실제 운영 방식 전격 해부
#    └ 댓글 0개 수집
#    → 누적 댓글 6525개
#
# ▶️ [319/349] KT 펨토셀 해킹 사태: 당신의 개인 정보는 안전한가?
#    └ 댓글 0개 수집
#    → 누적 댓글 6525개
#
# ▶️ [320/349] KT 해킹 수법은? #KT #해킹 #소액결제 #피해 #가상기지국
#    └ 댓글 0개 수집
#    → 누적 댓글 6525개
#
# ▶️ [321/349] “KT 기지국 해킹 발생…통신망 보안 비상 &quot;
#    └ 댓글 0개 수집
#    → 누적 댓글 6525개
#
# ▶️ [322/349] KT의 &#39;펨토셀&#39; 관리 부실, 펨토셀은 무엇인가? | 국회
#    └ 댓글 0개 수집
#    → 누적 댓글 6525개
#
# ▶️ [323/349] KT 유령 기지국 해킹… 전례 없는 수법으로 소액결제 피해 #KT #해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 6525개
#
# ▶️ [324/349] KT 유령 기지국 나도 모르게 털린 1억 7천만 원, 통신망 해킹의 진실
#    └ 댓글 0개 수집
#    → 누적 댓글 6525개
#
# ▶️ [325/349] 지금 바로 설정하세요! KT 소액결제해킹 대처방법(SKT, LG포함) |
#    └ 댓글 1개 수집
#    → 누적 댓글 6526개
#
# ▶️ [326/349] KT 해킹 개인정보 유출.. 내 정보도 털렸는지 확인하는 방법
#    └ 댓글 1개 수집
#    → 누적 댓글 6527개
#
# ▶️ [327/349] KT 불법 기지국에 고객개인정보 유출 피해 #KT #이동통신사 #해킹 #
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [328/349] kt 소액 결재 해킹 가상 기지국의 정체는?
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [329/349] “KT 유령 기지국 충격! 내 폰도 해킹 당할 수 있다”
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [330/349] KT 소액결제 피해, ‘가상 기지국’ 해킹 정황…대부분 ARS 인증
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [331/349] KT 펨토셀 해킹 사태: 당신의 개인 정보는 안전한가?
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [332/349] KT 해킹 전국민 ATM 만드나?? l해킹l보상lKTl
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [333/349] KT USIM 해킹 충격! 당신의 휴대폰도 털린다
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [334/349] KT 해킹 사태, 상상 이상의 충격! 2만명 넘는 피해자?!
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [335/349] 휴대전화가 털린다? 불법 기지국 해킹 사건
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [336/349] “KT도 몰랐던 유령 기지국…소액결제 해킹 초유의 사태
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [337/349] KT 소액결제 [중국발 해킹 비리] KT가 중국인 단2명에게 털리는 순간
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [338/349] ㅡKT 소액결제 해킹 범인ㅡ역시나 중국어로 문자가  온다는 건? 특정국가
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [339/349] 당신의 KT가 해킹당하고 있다  소름 돋는 &#39;손바닥 기기&#39;
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [340/349] 유령 기지국 해킹? 소액결제현금화 안전하게 하는 법 #KT소액결제 #소액
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [341/349] 막을 방법이 없었던 공포의 소액결제 KT 펨토셀 해킹 실제 운영 방식 전
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [342/349] KT 유령 기지국 해킹 땜시께 소액결제 피해를 막는 혼문봉인 방법!! 딱
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [343/349] KT 펨토셀 해킹은 이렇게 운영됐다
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [344/349] 펨토셀 해킹으로 KT 소액결제 피해 확산 #KT해킹 #펨토셀 #휴대폰보안
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [345/349] 美 증시  · KT 가짜 기지국 해킹 5,561명 유출  · 추석 고속도
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [346/349] kt 해킹사건
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [347/349] [속보] KT 소액결제 피해 5천만 원↑…가상 기지국 해킹 의혹
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [348/349] KT 소액결제 해킹, 동작·서초·일산까지 확산…차량 불법기지국 이용
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# ▶️ [349/349] 📱 KT 유령 기지국 소액결제 사고 총정리
#    └ 댓글 0개 수집
#    → 누적 댓글 6527개
#
# 🎯 완료 — 영상 349건, 댓글 6527건 저장됨.

# %%
from googleapiclient.discovery import build
import pandas as pd
from datetime import datetime
import os
from time import sleep

# ---------------------------------------
# 1️⃣ 환경설정 및 API 초기화
# ---------------------------------------
API_KEY = ""

def get_youtube():
    return build("youtube", "v3", developerKey=API_KEY)

youtube = get_youtube()

def safe_execute(request, retry=3):
    """API 요청 실행 (에러 발생 시 재시도 및 스킵)"""
    for attempt in range(retry):
        try:
            return request.execute()
        except Exception as e:
            msg = str(e)
            if "commentsDisabled" in msg:
                print("🚫 댓글 비활성화 영상 건너뜀")
                return {"items": []}
            elif "notFound" in msg:
                print("⚠️ 삭제/비공개 영상 건너뜀")
                return {"items": []}
            elif "quotaExceeded" in msg:
                print("❌ API 쿼터 초과 — 키 교체 필요")
                raise e
            else:
                print(f"❌ 오류 ({attempt+1}/{retry})회차 재시도 중: {e}")
                sleep(1)
    return {"items": []}


# ---------------------------------------
# 2️⃣ 영상 수집 함수 (최대 500건)
# ---------------------------------------
def collect_youtube_videos(query, start_date, end_date, max_total=500):
    all_videos = []
    next_page_token = None
    fetched = 0

    print(f"\n🚀 [{query}] 영상 수집 시작 ({start_date} ~ {end_date})")

    while fetched < max_total:
        req = youtube.search().list(
            part="snippet",
            q=query,
            type="video",
            order="viewCount",
            maxResults=50,
            publishedAfter=f"{start_date}T00:00:00Z",
            publishedBefore=f"{end_date}T23:59:59Z",
            pageToken=next_page_token
        )
        res = safe_execute(req)
        items = res.get("items", [])
        if not items:
            print("⚠️ 더 이상 영상 없음.")
            break

        for item in items:
            vid = item["id"]["videoId"]
            snippet = item["snippet"]
            all_videos.append({
                "videoId": vid,
                "title": snippet["title"],
                "description": snippet.get("description", ""),
                "channelTitle": snippet["channelTitle"],
                "channelId": snippet["channelId"],
                "publishedAt": snippet["publishedAt"],
                "url": f"https://www.youtube.com/watch?v={vid}"
            })

        fetched += len(items)
        print(f"✅ 누적 {fetched}건 수집 완료")

        next_page_token = res.get("nextPageToken")
        if not next_page_token:
            break

        sleep(0.3)  # API 요청 간 간격

    print(f"🎯 총 {len(all_videos)}건 영상 수집 완료\n")

    # ▶️ 영상 통계 및 채널 구독자 수 추가
    all_videos = enrich_video_stats(all_videos)
    return pd.DataFrame(all_videos)


# ---------------------------------------
# 3️⃣ 영상 통계 + 구독자 수
# ---------------------------------------
def enrich_video_stats(all_videos):
    for i in range(0, len(all_videos), 50):
        ids = [v["videoId"] for v in all_videos[i:i+50]]
        stats_req = youtube.videos().list(part="statistics,snippet", id=",".join(ids))
        stats_res = safe_execute(stats_req)
        stats_dict = {item["id"]: item for item in stats_res.get("items", [])}

        # 채널 ID 모으기
        channel_ids = []
        video_to_channel = {}
        for v in all_videos[i:i+50]:
            vid_stat = stats_dict.get(v["videoId"], {})
            cid = vid_stat.get("snippet", {}).get("channelId", "")
            video_to_channel[v["videoId"]] = cid
            if cid and cid not in channel_ids:
                channel_ids.append(cid)

        # 채널 구독자 수 조회
        channel_subs_dict = {}
        for j in range(0, len(channel_ids), 50):
            c_batch = channel_ids[j:j+50]
            channel_req = youtube.channels().list(part="statistics", id=",".join(c_batch))
            channel_res = safe_execute(channel_req)
            for item in channel_res.get("items", []):
                channel_subs_dict[item["id"]] = int(item["statistics"].get("subscriberCount", 0))

        # 통계 값 추가
        for v in all_videos[i:i+50]:
            stat = stats_dict.get(v["videoId"], {}).get("statistics", {})
            v["viewCount"] = int(stat.get("viewCount", 0))
            v["likeCount"] = int(stat.get("likeCount", 0))
            v["commentCount"] = int(stat.get("commentCount", 0))
            cid = video_to_channel.get(v["videoId"], "")
            v["subscriberCount"] = channel_subs_dict.get(cid, 0)

        sleep(0.3)
    return all_videos


# ---------------------------------------
# 4️⃣ 댓글 수집 
# ---------------------------------------
from time import sleep

def collect_all_comments(video_id):
    comments = []
    next_page_token = None

    while True:
        req = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            order="time",          # 최신순으로 가져와서 이후 정렬
            textFormat="plainText",
            pageToken=next_page_token
        )
        res = safe_execute(req)
        items = res.get("items", [])
        if not items:
            break

        for item in items:
            snippet = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "videoId": video_id,
                "author": snippet.get("authorDisplayName", ""),
                "text": snippet.get("textDisplay", ""),
                "publishedAt": snippet.get("publishedAt", "")
            })

        next_page_token = res.get("nextPageToken")
        if not next_page_token:
            break

        sleep(0.3)  # rate limit 방지

    # 오래된 순으로 정렬
    comments = sorted(comments, key=lambda x: x["publishedAt"])
    print(f"✅ 총 {len(comments)}개 댓글 수집 완료")
    return comments



# ---------------------------------------
# 5️⃣ 실행부
# ---------------------------------------
topic = {
    "name": "SKT_유심칩_유출",
    "query": "(SK OR SKT OR SK(텔레콤 OR 에스케이)) AND (유심 OR USIM OR SIM) AND (유출 OR 정보유출 OR 해킹 OR 보안사고)",
    "start": "2025-04-08",
    "end": "2025-06-06"
}

os.makedirs("YouTube_결과", exist_ok=True)

df_videos = collect_youtube_videos(topic["query"], topic["start"], topic["end"], max_total=500)
print(f"✅ 영상 {len(df_videos)}건 수집 완료")

# 💬 댓글 수집
all_comments = []
print(f"\n💬 총 {len(df_videos)}개 영상 댓글 수집 시작 (영상당 최대 100개)")

for idx, row in df_videos.iterrows():
    vid = row["videoId"]
    title = row["title"][:40]
    print(f"\n▶️ [{idx+1}/{len(df_videos)}] {title}")
    comments = collect_comments(vid, max_comments=100)
    print(f"   └ 댓글 {len(comments)}개 수집")
    all_comments.extend(comments)
    print(f"   → 누적 댓글 {len(all_comments)}개")

# 저장
ts = datetime.now().strftime("%Y%m%d_%H%M%S")
df_videos.to_excel(f"YouTube_결과/{topic['name']}_videos_{ts}.xlsx", index=False)
pd.DataFrame(all_comments).to_excel(f"YouTube_결과/{topic['name']}_comments_{ts}.xlsx", index=False)

print(f"\n🎯 완료 — 영상 {len(df_videos)}건, 댓글 {len(all_comments)}건 저장됨.")
# Out:
# 🚀 [(SK OR SKT OR SK(텔레콤 OR 에스케이)) AND (유심 OR USIM OR SIM) AND (유출 OR 정보유출 OR 해킹 OR 보안사고)] 영상 수집 시작 (2025-04-08 ~ 2025-06-06)
# ✅ 누적 50건 수집 완료
# ✅ 누적 100건 수집 완료
# ✅ 누적 150건 수집 완료
# ✅ 누적 200건 수집 완료
# ✅ 누적 250건 수집 완료
# ✅ 누적 300건 수집 완료
# ✅ 누적 350건 수집 완료
# ✅ 누적 400건 수집 완료
# ✅ 누적 450건 수집 완료
# ✅ 누적 500건 수집 완료
# 🎯 총 500건 영상 수집 완료
#
# ✅ 영상 500건 수집 완료
#
# 💬 총 500개 영상 댓글 수집 시작 (영상당 최대 100개)
#
# ▶️ [1/500] 지금 유심이 문제가 아닙니다 이거부터 당장 끄세요! (모든 통신사 공통)
#    └ 댓글 100개 수집
#    → 누적 댓글 100개
#
# ▶️ [2/500] 휴대폰 이거 안 끄면 다 털립니다. 빨리 끄세요!
#    └ 댓글 100개 수집
#    → 누적 댓글 200개
#
# ▶️ [3/500] 최악의 사태와 대응.. SKT 유심 해킹&amp;피해 대처법 총정리
#    └ 댓글 100개 수집
#    → 누적 댓글 300개
#
# ▶️ [4/500] &quot;핸드폰 꺼놓는 순간&quot;…SKT폰 &#39;이건 하지 말
#    └ 댓글 100개 수집
#    → 누적 댓글 400개
#
# ▶️ [5/500] skt 유심해킹이후 대처법 빨리하세요!
#    └ 댓글 100개 수집
#    → 누적 댓글 500개
#
# ▶️ [6/500] [자막뉴스] 3년 이내 SKT 썼으면 불안...조사하니 더 큰 게 터졌다
#    └ 댓글 100개 수집
#    → 누적 댓글 600개
#
# ▶️ [7/500] 유심만 바꿔주면 끝? SKT 해킹이 진짜 심각한 이유
#    └ 댓글 100개 수집
#    → 누적 댓글 700개
#
# ▶️ [8/500] (중요)SKT안써도 당장 막으세요(해킹대처법)
#    └ 댓글 100개 수집
#    → 누적 댓글 800개
#
# ▶️ [9/500] SKT 유심 해킹이 진짜 X된 이유
#    └ 댓글 100개 수집
#    → 누적 댓글 900개
#
# ▶️ [10/500] SKT 유심 해킹이 엄청큰일인 이유
#    └ 댓글 100개 수집
#    → 누적 댓글 1000개
#
# ▶️ [11/500] [단독] &quot;유심 바꿔낀 순간 먹통됐다&quot;…아무도 몰랐던
#    └ 댓글 100개 수집
#    → 누적 댓글 1100개
#
# ▶️ [12/500] [지금뉴스] SKT 해킹사태 진짜 문제는 ‘유심 복제’…막으려면 ‘이것’
#    └ 댓글 100개 수집
#    → 누적 댓글 1200개
#
# ▶️ [13/500] 엄마폰 유심보호서비스 가입하려다 &#39;화들짝&#39;...SKT 사태
#    └ 댓글 100개 수집
#    → 누적 댓글 1300개
#
# ▶️ [14/500] [자막] 최태원SKT 회장, 치과 치료 때문에 불출석 통보 #유심 #해킹
#    └ 댓글 100개 수집
#    → 누적 댓글 1400개
#
# ▶️ [15/500] &quot;이번엔 다르다&quot;…SK텔레콤 해커들이 노리는 건 / 연
#    └ 댓글 100개 수집
#    → 누적 댓글 1500개
#
# ▶️ [16/500] 지금 난리 난 SKT 유심 꿀팁ㄷㄷ(대리점 줄 서지마세요)
#    └ 댓글 100개 수집
#    → 누적 댓글 1600개
#
# ▶️ [17/500] SK텔레콤 해킹 사고 내 정보 지키는 3가지 필수 설정
#    └ 댓글 100개 수집
#    → 누적 댓글 1700개
#
# ▶️ [18/500] KT·LGU+ 나선다...&#39;SKT 유심 대란&#39;에 팔 걷어붙
#    └ 댓글 100개 수집
#    → 누적 댓글 1800개
#
# ▶️ [19/500] SKT 유심 해킹, 내 돈을 지키기 위한 대응 방법 3가지
#    └ 댓글 100개 수집
#    → 누적 댓글 1900개
#
# ▶️ [20/500] SKT 유심 해킹사태 그 후.. 바뀐 것이 있을까? &amp; 마이크로소
#    └ 댓글 100개 수집
#    → 누적 댓글 2000개
#
# ▶️ [21/500] 국민 절반이 피해자;;... SKT 유심 해킹 사건 3분 정리 / 스브스
#    └ 댓글 100개 수집
#    → 누적 댓글 2100개
#
# ▶️ [22/500] SKT 유심유출사건 언급한 LGU+ 최신근황 ㅎㄷㄷ
#    └ 댓글 100개 수집
#    → 누적 댓글 2200개
#
# ▶️ [23/500] 청첩장 문자 클릭했다가 2,500만 원 날려…&quot;유심 해킹 때문
#    └ 댓글 100개 수집
#    → 누적 댓글 2300개
#
# ▶️ [24/500] 유심 해킹 최악의 시나리오 이겁니다 (고려대 정보보호대학원 김승주 교수)
#    └ 댓글 100개 수집
#    → 누적 댓글 2400개
#
# ▶️ [25/500] &quot;유심 안 바꾸고 교체 효과&quot;…SKT 새 서비스 받으려
#    └ 댓글 100개 수집
#    → 누적 댓글 2500개
#
# ▶️ [26/500] 내 유심 벌써 복제된 거 아닌지 확인하는 가장 쉬운 방법 #SKT #sh
#    └ 댓글 57개 수집
#    → 누적 댓글 2557개
#
# ▶️ [27/500] 무료 해킹 방지 서비스 4가지! 모든 통신사 공통!! #유심#피싱#skt
#    └ 댓글 38개 수집
#    → 누적 댓글 2595개
#
# ▶️ [28/500] &quot;스마트폰 껐다 켜면 복제폰?&quot;...SKT &#39;유
#    └ 댓글 100개 수집
#    → 누적 댓글 2695개
#
# ▶️ [29/500] 중국반응│SK텔레콤 사건 합동조사반 &#39;SKT유심해킹&#39; 배후
#    └ 댓글 100개 수집
#    → 누적 댓글 2795개
#
# ▶️ [30/500] [자막뉴스] &quot;내 5천만원이 빠져나갔어요&quot;...SKT
#    └ 댓글 100개 수집
#    → 누적 댓글 2895개
#
# ▶️ [31/500] SKT 고객은 반드시 보셔야 합니다!!
#    └ 댓글 100개 수집
#    → 누적 댓글 2995개
#
# ▶️ [32/500] &quot;SKT 유심 무상교체 확정&quot; SK텔레콤 해킹 사고!
#    └ 댓글 100개 수집
#    → 누적 댓글 3095개
#
# ▶️ [33/500] 마음 졸이고 있는 SKT 유저들 이것부터 하세요 #SKT #shorts
#    └ 댓글 45개 수집
#    → 누적 댓글 3140개
#
# ▶️ [34/500] &#39;1등 통신사&#39; SK텔레콤은 왜 뚫렸나..이번 해킹이 소름
#    └ 댓글 100개 수집
#    → 누적 댓글 3240개
#
# ▶️ [35/500] [뉴스쏙] 유심 없다더니 &quot;VVIP만 15만 원에 팔아요&quo
#    └ 댓글 6개 수집
#    → 누적 댓글 3246개
#
# ▶️ [36/500] SKT &#39;유심 포맷&#39; 시작했지만…&quot;그냥 교체 추천
#    └ 댓글 100개 수집
#    → 누적 댓글 3346개
#
# ▶️ [37/500] SKT 해킹…유심칩 꼭 바꿔야 할까 [따져보니] [뉴스9]
#    └ 댓글 100개 수집
#    → 누적 댓글 3446개
#
# ▶️ [38/500] 🔴LIVE 국회 과방위 - &#39;유심해킹 질의&#39; 유영상 SK텔
#    └ 댓글 17개 수집
#    → 누적 댓글 3463개
#
# ▶️ [39/500] SK텔레콤 유심해킹사태_최태원 사주속 위기를 1년전 예언했던 무당 (유명
#    └ 댓글 61개 수집
#    → 누적 댓글 3524개
#
# ▶️ [40/500] &quot;SKT 유영상 사장은 유심 교체하셨어요?[2025년 4월 30
#    └ 댓글 100개 수집
#    → 누적 댓글 3624개
#
# ▶️ [41/500] [오늘] 유심 교체 꼭 해야할까? (ft. SKT 해킹)
#    └ 댓글 99개 수집
#    → 누적 댓글 3723개
#
# ▶️ [42/500] SK텔레콤 해킹에 기업도 &#39;비상&#39;…대리점에선 &quot;유
#    └ 댓글 100개 수집
#    → 누적 댓글 3823개
#
# ▶️ [43/500] SKT 해킹, 사실상 전 가입자 유심 정보 유출 (2025.05.19/뉴
#    └ 댓글 100개 수집
#    → 누적 댓글 3923개
#
# ▶️ [44/500] SKT 유심 유출 보상 ○○○만원 받아내는 법
#    └ 댓글 100개 수집
#    → 누적 댓글 4023개
#
# ▶️ [45/500] 유심 해킹 때문에 피해 발생하면 &#39;전액 보상&#39;하겠다는 SK
#    └ 댓글 74개 수집
#    → 누적 댓글 4097개
#
# ▶️ [46/500] SK 텔레콤 유심 정보 유출 사고 미스터리 | 도람뿌
#    └ 댓글 100개 수집
#    → 누적 댓글 4197개
#
# ▶️ [47/500] 해킹 피해 SK텔레콤 유심 교체 첫날…&#39;오픈런&#39;에 대리점
#    └ 댓글 29개 수집
#    → 누적 댓글 4226개
#
# ▶️ [48/500] [뉴스쏙] &#39;해킹 피해&#39; SK텔레콤, 오늘부터 유심 무료
#    └ 댓글 6개 수집
#    → 누적 댓글 4232개
#
# ▶️ [49/500] SKT 유심 교체 시 주의점 3가지 꼭 알아두세요!
#    └ 댓글 11개 수집
#    → 누적 댓글 4243개
#
# ▶️ [50/500] [이슈] SKT 이용자 9천명, &#39;유심 해킹&#39;에 46억원대
#    └ 댓글 68개 수집
#    → 누적 댓글 4311개
#
# ▶️ [51/500] 유심이 문제가 아니라 이 설정 2가지 당장 끄세요! #스마트폰 #해킹 #
#    └ 댓글 8개 수집
#    → 누적 댓글 4319개
#
# ▶️ [52/500] SKT 유심 교체 아닌 &#39;재설정&#39;‥믿어도 되나? (2025
#    └ 댓글 94개 수집
#    → 누적 댓글 4413개
#
# ▶️ [53/500] [긴급] 국민절반 2300만명 가입 skt 고객정보 유심 해킹 당했다!
#    └ 댓글 15개 수집
#    → 누적 댓글 4428개
#
# ▶️ [54/500] SKT 유심 해킹 사태! 그 이후 주식은?📉[📺 김구라의 경제연구소 EP
#    └ 댓글 74개 수집
#    → 누적 댓글 4502개
#
# ▶️ [55/500] 지금바로 부모님 설정해드리세요. SKT 유심 해킹 사태 현실적 대처방법
#    └ 댓글 52개 수집
#    → 누적 댓글 4554개
#
# ▶️ [56/500] SKT 유심 해킹 사태! 대리점 가지말고 eSIM으로 빠르게 교체하세요!
#    └ 댓글 20개 수집
#    → 누적 댓글 4574개
#
# ▶️ [57/500] [SKT 해킹 대응] 아이폰 유심을 e심으로 셀프 개통 방법 | 단계별
#    └ 댓글 13개 수집
#    → 누적 댓글 4587개
#
# ▶️ [58/500] [자막] SKT 유심 해킹,  위약금 면제 확답 못해 #유영상 #SKT
#    └ 댓글 80개 수집
#    → 누적 댓글 4667개
#
# ▶️ [59/500] [목돈연구소] SKT 유심 해킹 사건 내 개인정보는 어떡하나.. I 맨손
#    └ 댓글 64개 수집
#    → 누적 댓글 4731개
#
# ▶️ [60/500] SKT &#39;해킹 사고&#39; 조사 결과 발표…&quot;이용자 전
#    └ 댓글 100개 수집
#    → 누적 댓글 4831개
#
# ▶️ [61/500] SK텔레콤 해킹 사건! 지금 유심이 문제가 아닙니다  60대이상, 지금
#    └ 댓글 26개 수집
#    → 누적 댓글 4857개
#
# ▶️ [62/500] [자막] SKT 유심 해킹 사태, 종합적으로 검토 발언 모음.zip #유
#    └ 댓글 100개 수집
#    → 누적 댓글 4957개
#
# ▶️ [63/500] 잇섭이 말해주는 SKT 해킹 피해 범위  #잇섭 #해킹 #skt유심 #s
#    └ 댓글 1개 수집
#    → 누적 댓글 4958개
#
# ▶️ [64/500] 문제는 유심 변경이 아닙니다;; SKT 해킹 큰일난 이유
#    └ 댓글 25개 수집
#    → 누적 댓글 4983개
#
# ▶️ [65/500] skt 유심 해킹사태의 진짜 문제 ㄷㄷ
#    └ 댓글 30개 수집
#    → 누적 댓글 5013개
#
# ▶️ [66/500] &#39;유심 해킹 대란&#39; 고객 이탈 속출 속...SKT, 대규모
#    └ 댓글 100개 수집
#    → 누적 댓글 5113개
#
# ▶️ [67/500] SK텔레콤 “28일부터 유심 ‘무상 교체’…해킹 피해는 없어” / KBS
#    └ 댓글 100개 수집
#    → 누적 댓글 5213개
#
# ▶️ [68/500] SKT 500만 가입자, 불안한 유심 &#39;그대로&#39;…예약 교체
#    └ 댓글 100개 수집
#    → 누적 댓글 5313개
#
# ▶️ [69/500] &#39;유심 해킹&#39; SKT, 오늘부터 모든 가입자에 피해 예방법
#    └ 댓글 85개 수집
#    → 누적 댓글 5398개
#
# ▶️ [70/500] [자막] SKT 유심 해킹,  위약금 면제 확답 못해 #유영상 #SKT
#    └ 댓글 100개 수집
#    → 누적 댓글 5498개
#
# ▶️ [71/500] SK텔레콤 유심보호서비스 가입 안내 문자 발송, 가입시 로밍 차단 주의
#    └ 댓글 47개 수집
#    → 누적 댓글 5545개
#
# ▶️ [72/500] SKT 유심 해킹 사태! 대책 없이 당당하다 왜!? #USIM #Usim
#    └ 댓글 16개 수집
#    → 누적 댓글 5561개
#
# ▶️ [73/500] &quot;SKT 고객이라면 꼭 확인하세요&quot; 전 고객 대상 유심
#    └ 댓글 20개 수집
#    → 누적 댓글 5581개
#
# ▶️ [74/500] &quot;계좌에서 다수의 현금 인출…&quot;SKT 유심 보호 가입해
#    └ 댓글 59개 수집
#    → 누적 댓글 5640개
#
# ▶️ [75/500] [긴급!] SK텔레콤 유심정보 해킹 사태, 정부는 아직도 ‘검토’중? #
#    └ 댓글 65개 수집
#    → 누적 댓글 5705개
#
# ▶️ [76/500] SKT 유심 해킹 생각보다 심각합니다! 유심교체나 타사로 옮기세요
#    └ 댓글 66개 수집
#    → 누적 댓글 5771개
#
# ▶️ [77/500] 유심 해킹에 증권사 비상··· 주식거래 안전할까?
#    └ 댓글 10개 수집
#    → 누적 댓글 5781개
#
# ▶️ [78/500] &#39;SKT 유심 해킹&#39; 쉴드 불가인 이유 / 비디오머그 /
#    └ 댓글 23개 수집
#    → 누적 댓글 5804개
#
# ▶️ [79/500] SKT 유심 해킹 사건이 난리인 이유
#    └ 댓글 18개 수집
#    → 누적 댓글 5822개
#
# ▶️ [80/500] SKT 비행기 모드 절대 하면 안됨ㄷㄷ(유심 바꾸기 전 필수 시청)
#    └ 댓글 11개 수집
#    → 누적 댓글 5833개
#
# ▶️ [81/500] (속보) &quot;SK텔레콤 긴급 발표&quot; SKT 유심 해킹 해
#    └ 댓글 21개 수집
#    → 누적 댓글 5854개
#
# ▶️ [82/500] [🔴생중계] 국회 과방위, &#39;SKT 유심 해킹 사건&#39; 청문
#    └ 댓글 5개 수집
#    → 누적 댓글 5859개
#
# ▶️ [83/500] [이슈] SKT 유심 해킹 자가 진단법 #skt #유심 #해킹
#    └ 댓글 9개 수집
#    → 누적 댓글 5868개
#
# ▶️ [84/500] SK텔레콤 유심 해킹. 신인규, 징벌적 손해배상 물려야
#    └ 댓글 23개 수집
#    → 누적 댓글 5891개
#
# ▶️ [85/500] SKT 유심 해킹 터졌을 땐 주가가 멀쩡하다 갑자기 왜? [이반장의 생각
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 5891개
#
# ▶️ [86/500] 2300만 명 유심 해킹 이렇게 하면 안전 / #채널A #뉴스A라이브 #
#    └ 댓글 32개 수집
#    → 누적 댓글 5923개
#
# ▶️ [87/500] SKT 해킹으로 유심 교체했더니 수리비 60만원? #유심교체피해 #메인보
#    └ 댓글 13개 수집
#    → 누적 댓글 5936개
#
# ▶️ [88/500] SKT 해킹 사태 2차 조사결과 더 큰게 터졌다 #SKT #USIM #해
#    └ 댓글 49개 수집
#    → 누적 댓글 5985개
#
# ▶️ [89/500] 삼성, SKT 유심 해킹에 임원 유심 교체 지시…금융권도 본인인증 제한
#    └ 댓글 20개 수집
#    → 누적 댓글 6005개
#
# ▶️ [90/500] 2300만명 개인정보 털렸다 SKT 유심 해킹 대참사 #수확 #개인정보보
#    └ 댓글 18개 수집
#    → 누적 댓글 6023개
#
# ▶️ [91/500] 💥SKT 유심 해킹사태💥 반드시 해줘야 할 대처사항
#    └ 댓글 6개 수집
#    → 누적 댓글 6029개
#
# ▶️ [92/500] &quot;SKT유심 15만원에 팝니다&quot; 유심 대란에 웃돈 거래
#    └ 댓글 9개 수집
#    → 누적 댓글 6038개
#
# ▶️ [93/500] SKT 유심? 오픈런도 소용없네요(5/1 오전상황) #SKT #유심 #해
#    └ 댓글 46개 수집
#    → 누적 댓글 6084개
#
# ▶️ [94/500] SKT 고객 필수 시청! 유심 해킹 피해 안 보려면?
#    └ 댓글 10개 수집
#    → 누적 댓글 6094개
#
# ▶️ [95/500] SKT 유심 바꾸면 진짜 끝? 하…불안해서 살겠나…🤦🏻‍♂️🤦🏻‍♀️#s
#    └ 댓글 10개 수집
#    → 누적 댓글 6104개
#
# ▶️ [96/500] 최민희 결국 최태원 회장 소환! #정치 #skt해킹 #유심
#    └ 댓글 20개 수집
#    → 누적 댓글 6124개
#
# ▶️ [97/500] &quot;근데 이미 해킹을 당했잖아요&quot;... SKT, 알맹이
#    └ 댓글 9개 수집
#    → 누적 댓글 6133개
#
# ▶️ [98/500] SKT 해킹 범인, 또 너야? #shorts
#    └ 댓글 51개 수집
#    → 누적 댓글 6184개
#
# ▶️ [99/500] 🔴LIVE SK 텔레콤, &quot;가입자 전원 유심 정보 유출&quot
#    └ 댓글 9개 수집
#    → 누적 댓글 6193개
#
# ▶️ [100/500] SKT 유심 해킹이 위험한 진짜 이유
#    └ 댓글 16개 수집
#    → 누적 댓글 6209개
#
# ▶️ [101/500] 2025.04.28. #SKT #해킹 의심 신고 경찰 스미싱 은행 개통
#    └ 댓글 9개 수집
#    → 누적 댓글 6218개
#
# ▶️ [102/500] 최민희 결국 최태원 회장 소환! #정치 #skt해킹 #유심
#    └ 댓글 20개 수집
#    → 누적 댓글 6238개
#
# ▶️ [103/500] &quot;근데 이미 해킹을 당했잖아요&quot;... SKT, 알맹이
#    └ 댓글 9개 수집
#    → 누적 댓글 6247개
#
# ▶️ [104/500] SKT 해킹 범인, 또 너야? #shorts
#    └ 댓글 51개 수집
#    → 누적 댓글 6298개
#
# ▶️ [105/500] 🔴LIVE SK 텔레콤, &quot;가입자 전원 유심 정보 유출&quot
#    └ 댓글 9개 수집
#    → 누적 댓글 6307개
#
# ▶️ [106/500] SKT 유심 해킹이 위험한 진짜 이유
#    └ 댓글 16개 수집
#    → 누적 댓글 6323개
#
# ▶️ [107/500] SK텔레콤 유심 해킹으로 인해 기기변경에 지원 대폭 추가!! S25 현금
#    └ 댓글 10개 수집
#    → 누적 댓글 6333개
#
# ▶️ [108/500] [자막] SKT 유심해킹, 거짓말하다 걸린 유영상 사장 #유심 #해킹
#    └ 댓글 15개 수집
#    → 누적 댓글 6348개
#
# ▶️ [109/500] 이번 SKT 유심 해킹 사태가 심각한 이유
#    └ 댓글 3개 수집
#    → 누적 댓글 6351개
#
# ▶️ [110/500] 타 통신사도 가능한 유심해킹 대응방안
#    └ 댓글 11개 수집
#    → 누적 댓글 6362개
#
# ▶️ [111/500] 돈이 아쉬운 SK텔레콤 #정치 #국회 #알대정 #skt #skt위약금 #
#    └ 댓글 20개 수집
#    → 누적 댓글 6382개
#
# ▶️ [112/500] SKT 유심 해킹 사건, 고소 가능할까?
#    └ 댓글 33개 수집
#    → 누적 댓글 6415개
#
# ▶️ [113/500] &quot;이건 국가중대사태!&quot; SKT 유심 해킹 사태에 대해
#    └ 댓글 2개 수집
#    → 누적 댓글 6417개
#
# ▶️ [114/500] sk텔레콤 유심해킹 사건이 미국에서 일어났다면 어땠을까요 #유심해킹 #실
#    └ 댓글 3개 수집
#    → 누적 댓글 6420개
#
# ▶️ [115/500] &quot;내 계좌서 5000만원 털렸다&quot;  #sk텔레콤 #유심
#    └ 댓글 12개 수집
#    → 누적 댓글 6432개
#
# ▶️ [116/500] SK텔레콤 해킹 사고 유심 정보 유출, 유심보호서비스 가입 방법
#    └ 댓글 2개 수집
#    → 누적 댓글 6434개
#
# ▶️ [117/500] SK텔레콤 유심 현재상황
#    └ 댓글 13개 수집
#    → 누적 댓글 6447개
#
# ▶️ [118/500] 집단소송 참여할 때, 반드시 조심해야 할 것 #sk텔레콤 #SKT해킹 #
#    └ 댓글 11개 수집
#    → 누적 댓글 6458개
#
# ▶️ [119/500] 유심 해킹!! SK 사용자 필독!! #SK텔레콤 #유심해킹 #유심교체
#    └ 댓글 6개 수집
#    → 누적 댓글 6464개
#
# ▶️ [120/500] skt 유심 해킹 사건 귀책사유 확실하게 알려줌 #skt #유심 #이해민
#    └ 댓글 7개 수집
#    → 누적 댓글 6471개
#
# ▶️ [121/500] &quot;SKT 위약금 면제하라&quot; 최태원 면담 시도 &#39;
#    └ 댓글 22개 수집
#    → 누적 댓글 6493개
#
# ▶️ [122/500] &quot;통신망 핵심 뚫렸다… 이게 진짜 무섭다&quot;#SK텔레콤
#    └ 댓글 12개 수집
#    → 누적 댓글 6505개
#
# ▶️ [123/500] (SK텔레콤 유심 해킹) 갤럭시 스마트폰은 &#39;이 설정&#39; 안
#    └ 댓글 6개 수집
#    → 누적 댓글 6511개
#
# ▶️ [124/500] &quot;오픈런 했는데도&quot;.. SK텔레콤 유심 재고 부족에 혼
#    └ 댓글 15개 수집
#    → 누적 댓글 6526개
#
# ▶️ [125/500] 정부 &quot;SKT, 신규가입 받지 말라&quot; SKT 입장은?
#    └ 댓글 0개 수집
#    → 누적 댓글 6526개
#
# ▶️ [126/500] sk텔레콤 유심 해킹 걱정된다면? 이거 당장 막으세요  #SK텔레콤 #유
#    └ 댓글 5개 수집
#    → 누적 댓글 6531개
#
# ▶️ [127/500] SKT 이용자, &#39;유심 해킹&#39; 1인당 1백만 원 손해배상
#    └ 댓글 26개 수집
#    → 누적 댓글 6557개
#
# ▶️ [128/500] SKT 가입자 전 규모 유심 유출…과기부 &quot;복제폰 물리적 불가능
#    └ 댓글 48개 수집
#    → 누적 댓글 6605개
#
# ▶️ [129/500] IT강국 대한민국 SKT 유심 해킹 사태 2,500만 국민에게 대응이..
#    └ 댓글 5개 수집
#    → 누적 댓글 6610개
#
# ▶️ [130/500] [1편]어지러운 SK 유심 유출 근황 ㄷㄷ
#    └ 댓글 0개 수집
#    → 누적 댓글 6610개
#
# ▶️ [131/500] 한 대행, &quot;SKT 유심 교체 적정성 점검&quot; 지시
#    └ 댓글 3개 수집
#    → 누적 댓글 6613개
#
# ▶️ [132/500] SK텔레콤, 해킹 사고 후 2,300만 고객 유심 무상 교체 결정
#    └ 댓글 8개 수집
#    → 누적 댓글 6621개
#
# ▶️ [133/500] [에경PICK] 해킹 일주일 만에 입 연 SKT…“유심 무료교체” #sh
#    └ 댓글 2개 수집
#    → 누적 댓글 6623개
#
# ▶️ [134/500] 🔴LIVE SK 텔레콤, &quot;가입자 전원 유심 정보 유출&quot
#    └ 댓글 15개 수집
#    → 누적 댓글 6638개
#
# ▶️ [135/500] &quot;순식간에 5000만원 털렸다&quot;…SKT 유심 유출 피해
#    └ 댓글 8개 수집
#    → 누적 댓글 6646개
#
# ▶️ [136/500] SK텔레콤사태는 &#39;일파만파&quot;  #유심해킹사건 #심스와핑
#    └ 댓글 4개 수집
#    → 누적 댓글 6650개
#
# ▶️ [137/500] skt 유심 해킹 지금 당장 해야 할 일 3가지! #이슈 #sk텔레콤 #
#    └ 댓글 2개 수집
#    → 누적 댓글 6652개
#
# ▶️ [138/500] SK텔레콤 유심 데이터 해킹사건 코인투자 하시는 분들 꼭! 유심 보호 서
#    └ 댓글 11개 수집
#    → 누적 댓글 6663개
#
# ▶️ [139/500] 모든 가입자 유심 털렸다…SKT 해킹 책임은 누가? [세상만사] #SKT
#    └ 댓글 48개 수집
#    → 누적 댓글 6711개
#
# ▶️ [140/500] SK텔레콤 &quot;&#39;유심 재설정&#39; 서비스 첫날 2만 3
#    └ 댓글 6개 수집
#    → 누적 댓글 6717개
#
# ▶️ [141/500] SK텔레콤 해킹 피해, 법무법인 로집사집단소송 착수! #sk텔레콤 #SK
#    └ 댓글 3개 수집
#    → 누적 댓글 6720개
#
# ▶️ [142/500] [LIVE] 국민의힘, SK텔레콤 유심 해킹 &#39;긴급 간담회&#39
#    └ 댓글 7개 수집
#    → 누적 댓글 6727개
#
# ▶️ [143/500] 복제폰 나와도 책임질 수 있어요??  #유심 #해킹 #skt #대기업 #
#    └ 댓글 19개 수집
#    → 누적 댓글 6746개
#
# ▶️ [144/500] 최태원 SK회장의 청문회 불참 이유 ㄷㄷ #skt #sk텔레콤 #최태원
#    └ 댓글 6개 수집
#    → 누적 댓글 6752개
#
# ▶️ [145/500] 한덕수, SK텔레콤 유심 해킹 사고 관련 긴급지시
#    └ 댓글 1개 수집
#    → 누적 댓글 6753개
#
# ▶️ [146/500] SKT 유심 해킹 사태, SK텔레콤 폭망 중??
#    └ 댓글 3개 수집
#    → 누적 댓글 6756개
#
# ▶️ [147/500] SK텔레콤 4월19일 해킹 사고 대응 바
#    └ 댓글 8개 수집
#    → 누적 댓글 6764개
#
# ▶️ [148/500] 유심 해킹 무섭구나~ SK텔레콤 아이폰16프로맥스 100만원 지원!! 역
#    └ 댓글 7개 수집
#    → 누적 댓글 6771개
#
# ▶️ [149/500] SKT 유심해킹 방지 대처법 3가지 #skt #ai #해킹
#    └ 댓글 3개 수집
#    → 누적 댓글 6774개
#
# ▶️ [150/500] &quot;SKT 유심 해킹 46억 배상하라&quot; 9,100여 명
#    └ 댓글 11개 수집
#    → 누적 댓글 6785개
#
# ▶️ [151/500] 유심해킹 대란 SK대리점, SK텔레콤 고객센터에서 유심보호서비스 가입,
#    └ 댓글 7개 수집
#    → 누적 댓글 6792개
#
# ▶️ [152/500] 유심해킹 어떻게 대처해야 할까? #유심 #해킹 #방지방법 #개인정보보호
#    └ 댓글 1개 수집
#    → 누적 댓글 6793개
#
# ▶️ [153/500] SKT 유심 &#39;해킹 포비아&#39;, 현장은 대혼란 / KNN
#    └ 댓글 0개 수집
#    → 누적 댓글 6793개
#
# ▶️ [154/500] 이번 SK텔레콤 유심 해킹 사태 미국이었다면 #sk텔레콤 #유심 #해킹사
#    └ 댓글 3개 수집
#    → 누적 댓글 6796개
#
# ▶️ [155/500] 유심만 바꾸면 끝? 역대급 SK텔레콤 해킹 총정리 및 대처법  (노말틱
#    └ 댓글 8개 수집
#    → 누적 댓글 6804개
#
# ▶️ [156/500] 🔴LIVE SK 텔레콤, &quot;가입자 전원 유심 정보 유출&quot
#    └ 댓글 0개 수집
#    → 누적 댓글 6804개
#
# ▶️ [157/500] SK 텔레콤 유심 해킹 대란에 대리점 일주일 간 휴무…황당  / KNN
#    └ 댓글 6개 수집
#    → 누적 댓글 6810개
#
# ▶️ [158/500] 지금 2300만 명이 큰일난 이유
#    └ 댓글 1개 수집
#    → 누적 댓글 6811개
#
# ▶️ [159/500] 국가기간 통신망이 뚫렸다 &#39;중국 해커&#39;가 SKT를 노린 진
#    └ 댓글 9개 수집
#    → 누적 댓글 6820개
#
# ▶️ [160/500] SK텔레콤 유심 해킹 사태
#    └ 댓글 1개 수집
#    → 누적 댓글 6821개
#
# ▶️ [161/500] SK텔레콤 유심교체전에 주의사항 3가지 #SK텔레콤 #SKT #유심교체
#    └ 댓글 3개 수집
#    → 누적 댓글 6824개
#
# ▶️ [162/500] SKT, 5일부터 신규가입 중단... 유심보호서비스 자동 가입 전환
#    └ 댓글 6개 수집
#    → 누적 댓글 6830개
#
# ▶️ [163/500] “SK텔레콤 유심 정보 유출, 진짜 유출된 건 무엇인가?”
#    └ 댓글 0개 수집
#    → 누적 댓글 6830개
#
# ▶️ [164/500] SKT해킹!! 현재 근황  #skt #해킹 #유심 #skt사태
#    └ 댓글 2개 수집
#    → 누적 댓글 6832개
#
# ▶️ [165/500] [2편]어지러운 SK 유심 유출 근황 ㄷㄷ
#    └ 댓글 2개 수집
#    → 누적 댓글 6834개
#
# ▶️ [166/500] &quot;SKT 유심 해킹 피해 46억 배상하라&quot;…9천 명 공
#    └ 댓글 1개 수집
#    → 누적 댓글 6835개
#
# ▶️ [167/500] SKT 유심 품절에 분노하는 가입자들!
#    └ 댓글 0개 수집
#    → 누적 댓글 6835개
#
# ▶️ [168/500] [LIVE 🔴 2시 예정] &#39;유심 해킹 사태&#39; SK 텔레콤
#    └ 댓글 4개 수집
#    → 누적 댓글 6839개
#
# ▶️ [169/500] SKT 이용자 9천명, &#39;유심 해킹&#39;에 46억원대 손해배상
#    └ 댓글 5개 수집
#    → 누적 댓글 6844개
#
# ▶️ [170/500] 최태원 대국민 사과... 위약금 면제엔 &quot;논의 중&quot; (
#    └ 댓글 4개 수집
#    → 누적 댓글 6848개
#
# ▶️ [171/500] [에경PICK] 계좌 털릴수도 있는데…‘유심 해킹’ SKT, 직접고지 없
#    └ 댓글 4개 수집
#    → 누적 댓글 6852개
#
# ▶️ [172/500] SKT 위약금 거부…신뢰는 무너졌다 #SK텔레콤 #유심해킹 #위약금논란
#    └ 댓글 6개 수집
#    → 누적 댓글 6858개
#
# ▶️ [173/500] SKT 유심 해킹&amp;피해 대처법 총정리! 초비상! 무조건 공유해주세
#    └ 댓글 7개 수집
#    → 누적 댓글 6865개
#
# ▶️ [174/500] SKT 유심 해킹 번호이동이 답?!
#    └ 댓글 5개 수집
#    → 누적 댓글 6870개
#
# ▶️ [175/500] &quot;‘유심 해킹’보다 더 충격적인 진실&quot;#SK텔레콤 #유
#    └ 댓글 2개 수집
#    → 누적 댓글 6872개
#
# ▶️ [176/500] SKT 유심 교체 첫날…곳곳 재고 부족 #shorts / 연합뉴스TV (
#    └ 댓글 2개 수집
#    → 누적 댓글 6874개
#
# ▶️ [177/500] (긴급) SK텔레콤 유심 해킹됐는지 스마트폰으로 1초만에 확인하는 방법
#    └ 댓글 1개 수집
#    → 누적 댓글 6875개
#
# ▶️ [178/500] 두 번이나 해킹 당한 이통사 #유심 #유출 #정보 #이슈 #SKT
#    └ 댓글 2개 수집
#    → 누적 댓글 6877개
#
# ▶️ [179/500] 경찰, &#39;SKT 유심 해킹 사태&#39; 정식 수사 착수 #SKT
#    └ 댓글 2개 수집
#    → 누적 댓글 6879개
#
# ▶️ [180/500] 🚨SK텔레콤 유심 정보 해킹 사태, 손해배상청구소송 착수 예정🚨 #sk텔
#    └ 댓글 4개 수집
#    → 누적 댓글 6883개
#
# ▶️ [181/500] [이슈분석] SK텔레콤 유심 해킹 사태.. 역대급으로 심각한 이유 / L
#    └ 댓글 0개 수집
#    → 누적 댓글 6883개
#
# ▶️ [182/500] SK 유심 해킹 위험한 이유 #유심 #유심해킹 #SK유심 SKT유심 #S
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 6883개
#
# ▶️ [183/500] SKT 유심 정보를 해킹한 레드 멘션의 충격적인 정체와 그들이 노린 충격
#    └ 댓글 1개 수집
#    → 누적 댓글 6884개
#
# ▶️ [184/500] SKT 유심 해킹 사태, 재고 부족에 &quot;초기화 병행&quot;
#    └ 댓글 0개 수집
#    → 누적 댓글 6884개
#
# ▶️ [185/500] 이 와중에도 신규고객 잡기에 혈안 SK텔레콤 유심 해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 6884개
#
# ▶️ [186/500] SKT 해킹 사건으로 유심 교체 방법 그리고 옆 구멍 찔렀을 때😨 #쇼츠
#    └ 댓글 2개 수집
#    → 누적 댓글 6886개
#
# ▶️ [187/500] [SKT해킹 유심변경 하면 위험한이유]#SK텔레콤 #SKT유심해킹 #SK
#    └ 댓글 7개 수집
#    → 누적 댓글 6893개
#
# ▶️ [188/500] SK텔레콤 유심 유출 사태, 집단소송? #sk텔레콤  #skt #유심유출
#    └ 댓글 1개 수집
#    → 누적 댓글 6894개
#
# ▶️ [189/500] &quot;5천만 원 탈취, SKT 유심 유출 무관&quot; #shor
#    └ 댓글 3개 수집
#    → 누적 댓글 6897개
#
# ▶️ [190/500] SK 해킹 사고 및 간단 대처법 (통합)
#    └ 댓글 0개 수집
#    → 누적 댓글 6897개
#
# ▶️ [191/500] 🔴LIVE SK 텔레콤, &quot;가입자 전원 유심 정보 유출&quot
#    └ 댓글 2개 수집
#    → 누적 댓글 6899개
#
# ▶️ [192/500] 미국 암호화폐 거래소 &#39;유심해킹&#39;으로 5,400억원 털린
#    └ 댓글 0개 수집
#    → 누적 댓글 6899개
#
# ▶️ [193/500] SKT 유심 해킹 X된 이유
#    └ 댓글 2개 수집
#    → 누적 댓글 6901개
#
# ▶️ [194/500] SKT 유심 정보 해킹 유심보호서비스
#    └ 댓글 1개 수집
#    → 누적 댓글 6902개
#
# ▶️ [195/500] USIM과 ESIM의 차이점? #해킹 #이슈 #뉴스 #skt #usim
#    └ 댓글 0개 수집
#    → 누적 댓글 6902개
#
# ▶️ [196/500] 유심해킹사태 해결은 번호이동뿐?  #정치 #sk텔레콤
#    └ 댓글 3개 수집
#    → 누적 댓글 6905개
#
# ▶️ [197/500] SK텔레콤의 유심해킹관련 대응. 유심보호서비스 가입방법. #Sk텔레콤해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 6906개
#
# ▶️ [198/500] 유심 교체 못하고 출국했더니…개인정보 털렸다? SKT의 책임은? #SK텔
#    └ 댓글 1개 수집
#    → 누적 댓글 6907개
#
# ▶️ [199/500] [🔴현장 LIVE] SK텔레콤 유심 해킹 사태 관련 청문회-과학기술정보통
#    └ 댓글 2개 수집
#    → 누적 댓글 6909개
#
# ▶️ [200/500] SK텔레콤, 2,500만명 대상 유심 무료 교체 시작...‘재고 부족’
#    └ 댓글 1개 수집
#    → 누적 댓글 6910개
#
# ▶️ [201/500] 전국이 SKT 유심 해킹으로 난리입니다 #SKT #유심 #실시간
#    └ 댓글 5개 수집
#    → 누적 댓글 6915개
#
# ▶️ [202/500] 🔴LIVE SK 텔레콤, &quot;가입자 전원 유심 정보 유출&quot
#    └ 댓글 9개 수집
#    → 누적 댓글 6924개
#
# ▶️ [203/500] 유심복재 피해시 100% 책임   #SK텔레콤 #유심교체 #해킹피해 #개
#    └ 댓글 0개 수집
#    → 누적 댓글 6924개
#
# ▶️ [204/500] SK텔레콤 유심 해킹, 집단소송 시작됐다?! 피해자 대응 총정리
#    └ 댓글 3개 수집
#    → 누적 댓글 6927개
#
# ▶️ [205/500] SK텔레콤 해킹, 중국 해커 배후 가능성? 다크웹 유출은 미확인
#    └ 댓글 4개 수집
#    → 누적 댓글 6931개
#
# ▶️ [206/500] 사상 초유의 유심 해킹 사태｜창업주 뒷이야기 10화 #skt #유심 #해
#    └ 댓글 1개 수집
#    → 누적 댓글 6932개
#
# ▶️ [207/500] 황금연휴 김해공항 포화, SK텔레콤 유심해킹까지 / KNN
#    └ 댓글 3개 수집
#    → 누적 댓글 6935개
#
# ▶️ [208/500] &quot;피해 보상&quot; SKT 위약금 면제엔… / #채널A #s
#    └ 댓글 5개 수집
#    → 누적 댓글 6940개
#
# ▶️ [209/500] [4K] eSIM으로 바꿀 사람 꼭 보세요.  #SKT해킹 #eSIM #
#    └ 댓글 2개 수집
#    → 누적 댓글 6942개
#
# ▶️ [210/500] 업계 1위 SK텔레콤 유심 해킹, 피해자 규모도 역대 1위?_(2,300
#    └ 댓글 3개 수집
#    → 누적 댓글 6945개
#
# ▶️ [211/500] SKT 해킹 3년 전부터..2,700만 유심정보 유출 / 연합뉴스TV(Y
#    └ 댓글 4개 수집
#    → 누적 댓글 6949개
#
# ▶️ [212/500] [에경PICK] 유심 해킹에 고개 숙인 SK 최태원…위약금 면제는 “검토
#    └ 댓글 10개 수집
#    → 누적 댓글 6959개
#
# ▶️ [213/500] SKT 떠난다 봇물 유심 해킹 일파만파 / #채널A #shorts #뉴스
#    └ 댓글 1개 수집
#    → 누적 댓글 6960개
#
# ▶️ [214/500] &quot;SKT 위약금 면제면 500만 이탈, 7조 손실 공포!&quo
#    └ 댓글 4개 수집
#    → 누적 댓글 6964개
#
# ▶️ [215/500] SK텔레콤 해킹사태 유심교체전 체크사항! #SKT해킹 #유심교체 #SK텔
#    └ 댓글 1개 수집
#    → 누적 댓글 6965개
#
# ▶️ [216/500] &#39;SKT 유심 해킹&#39; 경영진 수사 착수…해킹 배후 수사도
#    └ 댓글 4개 수집
#    → 누적 댓글 6969개
#
# ▶️ [217/500] “SKT 해킹, 이제 과징금 폭탄까지…정부가 직접 나섰다!” #skt #
#    └ 댓글 3개 수집
#    → 누적 댓글 6972개
#
# ▶️ [218/500] 최태원 회장은 왜 침묵하는가? SKT 유심 해킹 사태(20250430)
#    └ 댓글 4개 수집
#    → 누적 댓글 6976개
#
# ▶️ [219/500] SK텔레콤 유심 해킹, 미국 5천억 손해배상 소송처럼 될까
#    └ 댓글 4개 수집
#    → 누적 댓글 6980개
#
# ▶️ [220/500] #유심 #해킹 #유심해킹 #skt #phone #sim #개인정보 #정보
#    └ 댓글 2개 수집
#    → 누적 댓글 6982개
#
# ▶️ [221/500] SKT 유심 해킹 사태 집단소송에 참가해야하는 이유 | SK텔레콤 집단소
#    └ 댓글 6개 수집
#    → 누적 댓글 6988개
#
# ▶️ [222/500] SK텔레콤 해킹사태로 가입자 2만 5천명 이탈  #SK텔레콤 #해킹 #유
#    └ 댓글 0개 수집
#    → 누적 댓글 6988개
#
# ▶️ [223/500] 최민희, 국회 과방위 ‘SK텔레콤 유심 정보유출 청문회’ 대선 후 재개
#    └ 댓글 4개 수집
#    → 누적 댓글 6992개
#
# ▶️ [224/500] SKT, 유심 무료교체 온라인 예약시스템 개통…접속 장애 #SKT #유심
#    └ 댓글 1개 수집
#    → 누적 댓글 6993개
#
# ▶️ [225/500] SK텔레콤 해킹사건 USIM 해킹이 무서운 이유
#    └ 댓글 1개 수집
#    → 누적 댓글 6994개
#
# ▶️ [226/500] SKT, 20일경 유심 교체 마무리… 소요 비용만 2000억원 (2025
#    └ 댓글 1개 수집
#    → 누적 댓글 6995개
#
# ▶️ [227/500] &quot;개인정보 대참사! SK텔레콤 유심 유출 사건&quot;#SK텔
#    └ 댓글 4개 수집
#    → 누적 댓글 6999개
#
# ▶️ [228/500] 이번 skt 유심 해킹 사태가 심각한 이유
#    └ 댓글 1개 수집
#    → 누적 댓글 7000개
#
# ▶️ [229/500] SK텔레콤 해킹사태, 다른 통신사들도 안전할까...? #통신주 #통신사
#    └ 댓글 0개 수집
#    → 누적 댓글 7000개
#
# ▶️ [230/500] SKT 유심해킹 위험한 이유와 화나는 ᄌ
#    └ 댓글 0개 수집
#    → 누적 댓글 7000개
#
# ▶️ [231/500] [ISSUE] “SKT 유심 정보 유출 사고”
#    └ 댓글 0개 수집
#    → 누적 댓글 7000개
#
# ▶️ [232/500] SK텔레콤 “28일부터 유심 ‘무상 교체’…해킹 피해는 없어” / KBS
#    └ 댓글 4개 수집
#    → 누적 댓글 7004개
#
# ▶️ [233/500] 시골의 sk텔레콤 유심대란 #유심 # 개인정보유출 #통신사 #shorts
#    └ 댓글 1개 수집
#    → 누적 댓글 7005개
#
# ▶️ [234/500] 유심 교체? 통신사 교체? ‘최악 해킹’ 당신의 선택은 #shorts/
#    └ 댓글 0개 수집
#    → 누적 댓글 7005개
#
# ▶️ [235/500] SKT 유심해킹#SKT#통신사#해킹#유심#유심해킹#피해
#    └ 댓글 1개 수집
#    → 누적 댓글 7006개
#
# ▶️ [236/500] 유심해킹사태 SK텔레콤 운명? 최태원 회장 사주를 살펴보니 ...
#    └ 댓글 1개 수집
#    → 누적 댓글 7007개
#
# ▶️ [237/500] 💣 SK텔레콤 해킹 터졌다! 유심 정보 유출 로 금융 사기 까지… 보안
#    └ 댓글 6개 수집
#    → 누적 댓글 7013개
#
# ▶️ [238/500] SKT &quot;유심보호서비스 모든 고객 가입 마무리&quot; #SK
#    └ 댓글 0개 수집
#    → 누적 댓글 7013개
#
# ▶️ [239/500] SK텔레콤 유심 해킹 ㅈ됐다. #sk텔레콤 #해킹 #유심  #통신사  @
#    └ 댓글 0개 수집
#    → 누적 댓글 7013개
#
# ▶️ [240/500] skt 요금을 미납해보았다 #shorts
#    └ 댓글 1개 수집
#    → 누적 댓글 7014개
#
# ▶️ [241/500] 내 유심 정보 초간단 보호하기  #skt #티월드 #유심 #해킹 #개인정
#    └ 댓글 0개 수집
#    → 누적 댓글 7014개
#
# ▶️ [242/500] SK텔레콤 유심 해킹 사건, 중국어로 정리 🦹 | 중국어 실력 향상 |
#    └ 댓글 3개 수집
#    → 누적 댓글 7017개
#
# ▶️ [243/500] SKT 유심 해킹사고가 불러온 최악의 시나리오
#    └ 댓글 0개 수집
#    → 누적 댓글 7017개
#
# ▶️ [244/500] [자막] 유심 해킹 SK텔레콤 유영상 사장, 국회 청문회 증인 선서
#    └ 댓글 1개 수집
#    → 누적 댓글 7018개
#
# ▶️ [245/500] SK텔레콤 시스템 해킹으로 고객USIM 정보 유출 #skt #usim #
#    └ 댓글 2개 수집
#    → 누적 댓글 7020개
#
# ▶️ [246/500] SK텔레콤 쓰는 사람 필수 체크!
#    └ 댓글 0개 수집
#    → 누적 댓글 7020개
#
# ▶️ [247/500] 위기의 SKT...유심교체는 언제 가능한가 #SK텔레콤 #유심교체 #해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 7021개
#
# ▶️ [248/500] “SKT 대란! 해킹에 유출에...가입까지 금지?!”  #유심대란 #유심
#    └ 댓글 1개 수집
#    → 누적 댓글 7022개
#
# ▶️ [249/500] 최악의 해킹사태다
#    └ 댓글 5개 수집
#    → 누적 댓글 7027개
#
# ▶️ [250/500] &quot;KT나 LG로 바꾸면 괜찮아요?&quot;... 개인정보위원회
#    └ 댓글 0개 수집
#    → 누적 댓글 7027개
#
# ▶️ [251/500] &quot;유심 해킹 터지자… 전국 매장 유심 대란!&quot; #SK텔
#    └ 댓글 1개 수집
#    → 누적 댓글 7028개
#
# ▶️ [252/500] 속보 - 우려했던 일이 현실로... SKT 해킹 5,000만원 인출, 설
#    └ 댓글 1개 수집
#    → 누적 댓글 7029개
#
# ▶️ [253/500] SK의 유심 해킹 사태, 위약금 논란!! #유심 #교체 #skt #위약금
#    └ 댓글 2개 수집
#    → 누적 댓글 7031개
#
# ▶️ [254/500] SK텔레콤 유심 해킹 사고! 지금 당장 3가지 설정하세요! 유심 교체 전
#    └ 댓글 2개 수집
#    → 누적 댓글 7033개
#
# ▶️ [255/500] #skt #유심 #해킹, #중국 #해커그룹 #소행?
#    └ 댓글 8개 수집
#    → 누적 댓글 7041개
#
# ▶️ [256/500] SKT &#39;유심 해킹&#39;, 왜 발생했고 누구의 잘못인가?
#    └ 댓글 5개 수집
#    → 누적 댓글 7046개
#
# ▶️ [257/500] 과거 내가 10년간 이용했던 SKT 현 근황 #skt #유심 #유출 #근
#    └ 댓글 1개 수집
#    → 누적 댓글 7047개
#
# ▶️ [258/500] [에경PICK] “재고 없어요” “주말 예약자부터”…SKT 유심 무상교체
#    └ 댓글 1개 수집
#    → 누적 댓글 7048개
#
# ▶️ [259/500] 황금연휴 김해공항 포화, SK텔레콤 유심해킹까지 / KNN
#    └ 댓글 1개 수집
#    → 누적 댓글 7049개
#
# ▶️ [260/500] SKT 유심 해킹, 어떻게 되는 걸까?
#    └ 댓글 1개 수집
#    → 누적 댓글 7050개
#
# ▶️ [261/500] SKT 유심 해킹 &#39;후폭풍&#39;…예고된 대란 | Final S
#    └ 댓글 7개 수집
#    → 누적 댓글 7057개
#
# ▶️ [262/500] [에경PICK] SKT 유심사태로 하루에만 3만4000명 이탈 #shor
#    └ 댓글 2개 수집
#    → 누적 댓글 7059개
#
# ▶️ [263/500] 유심대란 이 영상시청 50초만 투자하면 걱정 끝
#    └ 댓글 4개 수집
#    → 누적 댓글 7063개
#
# ▶️ [264/500] SKT, 유심 재설정 첫날 2만3천명 이용/ 연합뉴스TV(Yonhapne
#    └ 댓글 0개 수집
#    → 누적 댓글 7063개
#
# ▶️ [265/500] 2300만 해킹 사건! 해킹 IP주소가 찍혀있다? #shorts #SKT
#    └ 댓글 6개 수집
#    → 누적 댓글 7069개
#
# ▶️ [266/500] “한 번 털리면 끝” 유심 PIN 보안도 뚫는다 #usim #usim교체
#    └ 댓글 0개 수집
#    → 누적 댓글 7069개
#
# ▶️ [267/500] 최악의 SKT 유심 해킹 사건! &quot;번호이동 하려는데 위약금 내라
#    └ 댓글 3개 수집
#    → 누적 댓글 7072개
#
# ▶️ [268/500] SK 텔레콤 고객 필수시청 !! 충격 경고! 유심 해킹으로 통장이 순식간
#    └ 댓글 1개 수집
#    → 누적 댓글 7073개
#
# ▶️ [269/500] SK텔레콤 유심 해킹에…국내 1위 신뢰 ‘흔들’
#    └ 댓글 1개 수집
#    → 누적 댓글 7074개
#
# ▶️ [270/500] SK텔레콤, 국회 청문회서 유심 해킹 사고 책임 인정…위약금 면제는 &q
#    └ 댓글 1개 수집
#    → 누적 댓글 7075개
#
# ▶️ [271/500] SKT 텔레콤 유심 해킹 피해, 100% 책임 진다고? #이슈 #논란 #
#    └ 댓글 0개 수집
#    → 누적 댓글 7075개
#
# ▶️ [272/500] 한국 통신사 역사상 최악의 유심 해킹 사고 &#39;SK텔레콤 사태&#3
#    └ 댓글 1개 수집
#    → 누적 댓글 7076개
#
# ▶️ [273/500] 충격 심각한 sk 해킹 사고
#    └ 댓글 5개 수집
#    → 누적 댓글 7081개
#
# ▶️ [274/500] SKT의 적반하장!? 위약금 면제는 안된다고?! #SKT #lguplus
#    └ 댓글 2개 수집
#    → 누적 댓글 7083개
#
# ▶️ [275/500] SK텔레콤 유심 해킹 - 금융범죄 연관성 질문에 과기부 장관 답변은?
#    └ 댓글 4개 수집
#    → 누적 댓글 7087개
#
# ▶️ [276/500] SKT가 털렸는데, 왜 내가 위약금을 내? 위약금 면제 방법 공개! #법
#    └ 댓글 0개 수집
#    → 누적 댓글 7087개
#
# ▶️ [277/500] SK텔레콤 유심해킹 사고유심 무료 교체 오픈런 #행복한아침
#    └ 댓글 1개 수집
#    → 누적 댓글 7088개
#
# ▶️ [278/500] SK 해킹 사건 유심복제 간단 대처법 한가지
#    └ 댓글 8개 수집
#    → 누적 댓글 7096개
#
# ▶️ [279/500] SK텔레콤 유심 정보 유출? 예방법은?  #sk텔레콤 #유심정보유출  #
#    └ 댓글 1개 수집
#    → 누적 댓글 7097개
#
# ▶️ [280/500] 유심 교체전까지 어떻게 해야되는데#유심#skt#해킹#핸드폰
#    └ 댓글 0개 수집
#    → 누적 댓글 7097개
#
# ▶️ [281/500] SKT회원 위약금면제 안된다
#    └ 댓글 3개 수집
#    → 누적 댓글 7100개
#
# ▶️ [282/500] ‘SK텔레콤 유심 해킹’ 악용한 피싱 문자, 절대 클릭 금지
#    └ 댓글 0개 수집
#    → 누적 댓글 7100개
#
# ▶️ [283/500] SKT 해킹 사고 유심 무상 교체 방법 #sk텔레콤 최태원 T월드
#    └ 댓글 2개 수집
#    → 누적 댓글 7102개
#
# ▶️ [284/500] SK텔레콤 해킹 사건 정리 | 유심 무상 교체 시작 📱
#    └ 댓글 2개 수집
#    → 누적 댓글 7104개
#
# ▶️ [285/500] SKT 해킹 사태.. 유심 물량 부족 어떡해야 할까? #shorts
#    └ 댓글 0개 수집
#    → 누적 댓글 7104개
#
# ▶️ [286/500] SKT 위약금은?
#    └ 댓글 1개 수집
#    → 누적 댓글 7105개
#
# ▶️ [287/500] SKT 유심 해킹 한 달, 유심 교체는?
#    └ 댓글 2개 수집
#    → 누적 댓글 7107개
#
# ▶️ [288/500] SKT 유심 해킹사태? 유심이 도대체 뭔데 이렇게 무서운가요?
#    └ 댓글 0개 수집
#    → 누적 댓글 7107개
#
# ▶️ [289/500] ‘SK 텔레콤’ 해킹 사태! 금융피해는 없을까? 전문가 해석 총정리 #S
#    └ 댓글 3개 수집
#    → 누적 댓글 7110개
#
# ▶️ [290/500] SKT 유심 정보 해킹 충격! SK텔레콤의 진짜 문제는 따로 있다.
#    └ 댓글 2개 수집
#    → 누적 댓글 7112개
#
# ▶️ [291/500] SKT 유심 해킹? 알뜰폰 개통되고 5천만원 계좌이체 됨
#    └ 댓글 0개 수집
#    → 누적 댓글 7112개
#
# ▶️ [292/500] 유심을지켜라 sk텔레콤해킹사건
#    └ 댓글 0개 수집
#    → 누적 댓글 7112개
#
# ▶️ [293/500] 유심 보호 서비스 하루 새 217만 가입… 혼란 속 대기 170시간 #이
#    └ 댓글 0개 수집
#    → 누적 댓글 7112개
#
# ▶️ [294/500] 유심 해킹? 당신도 이미 노출됐을 수 있습니다! 해킹 사태 총정리!!!
#    └ 댓글 0개 수집
#    → 누적 댓글 7112개
#
# ▶️ [295/500] [에경PICK] “악성코드 또 나왔다”…SKT 서버에서 13종 추가 확인
#    └ 댓글 1개 수집
#    → 누적 댓글 7113개
#
# ▶️ [296/500] SKT 유심 해킹 사태 진짜 문제는 ‘복제폰’   #skt  #SK텔레콤
#    └ 댓글 0개 수집
#    → 누적 댓글 7113개
#
# ▶️ [297/500] SKT 유심 해킹 사태 총정리 복제폰 ᄋ
#    └ 댓글 0개 수집
#    → 누적 댓글 7113개
#
# ▶️ [298/500] ❗️유심 해킹 대처 방법? 3단계만 따라하세요 (가족들에게 공유) #sk
#    └ 댓글 1개 수집
#    → 누적 댓글 7114개
#
# ▶️ [299/500] 유심보호서비스 sk텔레콤 해킹 유심교체신청 유심예약
#    └ 댓글 0개 수집
#    → 누적 댓글 7114개
#
# ▶️ [300/500] SK텔레콤 유심 해킹사고 18일 첫 인지, 24시간 보고 규정 위반 의혹
#    └ 댓글 5개 수집
#    → 누적 댓글 7119개
#
# ▶️ [301/500] SKT 유심 해킹 조사 결과 발표까지 최대 1년 소요 답변 확인! 재발
#    └ 댓글 0개 수집
#    → 누적 댓글 7119개
#
# ▶️ [302/500] 최악의 SKT 유심 해킹 사건! &quot;유심만 해킹? 빙산의 일각일
#    └ 댓글 1개 수집
#    → 누적 댓글 7120개
#
# ▶️ [303/500] &quot;SK텔레콤 유심 해킹 사고, 대응 시작!&quot;
#    └ 댓글 1개 수집
#    → 누적 댓글 7121개
#
# ▶️ [304/500] &#39;해킹사고&#39; 고개 숙인 SK텔레콤(20250425)
#    └ 댓글 7개 수집
#    → 누적 댓글 7128개
#
# ▶️ [305/500] SKT, 오늘부터 신규가입 중단… 실효성 우려  #SKT #유심 #신규가
#    └ 댓글 0개 수집
#    → 누적 댓글 7128개
#
# ▶️ [306/500] SKT 유심 해킹 사태 정리📱 삼성도 발칵! 늦장 대응 논란 #SKT #
#    └ 댓글 1개 수집
#    → 누적 댓글 7129개
#
# ▶️ [307/500] 해킹 사고’가 발생한 SK텔레콤이 25일 2,300만 명에 달하는 전 고
#    └ 댓글 0개 수집
#    → 누적 댓글 7129개
#
# ▶️ [308/500] SK 텔레콤 유심 유출
#    └ 댓글 0개 수집
#    → 누적 댓글 7129개
#
# ▶️ [309/500] SK텔레콤 유심 해킹! 인천공항 당일 출국자만 가능한 인천공항 SKT 유
#    └ 댓글 0개 수집
#    → 누적 댓글 7129개
#
# ▶️ [310/500] “LG유플은 애교 수준? SKT, 메인서버 털렸다” #skt해킹#sk텔레
#    └ 댓글 1개 수집
#    → 누적 댓글 7130개
#
# ▶️ [311/500] SK텔레콤 고객 정보 털렸다 &quot;유심 정보 해킹&quot;
#    └ 댓글 0개 수집
#    → 누적 댓글 7130개
#
# ▶️ [312/500] &quot;SKT 2300만명 역대 최악의 유심유출!&quot; 이것부터
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 7130개
#
# ▶️ [313/500] 지금 꼭 확인 하세요! SK텔레콤 유심 해킹 사고 발생 - ( 대책 및
#    └ 댓글 3개 수집
#    → 누적 댓글 7133개
#
# ▶️ [314/500] skt유심유출사고 대처법 &quot;핵심3가지&quot; #뉴스 #skt
#    └ 댓글 0개 수집
#    → 누적 댓글 7133개
#
# ▶️ [315/500] SKT 과징금 예상 규모는? #경제토크쇼픽
#    └ 댓글 1개 수집
#    → 누적 댓글 7134개
#
# ▶️ [316/500] SK텔레콤 유심 해킹 사태, 대응책 총정리
#    └ 댓글 0개 수집
#    → 누적 댓글 7134개
#
# ▶️ [317/500] 아직도 안했다구요? 빨리 해야합니다. 지금 유심이 문제가 아니에요. 이것
#    └ 댓글 1개 수집
#    → 누적 댓글 7135개
#
# ▶️ [318/500] 통신 1위 SKT 무너지나... SK텔레콤 가입자 40만 이탈! #유심
#    └ 댓글 6개 수집
#    → 누적 댓글 7141개
#
# ▶️ [319/500] SK 텔레콤 해킹 사태 대비 #sk텔레콤 #해킹 #명의도용 #Pass #
#    └ 댓글 0개 수집
#    → 누적 댓글 7141개
#
# ▶️ [320/500] 개인정보 다 털렸다, SKT 유심 해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 7142개
#
# ▶️ [321/500] 통신사 1위 ‘SK텔레콤’, 외부 해킹으로 고객 유심 정보 유출 (202
#    └ 댓글 0개 수집
#    → 누적 댓글 7142개
#
# ▶️ [322/500] skt 유심 해킹...#skt #유심 #해킹 #뉴스 #이슈 #sk텔레콤
#    └ 댓글 0개 수집
#    → 누적 댓글 7142개
#
# ▶️ [323/500] SKT 유심교체 첫날 오픈런 상황 #sk텔레콤 #유심해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 7142개
#
# ▶️ [324/500] SKT 유심 해킹 사과 이건 레알 X된 상황임
#    └ 댓글 1개 수집
#    → 누적 댓글 7143개
#
# ▶️ [325/500] 2025 현시점 SKT 유심 해킹 피해 대처법 총정리 내 정보 지키는 3
#    └ 댓글 2개 수집
#    → 누적 댓글 7145개
#
# ▶️ [326/500] SKT 해킹 2695만건 유출! IMEI까지 포함된 역대급 개인정보 유출
#    └ 댓글 5개 수집
#    → 누적 댓글 7150개
#
# ▶️ [327/500] 한국 통신사 역사상 최악의 유심 해킹 사고 &#39;SK텔레콤 사태&#3
#    └ 댓글 2개 수집
#    → 누적 댓글 7152개
#
# ▶️ [328/500] SKT 해킹, 2700만 고객 디지털 신분증 털렸다 #SKT #해킹 #유
#    └ 댓글 0개 수집
#    → 누적 댓글 7152개
#
# ▶️ [329/500] sk텔레콤 유심 무상 교체, 환급도 가능하다!
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 7152개
#
# ▶️ [330/500] SKT 사용자 여러분 안심하십시오 #유심 #해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 7152개
#
# ▶️ [331/500] #이게머선일이고 #해킹 #sk텔레콤 #유심교체
#    └ 댓글 0개 수집
#    → 누적 댓글 7152개
#
# ▶️ [332/500] SKT 유심 해킹 사태, 2500만 명 정보 유출…지금 반드시 챙겨야 할
#    └ 댓글 0개 수집
#    → 누적 댓글 7152개
#
# ▶️ [333/500] SK텔레콤 가입자 꼭 보세요!(유심 해킹 대책) #쇼츠
#    └ 댓글 1개 수집
#    → 누적 댓글 7153개
#
# ▶️ [334/500] 미쳤다 SK 해킹 사건 유심 해킹
#    └ 댓글 2개 수집
#    → 누적 댓글 7155개
#
# ▶️ [335/500] 2025년 🚨 SKT 유심보호 서비스 가입 꿀팁! 유심 해킹 방지, 헷갈
#    └ 댓글 0개 수집
#    → 누적 댓글 7155개
#
# ▶️ [336/500] SKT 대규모 유심정보 해킹 피해자 대리 소송 참가 방법 #sk텔레콤 #
#    └ 댓글 4개 수집
#    → 누적 댓글 7159개
#
# ▶️ [337/500] SKT 유심 해킹, 내부자 있었다?
#    └ 댓글 0개 수집
#    → 누적 댓글 7159개
#
# ▶️ [338/500] #SK텔레콤 #해킹 #유심교체 #보안강화 #알뜰폰 #정보유출
#    └ 댓글 0개 수집
#    → 누적 댓글 7159개
#
# ▶️ [339/500] SK텔레콤 유심 유출과 OES 보안 강화 대응 SK Telecom USI
#    └ 댓글 1개 수집
#    → 누적 댓글 7160개
#
# ▶️ [340/500] SK텔레콤 유심해킹 사태 긴급 브리핑 1분 요약 #sk텔레콤 #유심교체
#    └ 댓글 1개 수집
#    → 누적 댓글 7161개
#
# ▶️ [341/500] SK텔레콤 쓰시는분들 유심교체하세요!! #SK텔레콤 #유심해킹 #유심유출
#    └ 댓글 0개 수집
#    → 누적 댓글 7161개
#
# ▶️ [342/500] [투자 노하우] 4월 SKT 유심 해킹 사태 발생…&quot;고객 우려↑
#    └ 댓글 1개 수집
#    → 누적 댓글 7162개
#
# ▶️ [343/500] #SK텔레콤 #유심해킹 #최태원 #사과 #보안사고
#    └ 댓글 0개 수집
#    → 누적 댓글 7162개
#
# ▶️ [344/500] skt 진짜 ㅈ댓다.. #skt #유심 #해킹 #아이폰 #핸드폰  #휴대
#    └ 댓글 0개 수집
#    → 누적 댓글 7162개
#
# ▶️ [345/500] SK 텔레콤 해킹!!! 유심정보 유출!!! 대응 방법은??
#    └ 댓글 0개 수집
#    → 누적 댓글 7162개
#
# ▶️ [346/500] SKT처럼 했다가 참교육당한 미국회사?
#    └ 댓글 0개 수집
#    → 누적 댓글 7162개
#
# ▶️ [347/500] SK텔레콤, 유심 정보 유출… 전 고객 무상 교체 실시 #SK텔레콤 #유
#    └ 댓글 0개 수집
#    → 누적 댓글 7162개
#
# ▶️ [348/500] 🎯SKT유심해킹,복제폰까지? #SK텔레콤 #해킹사건 #유심유출 #복제폰위
#    └ 댓글 2개 수집
#    → 누적 댓글 7164개
#
# ▶️ [349/500] SKT 가입자라면 이것부터 확인하세요! 유심해킹 피해 막는 법!!#SKT
#    └ 댓글 4개 수집
#    → 누적 댓글 7168개
#
# ▶️ [350/500] sk 유심 해킹으로 벌써 5천만원이 빠져나갔다??!
#    └ 댓글 0개 수집
#    → 누적 댓글 7168개
#
# ▶️ [351/500] sk 유심 해킹으로 벌써 5천만원이 빠져나갔다??!
#    └ 댓글 0개 수집
#    → 누적 댓글 7168개
#
# ▶️ [352/500] 5천만 원이 사라진 이유 유심 복제 피해와 무료 교체 서비스 #SK텔레콤
#    └ 댓글 0개 수집
#    → 누적 댓글 7168개
#
# ▶️ [353/500] SK텔레콤 유심 해킹 사건, 쉽게 설명해드립니다! #건강 #이슈 #관절가
#    └ 댓글 0개 수집
#    → 누적 댓글 7168개
#
# ▶️ [354/500] &quot;유심없어요?&quot; sk텔레콤 해킹 피해!
#    └ 댓글 0개 수집
#    → 누적 댓글 7168개
#
# ▶️ [355/500] SK텔레콤 유심 해킹 당신도 당할 수 있습니다.  #skt #sk텔레콤
#    └ 댓글 0개 수집
#    → 누적 댓글 7168개
#
# ▶️ [356/500] SKT 유심 정보 해킹과 3류스러운 대처
#    └ 댓글 0개 수집
#    → 누적 댓글 7168개
#
# ▶️ [357/500] SK텔레콤 유심 정보 유출, 2300만명이 위험하다
#    └ 댓글 0개 수집
#    → 누적 댓글 7168개
#
# ▶️ [358/500] [오늘의 이슈] SK텔레콤 유심 해킹, 강력한 제재로 보안 기술 높여야
#    └ 댓글 5개 수집
#    → 누적 댓글 7173개
#
# ▶️ [359/500] #유심칩해킹 #SK텔레콤 #왜우리가줄을서야하는지 #shorts
#    └ 댓글 6개 수집
#    → 누적 댓글 7179개
#
# ▶️ [360/500] &quot;SK텔레콤, 전 고객 &#39;유심 무상 교체&#39; 긴급
#    └ 댓글 0개 수집
#    → 누적 댓글 7179개
#
# ▶️ [361/500] SKT 유심해킹 상황
#    └ 댓글 0개 수집
#    → 누적 댓글 7179개
#
# ▶️ [362/500] 정부 “SKT 유출 피해, 복제폰 위험 없다… 유심 보호 서비스는 필수”
#    └ 댓글 3개 수집
#    → 누적 댓글 7182개
#
# ▶️ [363/500] &quot;SK텔레콤 유심 교체 대혼란! 줄서고, 웃돈 거래까지?&quo
#    └ 댓글 0개 수집
#    → 누적 댓글 7182개
#
# ▶️ [364/500] SK텔레콤 유심 유출 사고 대응방법 #sk텔레콤 #보안 #유심 #안전
#    └ 댓글 0개 수집
#    → 누적 댓글 7182개
#
# ▶️ [365/500] SKT 유심 해킹 악용한 보이스피싱
#    └ 댓글 0개 수집
#    → 누적 댓글 7182개
#
# ▶️ [366/500] 맛집 웨이팅X   SKT 유심 교체 행렬!
#    └ 댓글 0개 수집
#    → 누적 댓글 7182개
#
# ▶️ [367/500] 너 지금 유심 해킹 당한거야 !
#    └ 댓글 0개 수집
#    → 누적 댓글 7182개
#
# ▶️ [368/500] #sk텔레콤해킹 #금융자산해킹 #개인보안해킹 #유심 #핸드폰해킹 #유심핀
#    └ 댓글 0개 수집
#    → 누적 댓글 7182개
#
# ▶️ [369/500] #SK텔레콤 #유심해킹 #개인정보유출 #사이버수사대 #SKT해킹 #부우의
#    └ 댓글 2개 수집
#    → 누적 댓글 7184개
#
# ▶️ [370/500] #SKT #USIM #해킹 #괜찮지? #불안감#GU #sktelecom
#    └ 댓글 1개 수집
#    → 누적 댓글 7185개
#
# ▶️ [371/500] SK텔레콤 유심(USIM) 무료 교체 진행 4월28일(월)~  #sk텔레
#    └ 댓글 2개 수집
#    → 누적 댓글 7187개
#
# ▶️ [372/500] 25년4월29일#sk해킹사태#SK텔레콤#유심해킹#데이터유출#복제폰#해킹사
#    └ 댓글 0개 수집
#    → 누적 댓글 7187개
#
# ▶️ [373/500] 해킹의심? #skt #skt유심 #유심 #해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 7188개
#
# ▶️ [374/500] 128 SKT SIM 해킹! 네 돈도 털린다? 영어로 자연스럽게 설명하고
#    └ 댓글 4개 수집
#    → 누적 댓글 7192개
#
# ▶️ [375/500] SK텔레콤 유심 정보 유출 사과 #skt #sktelecom
#    └ 댓글 0개 수집
#    → 누적 댓글 7192개
#
# ▶️ [376/500] 현재 난리난 SKT 해킹 상황ㄷㄷ #skt #해킹 #유심
#    └ 댓글 2개 수집
#    → 누적 댓글 7194개
#
# ▶️ [377/500] SK텔레콤 해킹, KT LGU+  유심지원 나서나? #sk텔레콤 #lg유
#    └ 댓글 0개 수집
#    → 누적 댓글 7194개
#
# ▶️ [378/500] SKT, 통신 3사 중 유일한 보안 투자 축소 #경제토크쇼픽
#    └ 댓글 0개 수집
#    → 누적 댓글 7194개
#
# ▶️ [379/500] SK텔레콤 유심 해킹 사건
#    └ 댓글 0개 수집
#    → 누적 댓글 7194개
#
# ▶️ [380/500] SK 해킹 사건 위약금이 무려7조원?
#    └ 댓글 0개 수집
#    → 누적 댓글 7194개
#
# ▶️ [381/500] SKT 해킹 피해 5천만원 털렸다? #skt #유심 #shorts #이슈
#    └ 댓글 0개 수집
#    → 누적 댓글 7194개
#
# ▶️ [382/500] 당신폰 안전한가? sk 해킹 사고
#    └ 댓글 5개 수집
#    → 누적 댓글 7199개
#
# ▶️ [383/500] 유심 품귀 현상,해킹 미확인 피해 등 #skt #유심 #해킹 #통신비
#    └ 댓글 1개 수집
#    → 누적 댓글 7200개
#
# ▶️ [384/500] &quot;SK텔레콤 고객정보 유심에서 유출?!&quot;
#    └ 댓글 0개 수집
#    → 누적 댓글 7200개
#
# ▶️ [385/500] 철퇴 든 이해민  #shorts #조국혁신당 #이해민 #국회의원 #sk텔
#    └ 댓글 0개 수집
#    → 누적 댓글 7200개
#
# ▶️ [386/500] &quot;해킹 피해자에 유심비 청구? SKT 문자 논란!&quot; #
#    └ 댓글 0개 수집
#    → 누적 댓글 7200개
#
# ▶️ [387/500] SKT, &#39;역대급&#39; 유심 유출사고!!... 해킹 여파 &#
#    └ 댓글 1개 수집
#    → 누적 댓글 7201개
#
# ▶️ [388/500] SKT, 유심 해킹 터지더니 대리점 줄 폭발했다?
#    └ 댓글 0개 수집
#    → 누적 댓글 7201개
#
# ▶️ [389/500] SKT 해킹, 대기업/금융/정부 비상! 5천만원 피해 의심까지? (지금
#    └ 댓글 0개 수집
#    → 누적 댓글 7201개
#
# ▶️ [390/500] &quot;SK텔레콤 유심 해킹... 개인정보 유출 얼마나 심각할까?&q
#    └ 댓글 0개 수집
#    → 누적 댓글 7201개
#
# ▶️ [391/500] SK텔레콤 유심해킹 논란 #올바른정보 #이슈 #웃긴밈 #개인정보유출 #심
#    └ 댓글 0개 수집
#    → 누적 댓글 7201개
#
# ▶️ [392/500] SKT 유심해킹사태 기기를 아예 교체해야 되나요?
#    └ 댓글 0개 수집
#    → 누적 댓글 7201개
#
# ▶️ [393/500] SKT 유심 해킹 대처방안 #skt #유심
#    └ 댓글 0개 수집
#    → 누적 댓글 7201개
#
# ▶️ [394/500] SKT 해킹 대처 딱 30초! #skt #shorts #해킹 #대처방법
#    └ 댓글 1개 수집
#    → 누적 댓글 7202개
#
# ▶️ [395/500] SKT 신규가입 중단 2달! 위약금 면제는 6월 말 결정? #SKT #위
#    └ 댓글 0개 수집
#    → 누적 댓글 7202개
#
# ▶️ [396/500] “정부 인증도 못 막았다… SKT 유심 해킹”       #skt #sk
#    └ 댓글 0개 수집
#    → 누적 댓글 7202개
#
# ▶️ [397/500] #SK텔레콤 #유심해킹 #최태원사과 #보안사고 #정보보호위원회 #미라클톡
#    └ 댓글 0개 수집
#    → 누적 댓글 7202개
#
# ▶️ [398/500] &quot;SKT 유심 유출 파장…가입자들 집단소송·청원 나섰다&quot
#    └ 댓글 0개 수집
#    → 누적 댓글 7202개
#
# ▶️ [399/500] [브금 주의] ...진짜... #sk텔레콤
#    └ 댓글 0개 수집
#    → 누적 댓글 7202개
#
# ▶️ [400/500] SK텔레콤 해킹사고 관련 정보 #유심 #포스푸드케어 #특우농원 #특우tv
#    └ 댓글 1개 수집
#    → 누적 댓글 7203개
#
# ▶️ [401/500] SK텔레콤 해킹, 단순 민간 해킹 아닌 정밀한 사이버 작전 가능성 제기
#    └ 댓글 0개 수집
#    → 누적 댓글 7203개
#
# ▶️ [402/500] SK텔레콤 유심유출과 OES 보안강화 대응방법 이재백본부장 ONEECOT
#    └ 댓글 0개 수집
#    → 누적 댓글 7203개
#
# ▶️ [403/500] SK텔레콤서해킹 피해발생 가입자 유심정보 유출 악성코드 공격받아#SKT#
#    └ 댓글 0개 수집
#    → 누적 댓글 7203개
#
# ▶️ [404/500] 타로🔮SK텔레콤 유심정보해킹, 고객피해 없나요?
#    └ 댓글 1개 수집
#    → 누적 댓글 7204개
#
# ▶️ [405/500] SK텔레콤 유심 해킹 사태, 지금 당장 해야 할 조치
#    └ 댓글 0개 수집
#    → 누적 댓글 7204개
#
# ▶️ [406/500] 최태원, SKT 유심 해킹 관련 대국민 사과…사고 발생 19일만 #skt
#    └ 댓글 0개 수집
#    → 누적 댓글 7204개
#
# ▶️ [407/500] [긴급] SK텔레콤 유심 해킹...핸드폰만 털린 게 아니다 주민등록과 같
#    └ 댓글 0개 수집
#    → 누적 댓글 7204개
#
# ▶️ [408/500] SK텔레콤 유심 교체 빙자 스미싱 기승, 오로지 114만
#    └ 댓글 0개 수집
#    → 누적 댓글 7204개
#
# ▶️ [409/500] SK텔레콤 사용자 필수시청! 유심 해킹예방 대처법 #유심보호서비스 #유심
#    └ 댓글 0개 수집
#    → 누적 댓글 7204개
#
# ▶️ [410/500] 데일리모닝루틴 - 최태원
#    └ 댓글 0개 수집
#    → 누적 댓글 7204개
#
# ▶️ [411/500] SK텔레콤 해킹 공격으로 9.7GB 정보 유출, 유심 데이터 포함#SK텔
#    └ 댓글 0개 수집
#    → 누적 댓글 7204개
#
# ▶️ [412/500] SK 해킹 사고 이 후 부족한 유심 이런방법도 있습니다
#    └ 댓글 0개 수집
#    → 누적 댓글 7204개
#
# ▶️ [413/500] 당신 휴대폰도 위험합니다#sk텔레콤 #유심해킹#정보#핸드폰털림#정보유출
#    └ 댓글 0개 수집
#    → 누적 댓글 7204개
#
# ▶️ [414/500] skt 해킹 여파로 산업계 보안 비상 #보안 #sk텔레콤 #skt #해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 7204개
#
# ▶️ [415/500] SK텔레콤 유심 해킹 사고 대처를 하며 감사했다!! #보이스피싱 #SK텔
#    └ 댓글 3개 수집
#    → 누적 댓글 7207개
#
# ▶️ [416/500] SKT유심유출악용스미싱문자#shorts
#    └ 댓글 0개 수집
#    → 누적 댓글 7207개
#
# ▶️ [417/500] SK텔레콤 USIM해킹 조치4가지 #이슈#sk텔레콤
#    └ 댓글 0개 수집
#    → 누적 댓글 7207개
#
# ▶️ [418/500] SK텔레콤, 유심해킹 사건...대선 코 앞 예삿일 아니다
#    └ 댓글 3개 수집
#    → 누적 댓글 7210개
#
# ▶️ [419/500] SK텔레콤 유심해킹 보안주 후발주 외국인 순매수한 TOP4[공대원]
#    └ 댓글 0개 수집
#    → 누적 댓글 7210개
#
# ▶️ [420/500] 대한민국을 뒤흔든 역대급 해킹 사건들 top5 #유심 #개인정보유출 #S
#    └ 댓글 0개 수집
#    → 누적 댓글 7210개
#
# ▶️ [421/500] [자막] SKT 유영상 사장 위증죄로 고발하겠습니다 #유심 #해킹
#    └ 댓글 4개 수집
#    → 누적 댓글 7214개
#
# ▶️ [422/500] SK텔레콤 유심 해킹 파문…전국 대리점에 교체 대란
#    └ 댓글 0개 수집
#    → 누적 댓글 7214개
#
# ▶️ [423/500] KT가 유심 지원사격 나선다
#    └ 댓글 3개 수집
#    → 누적 댓글 7217개
#
# ▶️ [424/500] SKT유심해킹 안전한걸까? #skt #sk텔레콤 #유심 #해킹 #개인정보
#    └ 댓글 0개 수집
#    → 누적 댓글 7217개
#
# ▶️ [425/500] SK텔레콤 유심 해킹, 3년간 방치?! 이재명의 강력 비판!
#    └ 댓글 1개 수집
#    → 누적 댓글 7218개
#
# ▶️ [426/500] 국민 절반 쓰는 SK텔레콤, ‘심 스와핑’ 공포 확산 (20250423)
#    └ 댓글 2개 수집
#    → 누적 댓글 7220개
#
# ▶️ [427/500] [긴급] SK텔레콤 유심 해킹 의혹! 내 정보 지키는 2가지 방법 (유심
#    └ 댓글 0개 수집
#    → 누적 댓글 7220개
#
# ▶️ [428/500] SK 해킹 사건 웃긴 청문회 (완결편)
#    └ 댓글 1개 수집
#    → 누적 댓글 7221개
#
# ▶️ [429/500] SK텔레콤 유심(USIM)해킹 이렇게 대처하세요! - eSIM 셀프개통
#    └ 댓글 1개 수집
#    → 누적 댓글 7222개
#
# ▶️ [430/500] SK텔레콤 유심 해킹 사태, 피해자 235명이 1인당 100만원 손해배상
#    └ 댓글 0개 수집
#    → 누적 댓글 7222개
#
# ▶️ [431/500] SKT 유출 불안감 확산.. 해킹 의심신고도 속출
#    └ 댓글 0개 수집
#    → 누적 댓글 7222개
#
# ▶️ [432/500] SK텔레콤 유심 정보 유출 사태, 추가 악성코드 발견으로 논란 확대 #정
#    └ 댓글 0개 수집
#    → 누적 댓글 7222개
#
# ▶️ [433/500] skt 유심 해킹! 유심 무상 교체 하세요! #SK텔레콤 #유심해킹 #개
#    └ 댓글 0개 수집
#    → 누적 댓글 7222개
#
# ▶️ [434/500] 생활이슈 skt 유심해킹사태#SK해킹 #SKT해킹 #에스케이텔레콤해킹 #
#    └ 댓글 0개 수집
#    → 누적 댓글 7222개
#
# ▶️ [435/500] 피해 발생 100% 책임진다고?! SKT 피해 대응 총력 + 대기 기간에
#    └ 댓글 3개 수집
#    → 누적 댓글 7225개
#
# ▶️ [436/500] SK텔레콤 개인 정보 유출 사고 대처방법
#    └ 댓글 9개 수집
#    → 누적 댓글 7234개
#
# ▶️ [437/500] SK텔레콤 유심해킹 수혜주는 ?? 정치테마주 끝이 아니다 !! 앞으로 더
#    └ 댓글 1개 수집
#    → 누적 댓글 7235개
#
# ▶️ [438/500] SK 해킹 사고 이 후 무엇이 우선인가?
#    └ 댓글 1개 수집
#    → 누적 댓글 7236개
#
# ▶️ [439/500] SKT 유출 피해 최소화 방법 #sk텔레콤 #유심 정보 유출 #skt #
#    └ 댓글 0개 수집
#    → 누적 댓글 7236개
#
# ▶️ [440/500] SKT유심 해킹 사건 정리
#    └ 댓글 0개 수집
#    → 누적 댓글 7236개
#
# ▶️ [441/500] SK텔레콤 해킹도 모자라… 이번엔 알바몬?? #알바몬해킹 #SK텔레콤유출
#    └ 댓글 0개 수집
#    → 누적 댓글 7236개
#
# ▶️ [442/500] 이 두가지는 해두세요.#sk해킹 #kt #sk텔레콤 #유심보호서비스 #번
#    └ 댓글 1개 수집
#    → 누적 댓글 7237개
#
# ▶️ [443/500] SKT 결국 백기! 2300만 고객 대상 유심 무상 교체 애초에 관리를
#    └ 댓글 1개 수집
#    → 누적 댓글 7238개
#
# ▶️ [444/500] SK텔레콤, 유심 해킹 막는다! 무료 유심 교체 서비스 시작
#    └ 댓글 0개 수집
#    → 누적 댓글 7238개
#
# ▶️ [445/500] SK텔레콤 통신사 해킹 터졌다 유심 복제 막는 방법 초간단
#    └ 댓글 0개 수집
#    → 누적 댓글 7238개
#
# ▶️ [446/500] &quot;오픈런 했는데도&quot;.. SK텔레콤 유심 재고 부족에 혼
#    └ 댓글 2개 수집
#    → 누적 댓글 7240개
#
# ▶️ [447/500] SKT 유심 해킹 후폭풍…유심 보호 서비스 도입 &#39;불신 여전&#3
#    └ 댓글 2개 수집
#    → 누적 댓글 7242개
#
# ▶️ [448/500] SK텔레콤 유심교체에 관해 대리점(지점) 직원분과 전화통화.. SK 해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 7243개
#
# ▶️ [449/500] [자막] 유심 해킹 SK텔레콤 유영상 사장, 국회 청문회 증인 선서
#    └ 댓글 1개 수집
#    → 누적 댓글 7244개
#
# ▶️ [450/500] [최임화의 맞수다] [심층분석] SK텔레콤 유심 해킹 반사 수혜 받는 곳
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 7244개
#
# ▶️ [451/500] [긴급] SK텔레콤 유심 무료교체 시작! 개인정보 해킹 피해 막는 법 총
#    └ 댓글 2개 수집
#    → 누적 댓글 7246개
#
# ▶️ [452/500] 긴급 점검 SKT 유심 해킹 악성코드 관련 Tworld 접속 과부하 의심
#    └ 댓글 0개 수집
#    → 누적 댓글 7246개
#
# ▶️ [453/500] SK텔레콤 유심 해킹 사건! 지금 당장 확인해야 할 사항은? #sk텔레콤
#    └ 댓글 0개 수집
#    → 누적 댓글 7246개
#
# ▶️ [454/500] SK텔레콤 유심해킹수혜주 상한가 !! 계좌급등 !! 하락장이 올수있는 이
#    └ 댓글 1개 수집
#    → 누적 댓글 7247개
#
# ▶️ [455/500] SK텔레콤 해킹에 대한 대책은? 유심보호 서비스 가입만 하면 괜찮을까?
#    └ 댓글 0개 수집
#    → 누적 댓글 7247개
#
# ▶️ [456/500] 2025년 대한민국 난리 🚨 SKT 유심 해킹, 역대급 규모 데이터 유출
#    └ 댓글 0개 수집
#    → 누적 댓글 7247개
#
# ▶️ [457/500] SK텔레콤 유심 해킹! 고객정보 뚫렸다… 정부도 비상
#    └ 댓글 3개 수집
#    → 누적 댓글 7250개
#
# ▶️ [458/500] SKT 유심 해킹사고 찝찝해서 통신사 이동해야 할것 같아요 #뉴스 #해킹
#    └ 댓글 3개 수집
#    → 누적 댓글 7253개
#
# ▶️ [459/500] SK텔레콤 유심해킹 수혜주 ?? 꼬리내린 트럼프 미국증시 급등 !! 국내
#    └ 댓글 0개 수집
#    → 누적 댓글 7253개
#
# ▶️ [460/500] 유심 바꿔준다더니... 재고가 없다고요?  #SKT #유심 #해킹 #고객
#    └ 댓글 0개 수집
#    → 누적 댓글 7253개
#
# ▶️ [461/500] [속보]나도 모르는 사이에 5000만원 인출?! 결국 SKT 해킹사례 피
#    └ 댓글 2개 수집
#    → 누적 댓글 7255개
#
# ▶️ [462/500] 해킹보다 무서운 건 공포심… SKT 유심 아수라장 왜 벌어졌나? #SKT
#    └ 댓글 0개 수집
#    → 누적 댓글 7255개
#
# ▶️ [463/500] SK텔레콤 해킹 9.7GB 데이터 유출! 유심 정보 포함? | 최신 뉴스
#    └ 댓글 1개 수집
#    → 누적 댓글 7256개
#
# ▶️ [464/500] 황금연휴 김해공항 포화, SK텔레콤 유심해킹까지 | 특수학교 &#39;과
#    └ 댓글 0개 수집
#    → 누적 댓글 7256개
#
# ▶️ [465/500] SK텔레콤 유심 해킹과 반복적이고 상습적인 KT LG SK 통신3사 해킹
#    └ 댓글 2개 수집
#    → 누적 댓글 7258개
#
# ▶️ [466/500] &quot;SKT 해킹 역대급 파장! 🚨SK텔레콤 유심교체 대장주 엑스큐
#    └ 댓글 0개 수집
#    → 누적 댓글 7258개
#
# ▶️ [467/500] ​270만 쪽 유출된 SKT 해킹 사건의 전말  #SK텔레콤해킹 #개인정
#    └ 댓글 1개 수집
#    → 누적 댓글 7259개
#
# ▶️ [468/500] SK텔레콤, 유심 정보 유출 사고 발생…전 고객 대상 무상 교체 조치 시
#    └ 댓글 0개 수집
#    → 누적 댓글 7259개
#
# ▶️ [469/500] SK텔레콤 초대형 해킹사고! 가입자 대탈출 시작됐다 #sk텔레콤 #해킹사
#    └ 댓글 0개 수집
#    → 누적 댓글 7259개
#
# ▶️ [470/500] 오래전 예견된 SK텔레콤의 유심 해킹 부실 대응. 실망스러운 SKT의 대
#    └ 댓글 0개 수집
#    → 누적 댓글 7259개
#
# ▶️ [471/500] sk텔레콤 usim이 해킹 당했습니다. 약 2,300만명의 usim해킹.
#    └ 댓글 1개 수집
#    → 누적 댓글 7260개
#
# ▶️ [472/500] [주식]핵폰탄급 정보유출 지금 당장 확인하세요 (SK텔레콤 유심해킹)
#    └ 댓글 1개 수집
#    → 누적 댓글 7261개
#
# ▶️ [473/500] SKT 유심 유출, 해외 사례에서는 손해배상 어떻게 되었을까?
#    └ 댓글 0개 수집
#    → 누적 댓글 7261개
#
# ▶️ [474/500] SKT 유심 해킹, 손해배상 받을 수 있을까? ( SK텔레콤 사건 정리
#    └ 댓글 0개 수집
#    → 누적 댓글 7261개
#
# ▶️ [475/500] 🎬 [ SKT 해킹! 지금 당장 해야 할 3가지] #정보보안#shorts
#    └ 댓글 0개 수집
#    → 누적 댓글 7261개
#
# ▶️ [476/500] SK텔레콤 유심 해킹! 바꾸지 않으면 큰일난다고?
#    └ 댓글 9개 수집
#    → 누적 댓글 7270개
#
# ▶️ [477/500] SKT, 5월 유심 포맷 기술 적용 예고… 교체 없이 동일 효과 #이슈
#    └ 댓글 0개 수집
#    → 누적 댓글 7270개
#
# ▶️ [478/500] SK텔레콤 유심해킹! 알뜰폰사용자도 위험하다!
#    └ 댓글 0개 수집
#    → 누적 댓글 7270개
#
# ▶️ [479/500] SKT 유심해킹 대응방법3가지 #유심 #해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 7270개
#
# ▶️ [480/500] SK텔레콤 유심 해킹 사태 초비상!! 보안 관련주 급부상!!
#    └ 댓글 1개 수집
#    → 누적 댓글 7271개
#
# ▶️ [481/500] SK텔레콤 유심 해킹 사건! 문제점과 대처법 정말 쉽게 설명 드립니다.
#    └ 댓글 0개 수집
#    → 누적 댓글 7271개
#
# ▶️ [482/500] SK 텔레콤 유심 해킹 대란에 대리점 일주일 간 휴무…황당  / KNN
#    └ 댓글 0개 수집
#    → 누적 댓글 7271개
#
# ▶️ [483/500] SK텔레콤, 유심 해킹사고 인지 뒤 24시간 안에 보고하지 않았다 [경제
#    └ 댓글 0개 수집
#    → 누적 댓글 7271개
#
# ▶️ [484/500] SKT 유심 해킹에서 웹3로: 영지식 증명이 바꾸는 데이터 보안
#    └ 댓글 2개 수집
#    → 누적 댓글 7273개
#
# ▶️ [485/500] &quot;SK텔레콤, 유심 해킹 사태에도 외국인 매수 들어오는 이유는&
#    └ 댓글 0개 수집
#    → 누적 댓글 7273개
#
# ▶️ [486/500] SKT 해킹 사태 대비 모바일 보안 강화 수칙 #SKT #해킹 #유심
#    └ 댓글 0개 수집
#    → 누적 댓글 7273개
#
# ▶️ [487/500] SKT 유심 해킹! 지금 바로 해야 할 3가
#    └ 댓글 0개 수집
#    → 누적 댓글 7273개
#
# ▶️ [488/500] SK텔레콤 유심해킹사태! 해결할 수 있을까? 25.05.04 촬영
#    └ 댓글 0개 수집
#    → 누적 댓글 7273개
#
# ▶️ [489/500] [금융뉴스] 금융당국, SKT 유심 유출 점검회의···&quot;부정 인
#    └ 댓글 0개 수집
#    → 누적 댓글 7273개
#
# ▶️ [490/500] SK텔레콤 유심 해킹, 수혜주와 공략법
#    └ 댓글 1개 수집
#    → 누적 댓글 7274개
#
# ▶️ [491/500] SKT 추가 해킹 발견 #sk텔레콤 #코드 #네트워크 #유심 #보안 #뉴
#    └ 댓글 0개 수집
#    → 누적 댓글 7274개
#
# ▶️ [492/500] 유심 해킹 논란으로 안전불감증 보여준 SK텔레콤의 자회사 SK브로드밴드에
#    └ 댓글 2개 수집
#    → 누적 댓글 7276개
#
# ▶️ [493/500] SK텔레콤 유심해킹 사고 유심 무료 교체 어려움 | 행복한 아침 1603
#    └ 댓글 0개 수집
#    → 누적 댓글 7276개
#
# ▶️ [494/500] SK텔레콤 유심 무료 교체 시작 해킹 피해 100% 책임질 것
#    └ 댓글 0개 수집
#    → 누적 댓글 7276개
#
# ▶️ [495/500] #한솔인티큐브 #상한가 SK텔레콤 유심(USIM) 해킹 사태 여파로 정보
#    └ 댓글 0개 수집
#    → 누적 댓글 7276개
#
# ▶️ [496/500] 📱 SK텔레콤 역대급 해킹 사태! 당신의 유심정보가 털렸다?!
#    └ 댓글 0개 수집
#    → 누적 댓글 7276개
#
# ▶️ [497/500] &quot;유심 유출&quot; SK텔레콤 긴급 대응 시작!
#    └ 댓글 0개 수집
#    → 누적 댓글 7276개
#
# ▶️ [498/500] SKT 유심 해킹 사태로 인한 피해, SK텔레콤을 상대로 손해배상청구소송
#    └ 댓글 1개 수집
#    → 누적 댓글 7277개
#
# ▶️ [499/500] SK텔레콤 유심해킹 실화냐? 혼란을 틈타 보안주들 달린다!
#    └ 댓글 0개 수집
#    → 누적 댓글 7277개
#
# ▶️ [500/500] 가입자 정보가 유출됐다고?! SK 가입자 유심 정보 유출 #sk텔레콤 #
#    └ 댓글 2개 수집
#    → 누적 댓글 7279개
#
# 🎯 완료 — 영상 500건, 댓글 7279건 저장됨.

# %%
from googleapiclient.discovery import build
import pandas as pd
from datetime import datetime
import os
from time import sleep

# ---------------------------------------
# 1️⃣ 환경설정 및 API 초기화
# ---------------------------------------
API_KEY = "AIzaSyC7GTJAV5sXZfsJWQt2fgvzHrYx6i510bc"

def get_youtube():
    return build("youtube", "v3", developerKey=API_KEY)

youtube = get_youtube()

def safe_execute(request, retry=3):
    """API 요청 실행 (에러 발생 시 재시도 및 스킵)"""
    for attempt in range(retry):
        try:
            return request.execute()
        except Exception as e:
            msg = str(e)
            if "commentsDisabled" in msg:
                print("🚫 댓글 비활성화 영상 건너뜀")
                return {"items": []}
            elif "notFound" in msg:
                print("⚠️ 삭제/비공개 영상 건너뜀")
                return {"items": []}
            elif "quotaExceeded" in msg:
                print("❌ API 쿼터 초과 — 키 교체 필요")
                raise e
            else:
                print(f"❌ 오류 ({attempt+1}/{retry})회차 재시도 중: {e}")
                sleep(1)
    return {"items": []}


# ---------------------------------------
# 2️⃣ 영상 수집 함수 (최대 500건)
# ---------------------------------------
def collect_youtube_videos(query, start_date, end_date, max_total=500):
    all_videos = []
    next_page_token = None
    fetched = 0

    print(f"\n🚀 [{query}] 영상 수집 시작 ({start_date} ~ {end_date})")

    while fetched < max_total:
        req = youtube.search().list(
            part="snippet",
            q=query,
            type="video",
            order="viewCount",
            maxResults=50,
            publishedAfter=f"{start_date}T00:00:00Z",
            publishedBefore=f"{end_date}T23:59:59Z",
            pageToken=next_page_token
        )
        res = safe_execute(req)
        items = res.get("items", [])
        if not items:
            print("⚠️ 더 이상 영상 없음.")
            break

        for item in items:
            vid = item["id"]["videoId"]
            snippet = item["snippet"]
            all_videos.append({
                "videoId": vid,
                "title": snippet["title"],
                "description": snippet.get("description", ""),
                "channelTitle": snippet["channelTitle"],
                "channelId": snippet["channelId"],
                "publishedAt": snippet["publishedAt"],
                "url": f"https://www.youtube.com/watch?v={vid}"
            })

        fetched += len(items)
        print(f"✅ 누적 {fetched}건 수집 완료")

        next_page_token = res.get("nextPageToken")
        if not next_page_token:
            break

        sleep(0.3)  # API 요청 간 간격

    print(f"🎯 총 {len(all_videos)}건 영상 수집 완료\n")

    # ▶️ 영상 통계 및 채널 구독자 수 추가
    all_videos = enrich_video_stats(all_videos)
    return pd.DataFrame(all_videos)


# ---------------------------------------
# 3️⃣ 영상 통계 + 구독자 수
# ---------------------------------------
def enrich_video_stats(all_videos):
    for i in range(0, len(all_videos), 50):
        ids = [v["videoId"] for v in all_videos[i:i+50]]
        stats_req = youtube.videos().list(part="statistics,snippet", id=",".join(ids))
        stats_res = safe_execute(stats_req)
        stats_dict = {item["id"]: item for item in stats_res.get("items", [])}

        # 채널 ID 모으기
        channel_ids = []
        video_to_channel = {}
        for v in all_videos[i:i+50]:
            vid_stat = stats_dict.get(v["videoId"], {})
            cid = vid_stat.get("snippet", {}).get("channelId", "")
            video_to_channel[v["videoId"]] = cid
            if cid and cid not in channel_ids:
                channel_ids.append(cid)

        # 채널 구독자 수 조회
        channel_subs_dict = {}
        for j in range(0, len(channel_ids), 50):
            c_batch = channel_ids[j:j+50]
            channel_req = youtube.channels().list(part="statistics", id=",".join(c_batch))
            channel_res = safe_execute(channel_req)
            for item in channel_res.get("items", []):
                channel_subs_dict[item["id"]] = int(item["statistics"].get("subscriberCount", 0))

        # 통계 값 추가
        for v in all_videos[i:i+50]:
            stat = stats_dict.get(v["videoId"], {}).get("statistics", {})
            v["viewCount"] = int(stat.get("viewCount", 0))
            v["likeCount"] = int(stat.get("likeCount", 0))
            v["commentCount"] = int(stat.get("commentCount", 0))
            cid = video_to_channel.get(v["videoId"], "")
            v["subscriberCount"] = channel_subs_dict.get(cid, 0)

        sleep(0.3)
    return all_videos


# ---------------------------------------
# 4️⃣ 댓글 수집 
# ---------------------------------------
from time import sleep

def collect_all_comments(video_id):
    comments = []
    next_page_token = None

    while True:
        req = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            order="time",          # 최신순으로 가져와서 이후 정렬
            textFormat="plainText",
            pageToken=next_page_token
        )
        res = safe_execute(req)
        items = res.get("items", [])
        if not items:
            break

        for item in items:
            snippet = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "videoId": video_id,
                "author": snippet.get("authorDisplayName", ""),
                "text": snippet.get("textDisplay", ""),
                "publishedAt": snippet.get("publishedAt", "")
            })

        next_page_token = res.get("nextPageToken")
        if not next_page_token:
            break

        sleep(0.3)  # rate limit 방지

    # 오래된 순으로 정렬
    comments = sorted(comments, key=lambda x: x["publishedAt"])
    print(f"✅ 총 {len(comments)}개 댓글 수집 완료")
    return comments



# ---------------------------------------
# 5️⃣ 실행부
# ---------------------------------------
topic = {
    "name": "롯데카드_정보유출",
    "query": "(롯데 OR 롯데카드 OR Lotte OR Lottecard) AND (정보유출 OR 개인정보 OR 해킹 OR 보안사고)",
    "start": "2025-08-19",
    "end": "2025-10-16"
}

os.makedirs("YouTube_결과", exist_ok=True)

df_videos = collect_youtube_videos(topic["query"], topic["start"], topic["end"], max_total=500)
print(f"✅ 영상 {len(df_videos)}건 수집 완료")

# 💬 댓글 수집
all_comments = []
print(f"\n💬 총 {len(df_videos)}개 영상 댓글 수집 시작 (영상당 최대 100개)")

for idx, row in df_videos.iterrows():
    vid = row["videoId"]
    title = row["title"][:40]
    print(f"\n▶️ [{idx+1}/{len(df_videos)}] {title}")
    comments = collect_comments(vid, max_comments=100)
    print(f"   └ 댓글 {len(comments)}개 수집")
    all_comments.extend(comments)
    print(f"   → 누적 댓글 {len(all_comments)}개")

# 저장
ts = datetime.now().strftime("%Y%m%d_%H%M%S")
df_videos.to_excel(f"YouTube_결과/{topic['name']}_videos_{ts}.xlsx", index=False)
pd.DataFrame(all_comments).to_excel(f"YouTube_결과/{topic['name']}_comments_{ts}.xlsx", index=False)

print(f"\n🎯 완료 — 영상 {len(df_videos)}건, 댓글 {len(all_comments)}건 저장됨.")
# Out:
# 🚀 [(롯데 OR 롯데카드 OR Lotte OR Lottecard) AND (정보유출 OR 개인정보 OR 해킹 OR 보안사고)] 영상 수집 시작 (2025-08-19 ~ 2025-10-16)
# ✅ 누적 50건 수집 완료
# ✅ 누적 100건 수집 완료
# ✅ 누적 150건 수집 완료
# ✅ 누적 200건 수집 완료
# ✅ 누적 250건 수집 완료
# ✅ 누적 300건 수집 완료
# ✅ 누적 350건 수집 완료
# ✅ 누적 400건 수집 완료
# ✅ 누적 450건 수집 완료
# ✅ 누적 500건 수집 완료
# 🎯 총 500건 영상 수집 완료
#
# ✅ 영상 500건 수집 완료
#
# 💬 총 500개 영상 댓글 수집 시작 (영상당 최대 100개)
#
# ▶️ [1/500] [자막뉴스] 롯데카드 쓰는데, &#39;이 문자&#39; 받았다면 당장
#    └ 댓글 100개 수집
#    → 누적 댓글 100개
#
# ▶️ [2/500] 충격적 사실! 외국 해커에게 완전히 뚫린 한국정부기관! [코너별 다시보기
#    └ 댓글 100개 수집
#    → 누적 댓글 200개
#
# ▶️ [3/500] [단독] 롯데카드 해킹에서도…소름 돋는 공통점 찾았다 / SBS 8뉴스
#    └ 댓글 100개 수집
#    → 누적 댓글 300개
#
# ▶️ [4/500] [단독] &quot;LG U+, KT도 털렸다‥&#39;해킹 아냐&#39
#    └ 댓글 100개 수집
#    → 누적 댓글 400개
#
# ▶️ [5/500] [단독] 롯데카드, 부정사용 없다더니‥2차 &#39;피싱&#39; 공격
#    └ 댓글 100개 수집
#    → 누적 댓글 500개
#
# ▶️ [6/500] 결제 서버까지 공격 시도…&#39;960만 회원&#39; 롯데카드 발칵
#    └ 댓글 100개 수집
#    → 누적 댓글 600개
#
# ▶️ [7/500] [단독] 롯데카드 해킹 피해 눈덩이…피해 규모 예상보다 커/2025년 9
#    └ 댓글 100개 수집
#    → 누적 댓글 700개
#
# ▶️ [8/500] 롯데카드 해지하려면 &#39;숨바꼭질&#39;…뿔난 수천 명 &quot;
#    └ 댓글 100개 수집
#    → 누적 댓글 800개
#
# ▶️ [9/500] [단독] &quot;1만 명 유출 내역 바뀌었다‥롯데카드, 피해 규모 제
#    └ 댓글 100개 수집
#    → 누적 댓글 900개
#
# ▶️ [10/500] 롯데카드 해킹, SKT의 20배 수준…&quot;이게 보상이야?&quot
#    └ 댓글 100개 수집
#    → 누적 댓글 1000개
#
# ▶️ [11/500] 롯데카드, 해킹 17일 동안 몰랐다…&quot;전액 보상&quot; /
#    └ 댓글 100개 수집
#    → 누적 댓글 1100개
#
# ▶️ [12/500] 털린 사람 공통점에 &#39;헉 나도&#39;..급기야 한국서 좌표 찍었
#    └ 댓글 100개 수집
#    → 누적 댓글 1200개
#
# ▶️ [13/500] 롯데카드·KT 해킹은 시작일 뿐..&quot;국가AI위원회에 국정원 빠져
#    └ 댓글 100개 수집
#    → 누적 댓글 1300개
#
# ▶️ [14/500] &quot;SKT 20배&quot; 롯데카드 해킹사태…카드번호-CVC &
#    └ 댓글 100개 수집
#    → 누적 댓글 1400개
#
# ▶️ [15/500] [슬라생] 보안전문가도 큰 충격 “롯데카드 진짜 큰 일났다! 가장 이득보
#    └ 댓글 70개 수집
#    → 누적 댓글 1470개
#
# ▶️ [16/500] 롯데카드 해킹 싹다 털렸다! 카드번호 비밀번호까지.. 당장 &#39;이것
#    └ 댓글 54개 수집
#    → 누적 댓글 1524개
#
# ▶️ [17/500] 롯데카드 KT 도 해킹.. 삼성폰 쓴다면 이거 당장 끄세요! 내계좌 개인
#    └ 댓글 44개 수집
#    → 누적 댓글 1568개
#
# ▶️ [18/500] [이슈] 롯데카드 해킹 1.7GB 유출…“고객정보 포함 확인 중”/202
#    └ 댓글 47개 수집
#    → 누적 댓글 1615개
#
# ▶️ [19/500] &quot;어디까지 팔렸는지 몰라&quot; 1년 전 카드 정지했는데도
#    └ 댓글 79개 수집
#    → 누적 댓글 1694개
#
# ▶️ [20/500] 롯데카드 해킹의 황당한 원인은 업데이트. 기본만 지켰어도.
#    └ 댓글 100개 수집
#    → 누적 댓글 1794개
#
# ▶️ [21/500] 롯데카드에서 &#39;이거&#39; 받아도 당장 카드 해지하세요!! #롯
#    └ 댓글 99개 수집
#    → 누적 댓글 1893개
#
# ▶️ [22/500] 벌벌 떠는 28만 명…&#39;직접입력 결제 방식&#39; 때 위험 노출
#    └ 댓글 93개 수집
#    → 누적 댓글 1986개
#
# ▶️ [23/500] [단독] 부정 사용 직접 입증해야 하나요?‥롯데카드 &quot;부정 사용
#    └ 댓글 100개 수집
#    → 누적 댓글 2086개
#
# ▶️ [24/500] 롯데카드 역대급 해킹 피해!! 지금 꼭 해야 할 대응법!! + 좋은소식
#    └ 댓글 100개 수집
#    → 누적 댓글 2186개
#
# ▶️ [25/500] 롯데카드 해킹 &quot;첫 신고의 100배 유출, CVC도 포함&quo
#    └ 댓글 100개 수집
#    → 누적 댓글 2286개
#
# ▶️ [26/500] &#39;960만 회원&#39; 롯데카드 해킹 피해 눈덩이…곧 대국민 사
#    └ 댓글 100개 수집
#    → 누적 댓글 2386개
#
# ▶️ [27/500] &#39;297만명&#39; 회원정보 유출된 롯데카드! 혹시..나도?!
#    └ 댓글 76개 수집
#    → 누적 댓글 2462개
#
# ▶️ [28/500] 카드사까지 뚫렸다/960만 회원 롯데카드 해킹당해/중앙선관위는 진짜 안전
#    └ 댓글 100개 수집
#    → 누적 댓글 2562개
#
# ▶️ [29/500] &#39;297만 명 유출&#39; 롯데카드…&quot;재발급·비밀번호
#    └ 댓글 100개 수집
#    → 누적 댓글 2662개
#
# ▶️ [30/500] 롯데카드 대표 숨멎게 만든 이해민 의원 &quot;해킹은 이렇게 하는 겁
#    └ 댓글 47개 수집
#    → 누적 댓글 2709개
#
# ▶️ [31/500] &#39;롯데카드사&#39; 해킹 사고…유출 규모 얼마나? #JTBC #
#    └ 댓글 67개 수집
#    → 누적 댓글 2776개
#
# ▶️ [32/500] 정보보안 전문가 김승주 교수의 해킹 사태 완벽 분석
#    └ 댓글 84개 수집
#    → 누적 댓글 2860개
#
# ▶️ [33/500] 커지는 2차 피해 공포‥롯데카드 &quot;연관성 확인되는 한 전액 보상
#    └ 댓글 100개 수집
#    → 누적 댓글 2960개
#
# ▶️ [34/500] 돈 값하는 롯데카드의 해킹 쉴드. ISMS-P의 문제점
#    └ 댓글 82개 수집
#    → 누적 댓글 3042개
#
# ▶️ [35/500] &quot;롯데카드, 수백만 명 고객 정보 유출&quot;…18일 보상안
#    └ 댓글 100개 수집
#    → 누적 댓글 3142개
#
# ▶️ [36/500] 국회 과방위, 오늘 `통신·금융 해킹사태` 청문회 - [끝까지LIVE]
#    └ 댓글 2개 수집
#    → 누적 댓글 3144개
#
# ▶️ [37/500] 롯데카드 CVC번호, 서버에 암호로 저장됐더라면~ / YTN
#    └ 댓글 12개 수집
#    → 누적 댓글 3156개
#
# ▶️ [38/500] 이게 보상이야? 롯데카드 보상안 논란
#    └ 댓글 24개 수집
#    → 누적 댓글 3180개
#
# ▶️ [39/500] [LIVE] &#39;해킹 사고&#39; 롯데카드 대국민 사과 생중계/2
#    └ 댓글 5개 수집
#    → 누적 댓글 3185개
#
# ▶️ [40/500] 롯데카드 해킹 유출 6천 명 늘어‥조좌진 &quot;입증되면 보상한다&q
#    └ 댓글 100개 수집
#    → 누적 댓글 3285개
#
# ▶️ [41/500] 297만 명 고객 정보 유출에 고개 숙인 롯데카드 #롯데카드 #short
#    └ 댓글 16개 수집
#    → 누적 댓글 3301개
#
# ▶️ [42/500] 롯데카드 해킹‥피해 규모 예상 웃돌 듯 (2025.09.17/12MBC뉴
#    └ 댓글 88개 수집
#    → 누적 댓글 3389개
#
# ▶️ [43/500] [🔴속보] 롯데카드 해킹 눈덩이…&#39;수백만명 정보 유출&#39; 피
#    └ 댓글 18개 수집
#    → 누적 댓글 3407개
#
# ▶️ [44/500] 17일간 까맣게 몰랐다...&#39;회원 960만 명&#39; 롯데카드,
#    └ 댓글 24개 수집
#    → 누적 댓글 3431개
#
# ▶️ [45/500] &quot;예상보다 훨씬 심각&quot; 롯데카드 어쩌나 #shorts
#    └ 댓글 26개 수집
#    → 누적 댓글 3457개
#
# ▶️ [46/500] (경제한스푼)*세로모드* 롯데카드 해킹, 보안 업계 &quot;역대급 침
#    └ 댓글 2개 수집
#    → 누적 댓글 3459개
#
# ▶️ [47/500] &quot;피해 알려진 것보다 심각한 수준&quot;...롯데카드 해킹
#    └ 댓글 40개 수집
#    → 누적 댓글 3499개
#
# ▶️ [48/500] 이번 롯데카드 해킹사태가 심각한 이유 #shorts
#    └ 댓글 26개 수집
#    → 누적 댓글 3525개
#
# ▶️ [49/500] 롯데카드 &#39;해킹&#39;으로 레전드 갱신한 디시인.. 대박이네 ㅋ
#    └ 댓글 4개 수집
#    → 누적 댓글 3529개
#
# ▶️ [50/500] 회원이 몇 명인데…&quot;유출 흔적&quot; 롯데카드 &#39;발칵
#    └ 댓글 23개 수집
#    → 누적 댓글 3552개
#
# ▶️ [51/500] [직설] 롯데카드 1호 고객도 아무 연락 못 받았다 #문송천
#    └ 댓글 4개 수집
#    → 누적 댓글 3556개
#
# ▶️ [52/500] 롯데자이언츠 35홈런 거포 패트릭 위즈덤 영입 임박! 레이예스 결국 퇴출
#    └ 댓글 56개 수집
#    → 누적 댓글 3612개
#
# ▶️ [53/500] 롯데카드 유출규모 &#39;297만명&#39;…&quot;28만명은 CV
#    └ 댓글 10개 수집
#    → 누적 댓글 3622개
#
# ▶️ [54/500] &#39;롯데카드&#39; 297만 명 정보 털렸다‥뒤늦은 사과 &quo
#    └ 댓글 100개 수집
#    → 누적 댓글 3722개
#
# ▶️ [55/500] 롯데카드 297만 명 해킹‥&quot;피해액 전액 보상&quot; (20
#    └ 댓글 60개 수집
#    → 누적 댓글 3782개
#
# ▶️ [56/500] &quot;예상보다 훨씬 심각&quot;…&#39;960만 회원&#39;
#    └ 댓글 29개 수집
#    → 누적 댓글 3811개
#
# ▶️ [57/500] &quot;브랜드 이름에 먹칠&quot; 롯데카드 롯데그룹에 사과…무슨
#    └ 댓글 24개 수집
#    → 누적 댓글 3835개
#
# ▶️ [58/500] 967만 회원 롯데카드도 해킹 피해‥사고 발생 17일 후에야 알았다 #S
#    └ 댓글 30개 수집
#    → 누적 댓글 3865개
#
# ▶️ [59/500] [🔴 LIVE 과방위] 대규모 해킹사고(KT•롯데카드) 관련 청문회 l
#    └ 댓글 0개 수집
#    → 누적 댓글 3865개
#
# ▶️ [60/500] 최고 보안 인증에도 뚫린 롯데카드...&quot;인증 무용?&quot;
#    └ 댓글 31개 수집
#    → 누적 댓글 3896개
#
# ▶️ [61/500] [자막뉴스] 연회비 면제해주겠다 하지만...롯데카드 유출범위 보니 &#3
#    └ 댓글 30개 수집
#    → 누적 댓글 3926개
#
# ▶️ [62/500] 금융위 &quot;50억·영업정지...6개월&quot;...롯데카드 당장
#    └ 댓글 6개 수집
#    → 누적 댓글 3932개
#
# ▶️ [63/500] 롯데카드 &quot;297만명 회원 정보 유출…전액 보상 방침&quot;
#    └ 댓글 2개 수집
#    → 누적 댓글 3934개
#
# ▶️ [64/500] [이슈] 롯데카드 &quot;297만 명 정보 유출…28만 명 부정사용
#    └ 댓글 18개 수집
#    → 누적 댓글 3952개
#
# ▶️ [65/500] 롯데카드 해킹 사고, 297만 명 고객정보 유출｜어떻게 보시나요?
#    └ 댓글 31개 수집
#    → 누적 댓글 3983개
#
# ▶️ [66/500] [돌직구 강력반]롯데카드 해킹 피해 ‘눈덩이’…최종 안전장치까지 털렸다
#    └ 댓글 46개 수집
#    → 누적 댓글 4029개
#
# ▶️ [67/500] [🔴생중계] 국회 과방위, &#39;통신·금융 해킹사태&#39; 청문회
#    └ 댓글 4개 수집
#    → 누적 댓글 4033개
#
# ▶️ [68/500] [핫라인] 롯데카드, 해킹 사태 관련 대국민 사과···&quot;고객에게
#    └ 댓글 44개 수집
#    → 누적 댓글 4077개
#
# ▶️ [69/500] KT·롯데카드 해킹 사태 단체소송 가능성…정부 &quot;징벌적 과징금
#    └ 댓글 34개 수집
#    → 누적 댓글 4111개
#
# ▶️ [70/500] 967만 회원 롯데카드도 해킹 피해‥사고 발생 17일 후에야 알았다 (2
#    └ 댓글 60개 수집
#    → 누적 댓글 4171개
#
# ▶️ [71/500] 롯데카드 &quot;해킹으로 297만 명 회원 정보 유출...피해 전액
#    └ 댓글 57개 수집
#    → 누적 댓글 4228개
#
# ▶️ [72/500] [다시보기] 고개 숙인 롯데카드 &quot;297만 명 개인정보 유출…피
#    └ 댓글 11개 수집
#    → 누적 댓글 4239개
#
# ▶️ [73/500] 결국 롯데카드도 해킹... SKT 20배 수준이라고?
#    └ 댓글 28개 수집
#    → 누적 댓글 4267개
#
# ▶️ [74/500] [단독] &#39;롯데카드사&#39; 해킹 사고…금융위 측 &quot;유
#    └ 댓글 25개 수집
#    → 누적 댓글 4292개
#
# ▶️ [75/500] 🔴[LIVE] 이동통신 3사·롯데카드 대상...&#39;통신·금융 해킹사
#    └ 댓글 0개 수집
#    → 누적 댓글 4292개
#
# ▶️ [76/500] &#39;회원 960여만 명&#39; 롯데카드 해킹 사고...&quot;
#    └ 댓글 12개 수집
#    → 누적 댓글 4304개
#
# ▶️ [77/500] 롯데카드 해킹 충격…2차 피해 우려에 업계 비상
#    └ 댓글 9개 수집
#    → 누적 댓글 4313개
#
# ▶️ [78/500] 롯데카드 3백만 명 정보 유출…28만 명은 비번도 털려 [9시 뉴스] /
#    └ 댓글 17개 수집
#    → 누적 댓글 4330개
#
# ▶️ [79/500] [뉴스쏙] 부정 결제 피해 신고 떴다…롯데카드 해킹 긴급 조사했더니｜금감
#    └ 댓글 8개 수집
#    → 누적 댓글 4338개
#
# ▶️ [80/500] 롯데카드 해킹 유출 6천 명 늘어‥조좌진 &quot;입증되면 보상한다&q
#    └ 댓글 15개 수집
#    → 누적 댓글 4353개
#
# ▶️ [81/500] 대규모 해킹 사태! 조국혁신당 이해민 의원 &quot;사임하실 건가?&q
#    └ 댓글 2개 수집
#    → 누적 댓글 4355개
#
# ▶️ [82/500] 롯데카드 &quot;297만명 회원 정보 유출…전액 보상 방침&quot;
#    └ 댓글 27개 수집
#    → 누적 댓글 4382개
#
# ▶️ [83/500] [한눈에 이슈] 결국 대국민 사과한 롯데카드…CVC 번호 등 피해 규모가
#    └ 댓글 8개 수집
#    → 누적 댓글 4390개
#
# ▶️ [84/500] [목돈연구소] 967만 명 회원 롯데카드, 해킹 정황 확인 / 금 선물,
#    └ 댓글 3개 수집
#    → 누적 댓글 4393개
#
# ▶️ [85/500] &quot;이게 나라입니까?&quot;  #해킹 #사이버대한민국 #대한민
#    └ 댓글 16개 수집
#    → 누적 댓글 4409개
#
# ▶️ [86/500] 저도 롯데카드 고객입니다. 집단소송 합니다.
#    └ 댓글 16개 수집
#    → 누적 댓글 4425개
#
# ▶️ [87/500] &quot;SKT 20배&quot; 롯데카드 해킹사태…카드번호-CVC &
#    └ 댓글 5개 수집
#    → 누적 댓글 4430개
#
# ▶️ [88/500] [🔴 LIVE 과방위] 대규모 해킹사고(KT•롯데카드) 관련 청문회 l
#    └ 댓글 2개 수집
#    → 누적 댓글 4432개
#
# ▶️ [89/500] &#39;대규모 해킹&#39; 롯데카드 뒤에 또 MBK?…불거지는 책임론
#    └ 댓글 13개 수집
#    → 누적 댓글 4445개
#
# ▶️ [90/500] [목돈연구소] 롯데카드 해킹규모, 첫 신고의 100배 / 삼성, 5년간
#    └ 댓글 2개 수집
#    → 누적 댓글 4447개
#
# ▶️ [91/500] 🆔해커에게 무릎을 꿇은 대한민국 통신망 🆔 #KT #롯데카드 #해킹 #이
#    └ 댓글 2개 수집
#    → 누적 댓글 4449개
#
# ▶️ [92/500] 롯데카드 해킹 뚫리고도 17일간 몰랐다 (자막뉴스) / SBS
#    └ 댓글 12개 수집
#    → 누적 댓글 4461개
#
# ▶️ [93/500] [신통방통] 롯데카드, 해킹 사고로 고객 정보 대량 유출···28만 명은
#    └ 댓글 20개 수집
#    → 누적 댓글 4481개
#
# ▶️ [94/500] 고객정보 가치를 너무 적게 생각하는 롯데카드(?) 이해민 일침에 &#39
#    └ 댓글 8개 수집
#    → 누적 댓글 4489개
#
# ▶️ [95/500] 🔴“있었는데요, 더 늘었습니다” 다시 접속하니 늘어난 유출정보 내역 |
#    └ 댓글 5개 수집
#    → 누적 댓글 4494개
#
# ▶️ [96/500] &quot;혹시 내 비번도?&quot; 롯데카드 해킹 피해 확인, 이렇게
#    └ 댓글 6개 수집
#    → 누적 댓글 4500개
#
# ▶️ [97/500] 롯데카드 곧 대국민 사과
#    └ 댓글 3개 수집
#    → 누적 댓글 4503개
#
# ▶️ [98/500] &quot;100만 명대 정보 유출&quot; 롯데카드 오늘 대국민사과
#    └ 댓글 38개 수집
#    → 누적 댓글 4541개
#
# ▶️ [99/500] 롯데카드 297만 명 정보 유출…&quot;초기 발표 100배 넘어&qu
#    └ 댓글 11개 수집
#    → 누적 댓글 4552개
#
# ▶️ [100/500] 롯데카드 해킹 사고‥&quot;고객정보 유출 여부 확인 중&quot; (
#    └ 댓글 14개 수집
#    → 누적 댓글 4566개
#
# ▶️ [101/500] &#39;롯데카드 해킹&#39; 피해자 100만 명? | 이슈픽 zip
#    └ 댓글 7개 수집
#    → 누적 댓글 4573개
#
# ▶️ [102/500] &quot;롯데카드 버리세요&quot;  #롯데카드해킹사고 #해외결제서비
#    └ 댓글 4개 수집
#    → 누적 댓글 4577개
#
# ▶️ [103/500] 롯데카드 297만명 유출에도 과징금 상한은 고작 &#39;50억&#39;
#    └ 댓글 1개 수집
#    → 누적 댓글 4578개
#
# ▶️ [104/500] &#39;960만 회원&#39; 롯데카드 해킹…&quot;자료 유출 시도
#    └ 댓글 11개 수집
#    → 누적 댓글 4589개
#
# ▶️ [105/500] SKT·롯데카드 해킹 후폭풍… 정부, 개인정보 유출 차단 총력
#    └ 댓글 8개 수집
#    → 누적 댓글 4597개
#
# ▶️ [106/500] &#39;해킹&#39; 롯데카드 CVC까지 털렸다…금융당국 &quot;정
#    └ 댓글 14개 수집
#    → 누적 댓글 4611개
#
# ▶️ [107/500] 롯데카드 해킹사건과 모두의 정신건강
#    └ 댓글 24개 수집
#    → 누적 댓글 4635개
#
# ▶️ [108/500] 960만 회원 롯데카드, 해킹 피해 더 커지나…대주주 MBK 책임론도｜지
#    └ 댓글 3개 수집
#    → 누적 댓글 4638개
#
# ▶️ [109/500] 또 해킹이야? 롯데카드 해킹 사고났다.. 한국인 개인정보가 공공재야? #
#    └ 댓글 12개 수집
#    → 누적 댓글 4650개
#
# ▶️ [110/500] [뉴스나우] KT·롯데카드 연이은 해킹...늘어나는 피해 속 대책은? /
#    └ 댓글 5개 수집
#    → 누적 댓글 4655개
#
# ▶️ [111/500] [자막뉴스] 고객 민감정보까지...롯데카드 &quot;모든 가능성 열어둔
#    └ 댓글 6개 수집
#    → 누적 댓글 4661개
#
# ▶️ [112/500] 롯데, FA 불펜 영입 임박! 조상우·김범수·이영하 삼파전 속에서 구단
#    └ 댓글 6개 수집
#    → 누적 댓글 4667개
#
# ▶️ [113/500] 롯데카드 해킹 피해 눈덩이…금융범죄 우려까지 / 연합뉴스TV (Yonha
#    └ 댓글 5개 수집
#    → 누적 댓글 4672개
#
# ▶️ [114/500] 롯데카드 고객 297만 명 정보 유출…2차 피해 가능성은? [아침에 이슈
#    └ 댓글 9개 수집
#    → 누적 댓글 4681개
#
# ▶️ [115/500] [뉴스쏙] 롯데카드 해킹 데이터, 첫 신고의 100배…200GB 유출 &
#    └ 댓글 3개 수집
#    → 누적 댓글 4684개
#
# ▶️ [116/500] 결국 롯데카드도 털렸다ㄷㄷ
#    └ 댓글 6개 수집
#    → 누적 댓글 4690개
#
# ▶️ [117/500] 롯데카드 297만 명 정보 유출…&quot;초기 발표 100배 넘어&qu
#    └ 댓글 16개 수집
#    → 누적 댓글 4706개
#
# ▶️ [118/500] 생각보다 심각한 롯데카드 해킹 #shorts / YTN
#    └ 댓글 6개 수집
#    → 누적 댓글 4712개
#
# ▶️ [119/500] 롯데카드의 충격적인 보안 실태 / 비디오머그 / 귀에빡!종원 #Short
#    └ 댓글 8개 수집
#    → 누적 댓글 4720개
#
# ▶️ [120/500] 롯데카드 &quot;해킹 사고로 297만명 회원 정보 유출 확인&quot
#    └ 댓글 24개 수집
#    → 누적 댓글 4744개
#
# ▶️ [121/500] 롯데카드 해킹, 297만 명 털렸다…달랑 무이자 할부? [프레스룸 경제라
#    └ 댓글 10개 수집
#    → 누적 댓글 4754개
#
# ▶️ [122/500] &quot;카드번호·CVC까지 털렸다&quot;…롯데카드 해킹 대참사
#    └ 댓글 26개 수집
#    → 누적 댓글 4780개
#
# ▶️ [123/500] “롯데카드 해킹으로 카드번호 유출”…피해 규모 내일(18일) 발표 [9시
#    └ 댓글 8개 수집
#    → 누적 댓글 4788개
#
# ▶️ [124/500] 롯데카드 &quot;해킹으로 297만 명 정보 유출...28만 명 부정
#    └ 댓글 13개 수집
#    → 누적 댓글 4801개
#
# ▶️ [125/500] 예상보다 100배 넘는다…롯데카드 해킹 피해 눈덩이 / SBS
#    └ 댓글 4개 수집
#    → 누적 댓글 4805개
#
# ▶️ [126/500] 롯데카드서 해킹 사고 발생…&quot;고객 정보 유출 여부 확인 중&qu
#    └ 댓글 10개 수집
#    → 누적 댓글 4815개
#
# ▶️ [127/500] 롯데카드 &quot;28만 명 CVC까지 유출, 부정사용 가능성...전액
#    └ 댓글 10개 수집
#    → 누적 댓글 4825개
#
# ▶️ [128/500] [🔴속보] 롯데카드서 대규모 해킹 사고 &#39;1.7GB 분량&#39;
#    └ 댓글 0개 수집
#    → 누적 댓글 4825개
#
# ▶️ [129/500] &quot;대국민 사과로 끝날 일인가?&quot; 롯데카드 해킹 파장 어
#    └ 댓글 12개 수집
#    → 누적 댓글 4837개
#
# ▶️ [130/500] [LIVE] &#39;대규모 해킹 사태&#39; 롯데카드, 대국민 사과
#    └ 댓글 1개 수집
#    → 누적 댓글 4838개
#
# ▶️ [131/500] 롯데카드 해킹 피해 카드사가 전액 보상한다!
#    └ 댓글 1개 수집
#    → 누적 댓글 4839개
#
# ▶️ [132/500] 롯데카드 해킹 피해 눈덩이…최대 수백만명 달할 수도 / 연합뉴스TV (Y
#    └ 댓글 2개 수집
#    → 누적 댓글 4841개
#
# ▶️ [133/500] 롯데카드, 해킹 피해 눈덩이…곧 대국민 사과
#    └ 댓글 4개 수집
#    → 누적 댓글 4845개
#
# ▶️ [134/500] 롯데카드 해킹 피해 눈덩이…최대 수백만명 달할 수도 / 연합뉴스TV (Y
#    └ 댓글 3개 수집
#    → 누적 댓글 4848개
#
# ▶️ [135/500] [다시보기] &quot;해킹 사고로 297만명 회원 정보 유출 확인&qu
#    └ 댓글 7개 수집
#    → 누적 댓글 4855개
#
# ▶️ [136/500] 롯데카드 해킹 17일 ‘깜깜이’…“고객 피해 전액 배상” [9시 뉴스]
#    └ 댓글 7개 수집
#    → 누적 댓글 4862개
#
# ▶️ [137/500] &#39;960만 회원&#39; 롯데카드, 17일 늦게 해킹 파악…&qu
#    └ 댓글 6개 수집
#    → 누적 댓글 4868개
#
# ▶️ [138/500] [자막뉴스] CVC까지 샌 롯데카드...알려진 것의 &#39;100배&#
#    └ 댓글 4개 수집
#    → 누적 댓글 4872개
#
# ▶️ [139/500] 🔴&#39;960만 회원&#39; 롯데카드 해킹.. 연이은 금융권 해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 4872개
#
# ▶️ [140/500] &quot;100만명 밀렸는데 재발급 언제 되는 겁니까?&quot;...
#    └ 댓글 0개 수집
#    → 누적 댓글 4872개
#
# ▶️ [141/500] 서버 뚫린 KT, &#39;복제폰&#39; 우려까지…롯데카드 해킹 피해자
#    └ 댓글 9개 수집
#    → 누적 댓글 4881개
#
# ▶️ [142/500] 🔴[LIVE][속보] 롯데카드 &quot;정보 유출 고객에 연말까지 무이
#    └ 댓글 4개 수집
#    → 누적 댓글 4885개
#
# ▶️ [143/500] [단독] “롯데카드 해킹으로 카드번호 유출”…조사 결과 내일(18일) 발
#    └ 댓글 6개 수집
#    → 누적 댓글 4891개
#
# ▶️ [144/500] &#39;해킹 사고&#39; 롯데카드 &quot;24시간 상담 운영&qu
#    └ 댓글 2개 수집
#    → 누적 댓글 4893개
#
# ▶️ [145/500] [뉴스잇] 롯데카드, 297만명 정보유출…KT 추가 피해 확인 / 연합뉴
#    └ 댓글 5개 수집
#    → 누적 댓글 4898개
#
# ▶️ [146/500] &#39;해킹 사태&#39; 롯데카드, 카드번호도 털렸다…오늘 대국민 사
#    └ 댓글 16개 수집
#    → 누적 댓글 4914개
#
# ▶️ [147/500] 🔴LIVE 롯데카드 조좌진 대표 대국민 사과 현장, &#39;960만 회
#    └ 댓글 1개 수집
#    → 누적 댓글 4915개
#
# ▶️ [148/500] 롯데카드 정보 유출 297만 명…28만 명에 내년 연회비 면제 / 채널A
#    └ 댓글 11개 수집
#    → 누적 댓글 4926개
#
# ▶️ [149/500] [단독] 롯데카드 해킹도?…&quot;중국 해킹조직 &#39;달빛&#39
#    └ 댓글 23개 수집
#    → 누적 댓글 4949개
#
# ▶️ [150/500] KT·롯데카드 연이은 해킹…커지는 불안 속 대책은? [세상만사] #kt
#    └ 댓글 21개 수집
#    → 누적 댓글 4970개
#
# ▶️ [151/500] [🔴라이브를 켜라] 과방위, KT·롯데카드 해킹 청문회 24일 개최 /
#    └ 댓글 4개 수집
#    → 누적 댓글 4974개
#
# ▶️ [152/500] 롯데카드 해킹 피해자 100만 명 추정…내 정보도? / 채널A / 뉴스A
#    └ 댓글 9개 수집
#    → 누적 댓글 4983개
#
# ▶️ [153/500] 해커놀이터가 되어버린 대한민국 보아
#    └ 댓글 3개 수집
#    → 누적 댓글 4986개
#
# ▶️ [154/500] CVC 번호까지 털렸다…롯데카드, 고객 297만 명 정보 유출 / 채널A
#    └ 댓글 22개 수집
#    → 누적 댓글 5008개
#
# ▶️ [155/500] &quot;비번까지 유출됐는데&quot; 롯데카드 피해자들 분통…집단소송
#    └ 댓글 10개 수집
#    → 누적 댓글 5018개
#
# ▶️ [156/500] 경찰, &#39;롯데카드 해킹&#39; 유출정보 악용 가능성도 수사 /
#    └ 댓글 9개 수집
#    → 누적 댓글 5027개
#
# ▶️ [157/500] &quot;백만 명 정보 털렸다&quot;…롯데카드 충격 해킹 보상은
#    └ 댓글 6개 수집
#    → 누적 댓글 5033개
#
# ▶️ [158/500] [신통방통] &quot;피해자 수백만 될 수도&quot;···롯데카드 해
#    └ 댓글 7개 수집
#    → 누적 댓글 5040개
#
# ▶️ [159/500] 롯데카드서 해킹 사고 발생…&quot;고객 정보 유출 여부 확인 중&qu
#    └ 댓글 2개 수집
#    → 누적 댓글 5042개
#
# ▶️ [160/500] 롯데카드 해킹 사고 #Shorts (MBC뉴스)
#    └ 댓글 4개 수집
#    → 누적 댓글 5046개
#
# ▶️ [161/500] 롯데카드 조좌진 대표 &quot;회원정보 유출규모 297만명, 송구……2
#    └ 댓글 3개 수집
#    → 누적 댓글 5049개
#
# ▶️ [162/500] 롯데카드 해킹 17일간 몰랐다...금감원 &quot;피해 시 전액 보상&
#    └ 댓글 5개 수집
#    → 누적 댓글 5054개
#
# ▶️ [163/500] 경찰, &#39;롯데카드 해킹&#39; 유출정보 악용 가능성도 수사 /
#    └ 댓글 3개 수집
#    → 누적 댓글 5057개
#
# ▶️ [164/500] [자막뉴스] 허점 들통난 보안 인증... 롯데카드 해명에도 &#39;찜찜
#    └ 댓글 7개 수집
#    → 누적 댓글 5064개
#
# ▶️ [165/500] 롯데카드 kt 해킹은 빙산의 일각, 정부 시스템 전체가 이미 해킹되었는데
#    └ 댓글 19개 수집
#    → 누적 댓글 5083개
#
# ▶️ [166/500] 회원 960만 명 롯데카드 해킹 공격…&quot;정보 유출 확인 중&qu
#    └ 댓글 9개 수집
#    → 누적 댓글 5092개
#
# ▶️ [167/500] [이슈] &#39;해킹 사태&#39; 롯데카드, 카드번호도 털렸다…오늘
#    └ 댓글 0개 수집
#    → 누적 댓글 5092개
#
# ▶️ [168/500] [빠른뉴스 쨉] 롯데카드 297만 명 개인 정보 털렸다... 보상으로 &
#    └ 댓글 1개 수집
#    → 누적 댓글 5093개
#
# ▶️ [169/500] 롯데카드 해킹 피해 눈덩이…최대 수백만명 달할 수도 / 연합뉴스TV (Y
#    └ 댓글 2개 수집
#    → 누적 댓글 5095개
#
# ▶️ [170/500] 롯데카드 해킹! 297만 명 정보 중국에? 🚨 분노 폭발!#롯데카드해킹#
#    └ 댓글 5개 수집
#    → 누적 댓글 5100개
#
# ▶️ [171/500] 롯데카드 해킹 사고‥&quot;고객정보 유출 여부 확인 중&quot; (
#    └ 댓글 8개 수집
#    → 누적 댓글 5108개
#
# ▶️ [172/500] “롯데카드 해킹으로 카드번호 유출”…피해 규모 오늘(19일) 발표 / K
#    └ 댓글 5개 수집
#    → 누적 댓글 5113개
#
# ▶️ [173/500] 사과만 하니까 자꾸 해킹 당하는거 같은데 답답하다 정말
#    └ 댓글 4개 수집
#    → 누적 댓글 5117개
#
# ▶️ [174/500] 🔴[LIVE] &#39;롯데카드 해킹·홈플러스 사태&#39; MBK 정조
#    └ 댓글 0개 수집
#    → 누적 댓글 5117개
#
# ▶️ [175/500] 롯데카드, 카드번호와 주민번호 암호화 안 된 것도 털렸다
#    └ 댓글 4개 수집
#    → 누적 댓글 5121개
#
# ▶️ [176/500] 롯데카드 해킹, 고객정보 수백GB 유출? 대통령 긴급 지시!
#    └ 댓글 3개 수집
#    → 누적 댓글 5124개
#
# ▶️ [177/500] [집중진단] SKT·KT 이어 롯데카드까지... 해킹사태 대책은?
#    └ 댓글 7개 수집
#    → 누적 댓글 5131개
#
# ▶️ [178/500] “롯데카드 해킹으로 카드번호 유출”…피해 규모 내일(18일) 발표 / K
#    └ 댓글 6개 수집
#    → 누적 댓글 5137개
#
# ▶️ [179/500] &quot;언제 카드 털렸습니까?&quot; 롯데카드도 논란 / #채널A
#    └ 댓글 2개 수집
#    → 누적 댓글 5139개
#
# ▶️ [180/500] 롯데카드 해킹 사고...&quot;고객 정보 유출 확인 중&quot; /
#    └ 댓글 5개 수집
#    → 누적 댓글 5144개
#
# ▶️ [181/500] 롯데카드 대표 &quot;재발급 주말까지 대부분 해소...회사 책임 커&
#    └ 댓글 0개 수집
#    → 누적 댓글 5144개
#
# ▶️ [182/500] 롯데카드 &quot;해킹 사고로 297만명 고객정보 유출…200GB 분량
#    └ 댓글 2개 수집
#    → 누적 댓글 5146개
#
# ▶️ [183/500] 롯데카드 해킹 사태…원인과 대응책은? [따져보니] [뉴스9]
#    └ 댓글 3개 수집
#    → 누적 댓글 5149개
#
# ▶️ [184/500] 롯데카드 297만명 고객 정보 유출...원인은 2017년 보안 패치 누락
#    └ 댓글 4개 수집
#    → 누적 댓글 5153개
#
# ▶️ [185/500] &#39;해킹 사고&#39; 롯데카드 &quot;피해 전액 보장 약속&q
#    └ 댓글 1개 수집
#    → 누적 댓글 5154개
#
# ▶️ [186/500] SKT, 롯데카드 다음 비플페이 해킹 사태 속 &#39;보안 방패&#39
#    └ 댓글 1개 수집
#    → 누적 댓글 5155개
#
# ▶️ [187/500] 297만명 개인정보 털렸다! 롯데카드 &#39;이 문자&#39; 받으신
#    └ 댓글 2개 수집
#    → 누적 댓글 5157개
#
# ▶️ [188/500] 롯데카드 3백만 명 정보 유출…28만 명은 비번도 털려 / KBS  20
#    └ 댓글 5개 수집
#    → 누적 댓글 5162개
#
# ▶️ [189/500] 롯데카드 297만명 털렸다! 지금 바로 확인하세요!! #롯데카드 #롯데카
#    └ 댓글 1개 수집
#    → 누적 댓글 5163개
#
# ▶️ [190/500] 롯데카드 297만명 진짜 싹다 털렸습니다! 당장 &#39;이것&#39;부
#    └ 댓글 0개 수집
#    → 누적 댓글 5163개
#
# ▶️ [191/500] [🔴라이브를 켜라] 이동통신 3사·롯데카드 해킹사태 청문회…이 시각 과방
#    └ 댓글 1개 수집
#    → 누적 댓글 5164개
#
# ▶️ [192/500] 롯데카드, 해킹 사고 차등 보상에 소비자 반발 [말하는 기자들_금융_09
#    └ 댓글 2개 수집
#    → 누적 댓글 5166개
#
# ▶️ [193/500] [🔴 LIVE 과방위] 대규모 해킹사고(KT•롯데카드) 관련 청문회 l
#    └ 댓글 3개 수집
#    → 누적 댓글 5169개
#
# ▶️ [194/500] 롯데카드 해킹 17일간 몰랐다...금감원 &quot;피해 시 전액 보상&
#    └ 댓글 6개 수집
#    → 누적 댓글 5175개
#
# ▶️ [195/500] 롯데카드 해킹 피해 예상보다 커 / 연합뉴스TV(YonhapnewsTV)
#    └ 댓글 0개 수집
#    → 누적 댓글 5175개
#
# ▶️ [196/500] KT &quot;관리부실 인정&quot;…KT·롯데카드 해킹 청문회 /
#    └ 댓글 6개 수집
#    → 누적 댓글 5181개
#
# ▶️ [197/500] 국회 과방위 KT, 롯데카드 해킹 청문회 #국회 #과방위 #KT #롯데카
#    └ 댓글 1개 수집
#    → 누적 댓글 5182개
#
# ▶️ [198/500] [현장연결] 롯데카드 &#39;해킹 사고&#39; 결과 발표…대표이사 대
#    └ 댓글 7개 수집
#    → 누적 댓글 5189개
#
# ▶️ [199/500] 롯데카드 &quot;해킹사고 관련 24시간 상담창구 운영&quot; /
#    └ 댓글 0개 수집
#    → 누적 댓글 5189개
#
# ▶️ [200/500] 정부 인증 이틀 만에 뚫린 롯데카드 / 비디오머그 / 귀에빡!종원 #Sh
#    └ 댓글 1개 수집
#    → 누적 댓글 5190개
#
# ▶️ [201/500] [현장영상] 롯데카드 대국민 사과…“해킹 사고로 297만 명 정보 유출”
#    └ 댓글 3개 수집
#    → 누적 댓글 5193개
#
# ▶️ [202/500] KT·롯데카드 &#39;해킹&#39; 청문회‥&quot;국민 불안 사죄&
#    └ 댓글 8개 수집
#    → 누적 댓글 5201개
#
# ▶️ [203/500] 해킹  당한 줄 몰랐던 롯데카드 상황
#    └ 댓글 0개 수집
#    → 누적 댓글 5201개
#
# ▶️ [204/500] 롯데카드 어쩌나…해킹 피해자, 기업회생 카드 꺼냈다
#    └ 댓글 1개 수집
#    → 누적 댓글 5202개
#
# ▶️ [205/500] KT·LG U+·롯데카드도 털렸나?…해킹 공포 재점화
#    └ 댓글 1개 수집
#    → 누적 댓글 5203개
#
# ▶️ [206/500] 롯데카드 해킹 피해 눈덩이…피해 규모 예상보다 커 / 연합뉴스TV (Yo
#    └ 댓글 2개 수집
#    → 누적 댓글 5205개
#
# ▶️ [207/500] 롯데카드 해킹 1.7GB 유출…“고객정보 포함 확인 중” / KBS  2
#    └ 댓글 3개 수집
#    → 누적 댓글 5208개
#
# ▶️ [208/500] 롯데카드 해킹 피해 최대 수백만 명? / 연합뉴스TV(Yonhapnews
#    └ 댓글 0개 수집
#    → 누적 댓글 5208개
#
# ▶️ [209/500] 롯데카드, CVC-번호도 털렸다 &quot;내년 연회비 면제&quot;
#    └ 댓글 6개 수집
#    → 누적 댓글 5214개
#
# ▶️ [210/500] &#39;해킹&#39; 롯데카드 4만2천 명 해지...&quot;유출 고
#    └ 댓글 0개 수집
#    → 누적 댓글 5214개
#
# ▶️ [211/500] [🔴속보] 개인정보위, &#39;롯데카드 고객정보 유출&#39; 조사 착
#    └ 댓글 2개 수집
#    → 누적 댓글 5216개
#
# ▶️ [212/500] [신통방통] &quot;피해자 수백만 될 수도&quot;···롯데카드 해
#    └ 댓글 0개 수집
#    → 누적 댓글 5216개
#
# ▶️ [213/500] 🚨 롯데카드 297만명 해킹! 당신의 정보도 털렸을 수 있습니다 롯데카드
#    └ 댓글 1개 수집
#    → 누적 댓글 5217개
#
# ▶️ [214/500] 보름이 지나도 몰랐다…롯데카드 해킹 사태에 금융권 보안 비상
#    └ 댓글 6개 수집
#    → 누적 댓글 5223개
#
# ▶️ [215/500] 롯데카드 해킹사고…&quot;정보 유출 확인 중&quot; / 연합뉴스T
#    └ 댓글 0개 수집
#    → 누적 댓글 5223개
#
# ▶️ [216/500] 롯데카드 해킹 사태 심각! 조좌진 대표의 대국민 사과 예고 [세상만사]
#    └ 댓글 4개 수집
#    → 누적 댓글 5227개
#
# ▶️ [217/500] 롯데카드 &quot;28만 명 CVC까지 유출&quot;...19일간 몰
#    └ 댓글 0개 수집
#    → 누적 댓글 5227개
#
# ▶️ [218/500] [YTN 실시간뉴스] 롯데카드 해킹 &#39;눈덩이&#39;...곧 대국
#    └ 댓글 5개 수집
#    → 누적 댓글 5232개
#
# ▶️ [219/500] 롯데카드 “297만 명 정보 유출…28만 명 부정사용 여지” / KBS
#    └ 댓글 0개 수집
#    → 누적 댓글 5232개
#
# ▶️ [220/500] [전화연결] 롯데카드 297만명 정보 유출…28만명 &#39;부정사용&#
#    └ 댓글 1개 수집
#    → 누적 댓글 5233개
#
# ▶️ [221/500] 경찰 국수본, &#39;롯데카드 해킹&#39; 사건 수사 착수 / YTN
#    └ 댓글 7개 수집
#    → 누적 댓글 5240개
#
# ▶️ [222/500] 롯데카드 1.7GB 유출 비상사태, 내 통장 0원 되기 전에 당장 확인해
#    └ 댓글 0개 수집
#    → 누적 댓글 5240개
#
# ▶️ [223/500] 보안 구멍 뚫린 롯데카드…피해자 전액 보상 약속
#    └ 댓글 3개 수집
#    → 누적 댓글 5243개
#
# ▶️ [224/500] 롯데카드 해킹 CVC까지 털렸다 / 연합뉴스TV(YonhapnewsTV)
#    └ 댓글 0개 수집
#    → 누적 댓글 5243개
#
# ▶️ [225/500] “김영섭, 사퇴하라”… 국회,KT·롯데카드 해킹 앞다퉈 질타 #KT해킹
#    └ 댓글 2개 수집
#    → 누적 댓글 5245개
#
# ▶️ [226/500] &quot;SKT 피해 KT 갔더니 또 해킹..롯데카드는 다 털린 수준?
#    └ 댓글 4개 수집
#    → 누적 댓글 5249개
#
# ▶️ [227/500] SKT·KT·롯데카드 전방위 확산…정부 “해킹과의 전쟁” / 연합뉴스TV
#    └ 댓글 3개 수집
#    → 누적 댓글 5252개
#
# ▶️ [228/500] 역대급 개인정보 유출 파문, 롯데카드도 털렸다 #롯데카드#개인정보유출#해
#    └ 댓글 1개 수집
#    → 누적 댓글 5253개
#
# ▶️ [229/500] 롯데카드, 해킹 대참사…“비번·CVC 털렸다”
#    └ 댓글 1개 수집
#    → 누적 댓글 5254개
#
# ▶️ [230/500] 롯데카드 해킹사건?? 예상보다 더 심각해진 상황!! #해킹 #롯데카드해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 5255개
#
# ▶️ [231/500] 모르면 털립니다 해킹 피해 막는 방법
#    └ 댓글 0개 수집
#    → 누적 댓글 5255개
#
# ▶️ [232/500] [현장FACT] &#39;해킹 사고&#39; 롯데카드 &quot;28만
#    └ 댓글 7개 수집
#    → 누적 댓글 5262개
#
# ▶️ [233/500] 롯데카드도 털렸다.개인정보 297만명 유출#롯데카드#개인정보유출#CVC#
#    └ 댓글 1개 수집
#    → 누적 댓글 5263개
#
# ▶️ [234/500] 롯데카드 고객 297만 명 해킹 피해…“전액 보상·무이자 10개월”
#    └ 댓글 0개 수집
#    → 누적 댓글 5263개
#
# ▶️ [235/500] &quot;SKT 해킹은 장난 수준&quot;...롯데카드 비번·CVC까
#    └ 댓글 1개 수집
#    → 누적 댓글 5264개
#
# ▶️ [236/500] 960만 회원 충격😱롯데카드 해킹 또 터졌다!
#    └ 댓글 3개 수집
#    → 누적 댓글 5267개
#
# ▶️ [237/500] “정부 보안 무너졌다”… KT 해킹·롯데카드 유출 폭로｜국회 청문회, 관
#    └ 댓글 2개 수집
#    → 누적 댓글 5269개
#
# ▶️ [238/500] 롯데카드 해킹 사태 &#39;일파만파&#39;…피해자 100만 명 넘을
#    └ 댓글 0개 수집
#    → 누적 댓글 5269개
#
# ▶️ [239/500] 960만 명의 카드를 해킹한 넌 누구냐?
#    └ 댓글 0개 수집
#    → 누적 댓글 5269개
#
# ▶️ [240/500] 롯데계열사가 아니라고? 롯데카드해킹사태 홈플러스 MBK파트너스?
#    └ 댓글 1개 수집
#    → 누적 댓글 5270개
#
# ▶️ [241/500] 롯데카드 해킹 피해자 필수 시청 영상
#    └ 댓글 1개 수집
#    → 누적 댓글 5271개
#
# ▶️ [242/500] SK, KT에 이어 롯데카드도 털렸다고? [뉴빡] #롯데카드 #유출 #해
#    └ 댓글 0개 수집
#    → 누적 댓글 5271개
#
# ▶️ [243/500] 롯데카드 해킹!무조건 이렇게 방어하셔야 합니다!👊🏻😤 #뉴스 #한국 #이
#    └ 댓글 0개 수집
#    → 누적 댓글 5271개
#
# ▶️ [244/500] 롯데카드 해킹! 피해 규모가 충격적인 이유는?
#    └ 댓글 0개 수집
#    → 누적 댓글 5271개
#
# ▶️ [245/500] [경제현장 오늘 다시보기] 롯데카드 해킹 &quot;예상보다 훨씬 심각&
#    └ 댓글 0개 수집
#    → 누적 댓글 5271개
#
# ▶️ [246/500] 롯데카드 수백만명 해킹! 정보유출 피해 대응방법! | 롯데카드 고객센터
#    └ 댓글 0개 수집
#    → 누적 댓글 5271개
#
# ▶️ [247/500] 경찰 국수본, &#39;롯데카드 해킹&#39; 사건 수사 착수 / YTN
#    └ 댓글 4개 수집
#    → 누적 댓글 5275개
#
# ▶️ [248/500] [빠른뉴스 쨉] 롯데카드 297만 명 개인 정보 털렸다... 보상으로 &
#    └ 댓글 2개 수집
#    → 누적 댓글 5277개
#
# ▶️ [249/500] 롯데카드 297만명 정보 유출…28만명 부정 사용 피해 가능성 #롯데카드
#    └ 댓글 3개 수집
#    → 누적 댓글 5280개
#
# ▶️ [250/500] 조좌진 롯데카드 대표 &quot;사태수습이 마지막 임무…사임도 각오&qu
#    └ 댓글 0개 수집
#    → 누적 댓글 5280개
#
# ▶️ [251/500] 롯데카드, 해킹 피해 일파만파 &quot;297만명 정보 유출&quot;
#    └ 댓글 7개 수집
#    → 누적 댓글 5287개
#
# ▶️ [252/500] 롯데카드 개인정보 유출, 롯데그룹이 당혹한 까닭은
#    └ 댓글 0개 수집
#    → 누적 댓글 5287개
#
# ▶️ [253/500] [자막뉴스] 롯데카드 해킹 공격…&#39;회원 960만 명&#39; 개인
#    └ 댓글 1개 수집
#    → 누적 댓글 5288개
#
# ▶️ [254/500] 또 해킹? 롯데카드 967만명 해킹사태 #해킹 #롯데 #롯데카드 #skt
#    └ 댓글 1개 수집
#    → 누적 댓글 5289개
#
# ▶️ [255/500] 카드사 보안 적신호 🚨 롯데카드 사태 정리 #롯데카드 #개인정보유출 #보
#    └ 댓글 2개 수집
#    → 누적 댓글 5291개
#
# ▶️ [256/500] “내 롯데카드 해킹 됐나?”, 확인 및 대응 방법은...
#    └ 댓글 0개 수집
#    → 누적 댓글 5291개
#
# ▶️ [257/500] 카드사 역사상 최악? 롯데카드 297만명 정보 유출 #뉴스
#    └ 댓글 0개 수집
#    → 누적 댓글 5291개
#
# ▶️ [258/500] [3분쇼츠] 업계 5위 카드사도 개인정보 유출 막지 못했다
#    └ 댓글 0개 수집
#    → 누적 댓글 5291개
#
# ▶️ [259/500] 960만명 고객정보 털린 롯데카드, 보상으로 끝낼 수 있을까? 대국민 사
#    └ 댓글 1개 수집
#    → 누적 댓글 5292개
#
# ▶️ [260/500] 롯데카드 해킹 터지자마자 &#39;이 주식&#39;이 조용히 웃는 이유
#    └ 댓글 0개 수집
#    → 누적 댓글 5292개
#
# ▶️ [261/500] 롯데카드, 269만명 해킹 피해 with CLOVA Dubbing
#    └ 댓글 1개 수집
#    → 누적 댓글 5293개
#
# ▶️ [262/500] &#39;해킹 사고&#39; 롯데카드 &quot;피해 전액 보장 약속&q
#    └ 댓글 0개 수집
#    → 누적 댓글 5293개
#
# ▶️ [263/500] 롯데카드 해킹규모 알고 보니, 첫 신고의 &#39;100배&#39;｜전체
#    └ 댓글 2개 수집
#    → 누적 댓글 5295개
#
# ▶️ [264/500] 롯데카드 297만명 정보 유출… 당신의 카드는 안전합니까? #롯데카드 #
#    └ 댓글 2개 수집
#    → 누적 댓글 5297개
#
# ▶️ [265/500] 롯데카드, SKT 대규모 해킹사고, 개인정보유출 피해자들 법적 대응 방법
#    └ 댓글 1개 수집
#    → 누적 댓글 5298개
#
# ▶️ [266/500] CVC까지 털렸다, 불안한 롯데카드 가입자 / #채널A #shorts #
#    └ 댓글 1개 수집
#    → 누적 댓글 5299개
#
# ▶️ [267/500] 당하고도 17일간 모른 롯데카드…965만명 회원 &#39;발칵&#39;
#    └ 댓글 0개 수집
#    → 누적 댓글 5299개
#
# ▶️ [268/500] CVC까지 유출 우려 롯데카드 해킹에 국민 불안 확산 #롯데카드 #해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 5300개
#
# ▶️ [269/500] “297만명 개인정보 털린 롯데카드… 보안주 TOP5 공개”
#    └ 댓글 2개 수집
#    → 누적 댓글 5302개
#
# ▶️ [270/500] &#39;대규모 해킹&#39; 청문회…KT·롯데카드 대표 출석 [풀영상
#    └ 댓글 1개 수집
#    → 누적 댓글 5303개
#
# ▶️ [271/500] 롯데카드, SKT 대규모 해킹사고 내 개인정보는 안전한가?!
#    └ 댓글 1개 수집
#    → 누적 댓글 5304개
#
# ▶️ [272/500] 롯데카드 297만 명 정보 유출…부정사용 공포
#    └ 댓글 0개 수집
#    → 누적 댓글 5304개
#
# ▶️ [273/500] [롯데카드 집단소송 모집 중] 롯데카드 이용자라면 해킹 피해 집단 소송에
#    └ 댓글 1개 수집
#    → 누적 댓글 5305개
#
# ▶️ [274/500] 롯데카드 최악 해킹 사고...CVC 번호 노출 28만명
#    └ 댓글 8개 수집
#    → 누적 댓글 5313개
#
# ▶️ [275/500] 🔥 967만 명 회원 카드사, 해킹 당했다! #롯데카드 #해킹 #카드사
#    └ 댓글 0개 수집
#    → 누적 댓글 5313개
#
# ▶️ [276/500] “롯데카드 해킹 967만명 피해… 왜 17일간 숨겼나?” #롯데카드 #해
#    └ 댓글 1개 수집
#    → 누적 댓글 5314개
#
# ▶️ [277/500] 롯데카드 해킹, 297만명 개인정보 유출.. 사상 최악의 사고
#    └ 댓글 0개 수집
#    → 누적 댓글 5314개
#
# ▶️ [278/500] 롯데카드 CVC번호, 서버에 암호로 저장됐더라면~ / YTN 사이언스
#    └ 댓글 0개 수집
#    → 누적 댓글 5314개
#
# ▶️ [279/500] 롯데카드 해킹 297만명 피해 눈덩이…피해 규모 확산!!   #롯데카드
#    └ 댓글 0개 수집
#    → 누적 댓글 5314개
#
# ▶️ [280/500] [원영섭 shorts] 롯데카드 해킹피해 손배소 원고모집
#    └ 댓글 1개 수집
#    → 누적 댓글 5315개
#
# ▶️ [281/500] 롯데카드와 KT 해킹이번이 처음이 아닌 상습이다!
#    └ 댓글 0개 수집
#    → 누적 댓글 5315개
#
# ▶️ [282/500] 롯데카드 28만명 중요 정보 유출, KT는 무단 소액결제 피해 늘어 [박
#    └ 댓글 0개 수집
#    → 누적 댓글 5315개
#
# ▶️ [283/500] 우리나라 보안의 문제점, 보안 인증 하나만 받으면 끝?
#    └ 댓글 1개 수집
#    → 누적 댓글 5316개
#
# ▶️ [284/500] 예고된 해킹?롯데카드, 5년간 보안감사 ‘1회’ #롯데카드 #해킹 #mb
#    └ 댓글 0개 수집
#    → 누적 댓글 5316개
#
# ▶️ [285/500] [현장연결] KT·롯데카드 해킹 사고에…김 총리, 긴급현안점검회의 주재
#    └ 댓글 5개 수집
#    → 누적 댓글 5321개
#
# ▶️ [286/500] &#39;skt 20배&#39; 롯데카드 해킹, 카드 재발급 폭주에 24
#    └ 댓글 0개 수집
#    → 누적 댓글 5321개
#
# ▶️ [287/500] 읽어주는 세계뉴스-롯데카드 해킹 발생 #뉴스 #롯데카드 #해킹 #fyp
#    └ 댓글 1개 수집
#    → 누적 댓글 5322개
#
# ▶️ [288/500] 롯데카드 해킹 사태 어디까지가나? 최고 수위 제재와 책임소재, 배후는?
#    └ 댓글 0개 수집
#    → 누적 댓글 5322개
#
# ▶️ [289/500] 수백만명 털렸다…롯데카드 해킹 #해킹 #개인정보
#    └ 댓글 0개 수집
#    → 누적 댓글 5322개
#
# ▶️ [290/500] 발표후!! 롯데카드 해킹에 대한 보상?  #뉴스 #정보 #이슈 #보상 #
#    └ 댓글 0개 수집
#    → 누적 댓글 5322개
#
# ▶️ [291/500] “롯데카드 해킹, 결국 터질 게 터졌다”
#    └ 댓글 0개 수집
#    → 누적 댓글 5322개
#
# ▶️ [292/500] 고개 숙인 롯데카드 &quot;297만 명 개인정보 유출…피해 전액 보상
#    └ 댓글 4개 수집
#    → 누적 댓글 5326개
#
# ▶️ [293/500] 960만 명 정보 유출! 또 롯데카드 #롯데카드 #롯데카드해킹 #개인정보
#    └ 댓글 0개 수집
#    → 누적 댓글 5326개
#
# ▶️ [294/500] 롯데카드 대규모 유출 (카드번호·결제내역 유출) #논란 #정보유출 #개인
#    └ 댓글 0개 수집
#    → 누적 댓글 5326개
#
# ▶️ [295/500] 여러분, 카드사 해킹… 이번엔 롯데카드입니다.
#    └ 댓글 0개 수집
#    → 누적 댓글 5326개
#
# ▶️ [296/500] 조좌진 롯데카드 대표이사 “해킹 사태 책임지고 피해액 전액 보상할 것”
#    └ 댓글 0개 수집
#    → 누적 댓글 5326개
#
# ▶️ [297/500] [⚡]롯데카드 &quot;297만명 고객정보 유출&quot;
#    └ 댓글 1개 수집
#    → 누적 댓글 5327개
#
# ▶️ [298/500] 내 카드도 털렸을까 롯데카드 정보 유출 전격 확인#롯데카드 #정보유출 #
#    └ 댓글 0개 수집
#    → 누적 댓글 5327개
#
# ▶️ [299/500] 충격! 롯데카드 해킹 규모 실화냐? 카드 확인 필수
#    └ 댓글 0개 수집
#    → 누적 댓글 5327개
#
# ▶️ [300/500] 롯데카드 해킹 반드시 알아야 할 대처법!!!
#    └ 댓글 1개 수집
#    → 누적 댓글 5328개
#
# ▶️ [301/500] 롯데카드 297만명 개인정보유출 피해 확인 및 대처방법  #롯데카드 #개
#    └ 댓글 0개 수집
#    → 누적 댓글 5328개
#
# ▶️ [302/500] 김건희 여사 첫 재판 출정… 통일교 총재 구속, 롯데카드 해킹까지! (1
#    └ 댓글 1개 수집
#    → 누적 댓글 5329개
#
# ▶️ [303/500] 롯데 카드가 해킹 당했다고? #shorts
#    └ 댓글 0개 수집
#    → 누적 댓글 5329개
#
# ▶️ [304/500] 롯데카드 해킹사고 발생, 960만명 회원 불안 !
#    └ 댓글 0개 수집
#    → 누적 댓글 5329개
#
# ▶️ [305/500] &#39;해킹&#39; 롯데카드 대표 &quot;보안 미흡 사과…피해 전
#    └ 댓글 0개 수집
#    → 누적 댓글 5329개
#
# ▶️ [306/500] 롯데카드 297만명 정보 유출…카드번호·CVC까지 털렸다 #롯데카드 #해
#    └ 댓글 0개 수집
#    → 누적 댓글 5329개
#
# ▶️ [307/500] 롯데카드 해킹 피해보상·내 정보 확인법 | 안전한 카드 생활 꿀팁
#    └ 댓글 0개 수집
#    → 누적 댓글 5329개
#
# ▶️ [308/500] 롯데카드 해킹규모 무려 100배#해킹#보안
#    └ 댓글 0개 수집
#    → 누적 댓글 5329개
#
# ▶️ [309/500] 롯데카드 해킹 960만명 정보 위기 17일간 몰랐다
#    └ 댓글 1개 수집
#    → 누적 댓글 5330개
#
# ▶️ [310/500] &quot;롯데카드 297만 명 해킹! CVC까지 털렸다… 소유자 필수
#    └ 댓글 0개 수집
#    → 누적 댓글 5330개
#
# ▶️ [311/500] SKT, KT, 롯데카드, YES24… 요즘 해킹 사고 많은 이유[휙]
#    └ 댓글 1개 수집
#    → 누적 댓글 5331개
#
# ▶️ [312/500] 롯데카드 297만 명 정보 유출···보안 사고에 징벌적 과징금 - 언론사
#    └ 댓글 0개 수집
#    → 누적 댓글 5331개
#
# ▶️ [313/500] 9월 19일 아침뉴스 | 롯데카드 개인정보 유출 피해자 전원, 10개월
#    └ 댓글 0개 수집
#    → 누적 댓글 5331개
#
# ▶️ [314/500] 롯데카드 해킹 사태 심각합니다!
#    └ 댓글 0개 수집
#    → 누적 댓글 5331개
#
# ▶️ [315/500] 롯데카드 해킹 유출 피해 #롯데카드 #카드 #해킹 #이슈 #사건사고
#    └ 댓글 0개 수집
#    → 누적 댓글 5331개
#
# ▶️ [316/500] 롯데카드 “해킹 피해 회원 규모 297만명… 주민등록번호·CVC 등 유출
#    └ 댓글 1개 수집
#    → 누적 댓글 5332개
#
# ▶️ [317/500] [이슈터미네이터] SKT·KT·롯데카드·예스24까지...잇단 초대형 해킹
#    └ 댓글 4개 수집
#    → 누적 댓글 5336개
#
# ▶️ [318/500] [에경PICK] ‘960만 회원’ 롯데카드 해킹 피해 규모 눈덩이 #sh
#    └ 댓글 1개 수집
#    → 누적 댓글 5337개
#
# ▶️ [319/500] &quot;롯데카드 297만 명 해킹! CVC까지 털렸다… 소유자 필수
#    └ 댓글 0개 수집
#    → 누적 댓글 5337개
#
# ▶️ [320/500] 롯데카드 해킹 사태, 개인정보 피해 내용 정리 #사회이슈 #개인정보 #뉴
#    └ 댓글 1개 수집
#    → 누적 댓글 5338개
#
# ▶️ [321/500] 롯데카드 해킹사태, 롯데는 억울하다 #롯데카드 #해킹사태 #롯데그룹 #브
#    └ 댓글 0개 수집
#    → 누적 댓글 5338개
#
# ▶️ [322/500] 백수노총각 신입 시청자모집 롯데카드 해킹피해 조심 #부천#서울#전주#술먹
#    └ 댓글 0개 수집
#    → 누적 댓글 5338개
#
# ▶️ [323/500] 전대미문의 KT·롯데카드 해킹 사태…강제절차로 자료 확보[뉴스와] / 연
#    └ 댓글 4개 수집
#    → 누적 댓글 5342개
#
# ▶️ [324/500] 롯데카드 해킹, 단 일주일 만에 3만 명 떠났다…왜 이렇게 불안한 걸까?
#    └ 댓글 0개 수집
#    → 누적 댓글 5342개
#
# ▶️ [325/500] 롯데카드 해킹 지금 해야할 3가지 #경제뉴스 #개인정보보호
#    └ 댓글 0개 수집
#    → 누적 댓글 5342개
#
# ▶️ [326/500] 롯데카드 &quot;해킹피해 전액 보상할 것…연회비·크레딧케어 무료,무이
#    └ 댓글 3개 수집
#    → 누적 댓글 5345개
#
# ▶️ [327/500] [에경PICK] ‘롯데카드 해킹’ 핵심 피해고객 28만명 #shorts
#    └ 댓글 2개 수집
#    → 누적 댓글 5347개
#
# ▶️ [328/500] 롯데카드 해킹 피해자 집단소송 본격화…MBK 책임론도 확산
#    └ 댓글 0개 수집
#    → 누적 댓글 5347개
#
# ▶️ [329/500] 롯데카드 해킹 데이터, 첫 신고의 100배 유출
#    └ 댓글 0개 수집
#    → 누적 댓글 5347개
#
# ▶️ [330/500] [스팟Live] *풀영상* 고개 숙인 롯데카드 대표  &quot;297만
#    └ 댓글 0개 수집
#    → 누적 댓글 5347개
#
# ▶️ [331/500] 보안망 뚫린 롯데카드, 해킹사고 왜 막지 못했나  / 머니투데이방송 (뉴
#    └ 댓글 0개 수집
#    → 누적 댓글 5347개
#
# ▶️ [332/500] 롯데카드 28만명 개인정보 &#39;싹 다 털렸다&#39;
#    └ 댓글 1개 수집
#    → 누적 댓글 5348개
#
# ▶️ [333/500] 롯데카드 해킹 피해 #롯데카드#사이버공격#해킹#SK텔레콤#KT#MBK파트
#    └ 댓글 3개 수집
#    → 누적 댓글 5351개
#
# ▶️ [334/500] 점점 심각해지는 롯데카드 해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 5352개
#
# ▶️ [335/500] 롯데카드 해킹, 28만명 비밀번호 유출?! #shorts
#    └ 댓글 0개 수집
#    → 누적 댓글 5352개
#
# ▶️ [336/500] [다시보기] 롯데카드 해킹, 297만 명 털렸다…달랑 무이자 할부?  -
#    └ 댓글 0개 수집
#    → 누적 댓글 5352개
#
# ▶️ [337/500] 960만 회원 충격…롯데카드 대국민 사과 임박 #롯데카드 #해킹 #이재명
#    └ 댓글 0개 수집
#    → 누적 댓글 5352개
#
# ▶️ [338/500] 롯데카드 개인정보 유출 피해 혼선…&quot;1만 명 추가 확인중&quo
#    └ 댓글 0개 수집
#    → 누적 댓글 5352개
#
# ▶️ [339/500] [오디오 뉴스] 보안 투자 줄인 MBK…롯데카드 해킹 사태 ‘뇌관’
#    └ 댓글 0개 수집
#    → 누적 댓글 5352개
#
# ▶️ [340/500] 롯데카드, 개인정보 유출 297만 명 피해…고객 불안 확산에 보상안 발표
#    └ 댓글 0개 수집
#    → 누적 댓글 5352개
#
# ▶️ [341/500] 롯데카드 쓰신다면 당장 확인하세요! 🚨 수백만명 정보 유출 역대급 사고
#    └ 댓글 0개 수집
#    → 누적 댓글 5352개
#
# ▶️ [342/500] [AM-PM] &#39;해킹 사고&#39; 롯데카드, 대국민 사과…피해
#    └ 댓글 0개 수집
#    → 누적 댓글 5352개
#
# ▶️ [343/500] 롯데카드 해킹사태, 억울한 롯데그룹? #롯데 #롯데그룹 #롯데카드 #MB
#    └ 댓글 0개 수집
#    → 누적 댓글 5352개
#
# ▶️ [344/500] 금융당국 &quot;해킹 사태 롯데카드에 최대수준 엄정 제재 방침&quo
#    └ 댓글 1개 수집
#    → 누적 댓글 5353개
#
# ▶️ [345/500] [롯데카드안쓴다]롯데충성 고객을 이렇게 버리다니 ...#롯데  #롯데카드
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 5353개
#
# ▶️ [346/500] 롯데카드 해킹 국감 집중점검! 금융권 보안은 안전한가?
#    └ 댓글 0개 수집
#    → 누적 댓글 5353개
#
# ▶️ [347/500] 롯데카드, 오늘 해킹사고 대국민 사과…사고 경위 발표 / 연합뉴스TV (
#    └ 댓글 0개 수집
#    → 누적 댓글 5353개
#
# ▶️ [348/500] 부정사용 절대 없다던 롯데카드...실상은?
#    └ 댓글 0개 수집
#    → 누적 댓글 5353개
#
# ▶️ [349/500] [스팟Live] &#39;960만 해킹 피해&#39; 롯데카드, 대국민
#    └ 댓글 2개 수집
#    → 누적 댓글 5355개
#
# ▶️ [350/500] 롯데카드해킹! 이렇게 대처하세요!!  #롯데카드 #카드해킹 #스미싱주의
#    └ 댓글 0개 수집
#    → 누적 댓글 5355개
#
# ▶️ [351/500] 💳 롯데카드 고객 297만 명 정보 유출… 핵심 보상 방안은? 🤔
#    └ 댓글 0개 수집
#    → 누적 댓글 5355개
#
# ▶️ [352/500] KT 또 다른 해킹 확인…롯데카드엔 &quot;엄정 제재&quot; /
#    └ 댓글 1개 수집
#    → 누적 댓글 5356개
#
# ▶️ [353/500] 요즘 난리난 롯데카드
#    └ 댓글 0개 수집
#    → 누적 댓글 5356개
#
# ▶️ [354/500] 경찰, &#39;롯데카드 해킹&#39; 유출정보 악용 가능성도 수사 /
#    └ 댓글 1개 수집
#    → 누적 댓글 5357개
#
# ▶️ [355/500] 롯데카드, 해킹 사고 17일간 몰라…금감원, 긴급검사 착수 / 연합뉴스T
#    └ 댓글 2개 수집
#    → 누적 댓글 5359개
#
# ▶️ [356/500] [롯데카드]개인정보유출문자만 달랑받았다면?  #롯데카드 #롯데카드개인정보
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 5359개
#
# ▶️ [357/500] 롯데카드, 개인정보 유출 297만명 보상안 논란…&quot;소비자 우롱&
#    └ 댓글 0개 수집
#    → 누적 댓글 5359개
#
# ▶️ [358/500] 롯데카드 해킹…1.7GB 유출, 960만 고객 불안
#    └ 댓글 0개 수집
#    → 누적 댓글 5359개
#
# ▶️ [359/500] 정보유출보다 더 화난다는 롯데카드 보상안
#    └ 댓글 1개 수집
#    → 누적 댓글 5360개
#
# ▶️ [360/500] [직설] SKT, KT 이어 롯데카드 해킹 사고…징벌적 과징금 도입한다?
#    └ 댓글 2개 수집
#    → 누적 댓글 5362개
#
# ▶️ [361/500] 롯데카드 297만 명의 개인정보 중국 해킹조직 ‘달빛(Dalbit)’ 추
#    └ 댓글 1개 수집
#    → 누적 댓글 5363개
#
# ▶️ [362/500] 보안·재무 악재…롯데카드 매각 ‘빨간불’ #더퍼블릭 #롯데카드 #매각 #
#    └ 댓글 0개 수집
#    → 누적 댓글 5363개
#
# ▶️ [363/500] 예상보다 100배 롯데카드 해킹 #롯데 #이슈 #뉴스
#    └ 댓글 0개 수집
#    → 누적 댓글 5363개
#
# ▶️ [364/500] 케이티KT 소액결제-롯데카드 정보유출, 잇따른 보안 사고 왜?
#    └ 댓글 0개 수집
#    → 누적 댓글 5363개
#
# ▶️ [365/500] 롯데카드 해킹, 297만명 회원 개인정보 유출... 대국민 사과 및 보상
#    └ 댓글 0개 수집
#    → 누적 댓글 5363개
#
# ▶️ [366/500] 롯카 대표도 놀랐다…297만명 개인정보 유출, 대체 어떻게? #롯데카드
#    └ 댓글 0개 수집
#    → 누적 댓글 5363개
#
# ▶️ [367/500] 롯데카드 해킹! 개인정보 유출 공포 확산
#    └ 댓글 0개 수집
#    → 누적 댓글 5363개
#
# ▶️ [368/500] 🚨“롯데카드 960만 회원💳해킹 초대형 사고&quot; #오늘의이슈 #쇼
#    └ 댓글 0개 수집
#    → 누적 댓글 5363개
#
# ▶️ [369/500] 국회서 24일 해킹사태 청문회…KT·롯데카드 대표 증인 / 연합뉴스TV
#    └ 댓글 0개 수집
#    → 누적 댓글 5363개
#
# ▶️ [370/500] [자막] 롯데카드 정보유출 297만명… 재발 막기 위해 제도 전면 개선
#    └ 댓글 4개 수집
#    → 누적 댓글 5367개
#
# ▶️ [371/500] 당신 카드도 위험? 롯데카드 해킹 전말 공개
#    └ 댓글 0개 수집
#    → 누적 댓글 5367개
#
# ▶️ [372/500] 롯데카드 해킹 사태 후폭풍이 거세지고 있습니다.  #shorts #롯데카
#    └ 댓글 0개 수집
#    → 누적 댓글 5367개
#
# ▶️ [373/500] #롯데카드 #해킹 #피해 #심각 #mbk파트너스 #관련 #논란
#    └ 댓글 0개 수집
#    → 누적 댓글 5367개
#
# ▶️ [374/500] 롯데카드 해킹 17일간 몰랐다…전액 보상 지시 | 롯데카드 | 개인정보유
#    └ 댓글 0개 수집
#    → 누적 댓글 5367개
#
# ▶️ [375/500] 국가수사본부, &#39;롯데카드 해킹·정보유출&#39; 수사 착수!!
#    └ 댓글 0개 수집
#    → 누적 댓글 5367개
#
# ▶️ [376/500] #롯데카드 #해킹 #과징금 #논란 #SKT #비교 #최대 #800억부과
#    └ 댓글 0개 수집
#    → 누적 댓글 5367개
#
# ▶️ [377/500] 롯데카드 해킹의 원인은 바로
#    └ 댓글 0개 수집
#    → 누적 댓글 5367개
#
# ▶️ [378/500] 롯데카드, 대규모 해킹 피해 발생!
#    └ 댓글 0개 수집
#    → 누적 댓글 5367개
#
# ▶️ [379/500] 롯데카드, 297만명 정보 해킹
#    └ 댓글 1개 수집
#    → 누적 댓글 5368개
#
# ▶️ [380/500] 롯데카드 정보 유출 사건, 역대급 해킹 파장이 밀려온다. 내 카드 정보는
#    └ 댓글 1개 수집
#    → 누적 댓글 5369개
#
# ▶️ [381/500] 롯데카드서 해킹사고…&quot;고객 정보 유출여부 확인 중&quot; /
#    └ 댓글 0개 수집
#    → 누적 댓글 5369개
#
# ▶️ [382/500] SKT 해킹 후 롯데카드도 털렸다
#    └ 댓글 0개 수집
#    → 누적 댓글 5369개
#
# ▶️ [383/500] KT·롯데카드, 국회 불려간 이유#KT #롯데카드 #개인정보유출 #국회청
#    └ 댓글 2개 수집
#    → 누적 댓글 5371개
#
# ▶️ [384/500] &quot;우리 계열사 아니라구요~&quot; 롯데그룹, 롯데카드 해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 5371개
#
# ▶️ [385/500] 2025년 9월 20일 오늘뉴스 #롯데카드 #해킹 #카드  #오늘뉴스 #
#    └ 댓글 1개 수집
#    → 누적 댓글 5372개
#
# ▶️ [386/500] 250918 롯데카드 297만명 회원정보 유출 #뉴스 #롯데카드 #해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 5372개
#
# ▶️ [387/500] 롯데 28만명 불안하게 만들다!! #뉴스 #이슈 #개인정보 #롯데 #롯데
#    └ 댓글 0개 수집
#    → 누적 댓글 5372개
#
# ▶️ [388/500] 카드번호·CVC까지 유출… 롯데카드 대규모 해킹 충격 #롯데카드 #뉴스
#    └ 댓글 0개 수집
#    → 누적 댓글 5372개
#
# ▶️ [389/500] 내 정보 또 털리냐? 🤬 롯데카드 해킹!
#    └ 댓글 0개 수집
#    → 누적 댓글 5372개
#
# ▶️ [390/500] 사상 최악 롯데카드 해킹 #shorts #뉴스 #이슈
#    └ 댓글 0개 수집
#    → 누적 댓글 5372개
#
# ▶️ [391/500] 롯데카드 해킹 개인 결제 민감 정보 대규모
#    └ 댓글 0개 수집
#    → 누적 댓글 5372개
#
# ▶️ [392/500] 조좌진 롯데카드 대표, 해킹 사고 사과…&quot;피해 전액 보상 약속&
#    └ 댓글 0개 수집
#    → 누적 댓글 5372개
#
# ▶️ [393/500] &quot;297만 명 피해!&quot; 롯데카드 초대형 해킹 충격 #롯
#    └ 댓글 1개 수집
#    → 누적 댓글 5373개
#
# ▶️ [394/500] ** 롯데카드 해킹, 진짜 심각하네!
#    └ 댓글 0개 수집
#    → 누적 댓글 5373개
#
# ▶️ [395/500] 회원 960만 롯데카드 해킹을 17일 동안 몰랐습니다  #롯데카드해킹,
#    └ 댓글 1개 수집
#    → 누적 댓글 5374개
#
# ▶️ [396/500] 롯데카드, 해킹으로 297만명 고객정보 유출! #사회이슈 #뉴스 #이슈
#    └ 댓글 1개 수집
#    → 누적 댓글 5375개
#
# ▶️ [397/500] “1.7GB라더니 200GB” … 롯데카드, 카드번호까지 털렸다
#    └ 댓글 0개 수집
#    → 누적 댓글 5375개
#
# ▶️ [398/500] 롯데카드, 정보유출 고객에게 10개월 무이자 할부 #롯데카드 #신용카드
#    └ 댓글 0개 수집
#    → 누적 댓글 5375개
#
# ▶️ [399/500] 롯데카드 해킹·김건희 전자발찌… 오늘의 1분 뉴스
#    └ 댓글 0개 수집
#    → 누적 댓글 5375개
#
# ▶️ [400/500] 롯데카드 해킹, 당신의 정보는? 2025.09.10
#    └ 댓글 0개 수집
#    → 누적 댓글 5375개
#
# ▶️ [401/500] [주식] 롯데카드 해킹! 297만명 정보유출! 스테이블코인 보안주 #nh
#    └ 댓글 0개 수집
#    → 누적 댓글 5375개
#
# ▶️ [402/500] 롯데카드 297만 명 해킹! 내 정보도 털렸는지 확인하세요
#    └ 댓글 0개 수집
#    → 누적 댓글 5375개
#
# ▶️ [403/500] 롯데카드, 해킹 17일 몰랐다…결제내역 유출 의심
#    └ 댓글 0개 수집
#    → 누적 댓글 5375개
#
# ▶️ [404/500] 롯데카드 해킹사태, 보안투자·인증제도 무용지물 [말하는 기자들_금융_09
#    └ 댓글 1개 수집
#    → 누적 댓글 5376개
#
# ▶️ [405/500] 롯데카드 KT 도 해킹 되었어요! 삼성폰 쓴다면 이거 당장 끄세요! 내계
#    └ 댓글 1개 수집
#    → 누적 댓글 5377개
#
# ▶️ [406/500] 롯데카드, 해킹 사고 17일 뒤 금감원 늑장 신고…&quot;카드정보 유
#    └ 댓글 0개 수집
#    → 누적 댓글 5377개
#
# ▶️ [407/500] 롯데카드 대규모 해킹사고
#    └ 댓글 1개 수집
#    → 누적 댓글 5378개
#
# ▶️ [408/500] [현장] 롯데카드 해킹 피해자 &#39;수백만명 가능성&#39;...조좌
#    └ 댓글 0개 수집
#    → 누적 댓글 5378개
#
# ▶️ [409/500] 중국인에 KT 소액결제 해킹 폰번호·IMEI도 털렸다 롯데카드도 #ccp
#    └ 댓글 3개 수집
#    → 누적 댓글 5381개
#
# ▶️ [410/500] &quot;롯데카드 해킹 사고 피해 수백만명 가능성에 정보및 보안주&qu
#    └ 댓글 0개 수집
#    → 누적 댓글 5381개
#
# ▶️ [411/500] 롯데카드, 960만 고객정보 해킹당했다...“유출 여부 확인 중&quot
#    └ 댓글 0개 수집
#    → 누적 댓글 5381개
#
# ▶️ [412/500] “SKT보다 20배 더 크다! 롯데카드, 카드번호·CVC까지 싹 털렸다”
#    └ 댓글 0개 수집
#    → 누적 댓글 5381개
#
# ▶️ [413/500] 롯데카드에서는 왜 두번이나 유출사고 터졌나
#    └ 댓글 0개 수집
#    → 누적 댓글 5381개
#
# ▶️ [414/500] 롯데카드 해킹 대폭발! 297만 명 정보 유출! 보안주 급등
#    └ 댓글 0개 수집
#    → 누적 댓글 5381개
#
# ▶️ [415/500] KT 롯데카드 해킹 관련 정부 대책 마련 브리핑 KT 롯데카드 해킹 사건
#    └ 댓글 0개 수집
#    → 누적 댓글 5381개
#
# ▶️ [416/500] 롯데카드 해킹 LG KT도 털렸다 인스타그램 로멘스스캠 주의 #해킹 #통
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 5381개
#
# ▶️ [417/500] 통신3사·롯데카드 CEO 소환한 과방위, 정보유출 책임 묻는다 | 국회
#    └ 댓글 0개 수집
#    → 누적 댓글 5381개
#
# ▶️ [418/500] 롯데카드 대참사 #shorts #롯데 #해킹 #대참사
#    └ 댓글 0개 수집
#    → 누적 댓글 5381개
#
# ▶️ [419/500] 롯데카드의 해킹사태! 보안株 동반 강세 #롯데카드 #안랩 #이스트소프트
#    └ 댓글 0개 수집
#    → 누적 댓글 5381개
#
# ▶️ [420/500] “롯데카드 297만명 개인정보 유출…전액 보상 약속”
#    └ 댓글 1개 수집
#    → 누적 댓글 5382개
#
# ▶️ [421/500] &#39;960만 회원&#39; 롯데카드 해킹... CVC 번호까지 털려
#    └ 댓글 1개 수집
#    → 누적 댓글 5383개
#
# ▶️ [422/500] 롯데카드 해킹 시도?! 당신 정보도 노출됐을 수 있습니다 #롯데카드 #해
#    └ 댓글 0개 수집
#    → 누적 댓글 5383개
#
# ▶️ [423/500] #이모저모 #롯데 #카드 #해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 5383개
#
# ▶️ [424/500] 뉴스35 롯데카드 해킹 사태 &#39;보안 위반사항 파악, 엄정 조치&#
#    └ 댓글 0개 수집
#    → 누적 댓글 5383개
#
# ▶️ [425/500] KT에 롯데카드까지... 개인정보 유출 패닉 보안 솔루션 전문 &#39;
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 5383개
#
# ▶️ [426/500] KT·롯데카드 탈탈 턴 과방위 한숨 푹…과방위원장 최민희 입에 칼물고?
#    └ 댓글 0개 수집
#    → 누적 댓글 5383개
#
# ▶️ [427/500] 롯데카드 3백만 명 정보 유출…28만 명은 비번도 털려 / KBS  20
#    └ 댓글 2개 수집
#    → 누적 댓글 5385개
#
# ▶️ [428/500] 아놔 또 해킹이라고? kt와 롯데카드 해킹 이유
#    └ 댓글 0개 수집
#    → 누적 댓글 5385개
#
# ▶️ [429/500] 롯데카드, 피해액 전액 보상하겠다. #롯데카드 #신용카드 #해킹사고 #c
#    └ 댓글 0개 수집
#    → 누적 댓글 5385개
#
# ▶️ [430/500] [형지글로벌주가][주식] kt 롯데카드 해킹사태 보안주 엮인 사연. 신사
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 5385개
#
# ▶️ [431/500] 샌즈랩, 롯데카드 해킹 사고 여파에 급등 | Market Now 2 (2
#    └ 댓글 0개 수집
#    → 누적 댓글 5385개
#
# ▶️ [432/500] 금감원, &#39;해킹 사고&#39; 발생 롯데카드 현장 검사 착수 /
#    └ 댓글 0개 수집
#    → 누적 댓글 5385개
#
# ▶️ [433/500] [한국정보인증주가][주식] kt 롯데카드 해킹 사타 일파만파! 보안주 저
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 5385개
#
# ▶️ [434/500] 2025 국정감사 국회 정무위원회(롯데카드 해킹, 홈플러스 사태)
#    └ 댓글 0개 수집
#    → 누적 댓글 5385개
#
# ▶️ [435/500] [빠른뉴스 쨉] 롯데카드 297만 명 개인 정보 털렸다... 보상으로 &
#    └ 댓글 3개 수집
#    → 누적 댓글 5388개
#
# ▶️ [436/500] 롯데카드, 해킹 17일간 몰랐다... &quot;967만명 개인정보 유출
#    └ 댓글 2개 수집
#    → 누적 댓글 5390개
#
# ▶️ [437/500] 💳롯데카드 개인정보 유출, 손해배상 소송으로 얼마 받을까 ㅣ손해배상변호사
#    └ 댓글 0개 수집
#    → 누적 댓글 5390개
#
# ▶️ [438/500] 2025 3분기 금융 IT 이슈 총정리💸ㅣ롯데카드 해킹, 스테이블코인,
#    └ 댓글 0개 수집
#    → 누적 댓글 5390개
#
# ▶️ [439/500] 롯데카드 해킹 충격 폭로!”“SKT 이어 롯데카드까지? 대한민국 보안 붕
#    └ 댓글 0개 수집
#    → 누적 댓글 5390개
#
# ▶️ [440/500] 롯데카드 297만 명 정보 유출…  대표 이름걸고 약속한 보상은? / K
#    └ 댓글 0개 수집
#    → 누적 댓글 5390개
#
# ▶️ [441/500] 김 총리 &quot;해킹과 전쟁 각오…KT·롯데카드 사고 의혹도 조사&q
#    └ 댓글 2개 수집
#    → 누적 댓글 5392개
#
# ▶️ [442/500] 롯데카드 해킹 17일간 몰랐다...금감원 &quot;피해 시 전액 보상&
#    └ 댓글 0개 수집
#    → 누적 댓글 5392개
#
# ▶️ [443/500] ‘해킹사고’ 롯데카드, ‘롯데’와 무관한 회사…‘홈플러스’와 관련있다고?
#    └ 댓글 0개 수집
#    → 누적 댓글 5392개
#
# ▶️ [444/500] [잇클릭] &#39;롯데카드 해킹 사태&#39;…보안주 줄강세! / 김현
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 5392개
#
# ▶️ [445/500] 롯데카드 CVC까지 유출…대표이사 내일 사과”“Lotte Card Dat
#    └ 댓글 0개 수집
#    → 누적 댓글 5392개
#
# ▶️ [446/500] &#39;대규모 해킹 사태&#39; 롯데카드, 대국민 사과 [세상만사]
#    └ 댓글 0개 수집
#    → 누적 댓글 5392개
#
# ▶️ [447/500] &quot;내 정보 어디까지 털렸나&quot;…&#39;970만 고객&#
#    └ 댓글 1개 수집
#    → 누적 댓글 5393개
#
# ▶️ [448/500] 국가수사본부, &#39;롯데카드 해킹·정보유출&#39; 수사 착수 / 연
#    └ 댓글 0개 수집
#    → 누적 댓글 5393개
#
# ▶️ [449/500] (오후속개) 국회 과방위 KT, 롯데카드 해킹 청문회 #국회 #과방위 #
#    └ 댓글 1개 수집
#    → 누적 댓글 5394개
#
# ▶️ [450/500] 롯데카드 쓰는 기자도 털렸다 국민의힘 신성범 &quot;재발급 못받았다는
#    └ 댓글 0개 수집
#    → 누적 댓글 5394개
#
# ▶️ [451/500] 롯데카드 해킹 정황 | 개인정보 유출 확인법부터 내 돈과 정보를 지키는
#    └ 댓글 0개 수집
#    → 누적 댓글 5394개
#
# ▶️ [452/500] 봉추선생 금요일 방송 2025.09.19 - #소프트캠프 #보안주 #해킹
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 5394개
#
# ▶️ [453/500] 롯데카드도 해킹 피해? 고객 정보 유출 가능성 조사 중!
#    └ 댓글 0개 수집
#    → 누적 댓글 5394개
#
# ▶️ [454/500] [오늘의 이슈] 롯데카드 개인정보 유출, 한국의 개인정보보호 이래도 되나
#    └ 댓글 0개 수집
#    → 누적 댓글 5394개
#
# ▶️ [455/500] 김 총리, 내일 &#39;롯데카드·KT 해킹&#39; 긴급 현안점검&#3
#    └ 댓글 0개 수집
#    → 누적 댓글 5394개
#
# ▶️ [456/500] 롯데카드 해킹, 피해자 100만 명 넘어설 듯…금융당국 긴급 조사
#    └ 댓글 0개 수집
#    → 누적 댓글 5394개
#
# ▶️ [457/500] 롯데카드ㆍKT 소액결제 해킹ㆍSKT 해킹블록체인 기술 디지탈 화폐로 몰아
#    └ 댓글 1개 수집
#    → 누적 댓글 5395개
#
# ▶️ [458/500] 롯데카드사, 정보 유출 17일지나 알아! 금융위 후보자는 금융 해킹사고
#    └ 댓글 0개 수집
#    → 누적 댓글 5395개
#
# ▶️ [459/500] 대한민국을 덮친 해킹 공포
#    └ 댓글 0개 수집
#    → 누적 댓글 5395개
#
# ▶️ [460/500] CVC까지 털렸다? 롯데카드 정보유출 충격내용 정리# #이슈#정보유출 #
#    └ 댓글 1개 수집
#    → 누적 댓글 5396개
#
# ▶️ [461/500] 내 개인정보 이제는 보내줘야 하나 롯데카드 해킹 #shorts #핫이슈
#    └ 댓글 0개 수집
#    → 누적 댓글 5396개
#
# ▶️ [462/500] 롯데카드 해킹사고 한 달…8만명 카드 해지하고 탈회
#    └ 댓글 0개 수집
#    → 누적 댓글 5396개
#
# ▶️ [463/500] “960만 명 정보 털렸다” 롯데카드, 사과와 보상으로 막을 수 있을까?
#    └ 댓글 0개 수집
#    → 누적 댓글 5396개
#
# ▶️ [464/500] 롯데카드 해킹 피해, 1.7GB는 빙산의 일각
#    └ 댓글 0개 수집
#    → 누적 댓글 5396개
#
# ▶️ [465/500] “17일 동안 몰랐다” 롯데카드 해킹 충격
#    └ 댓글 0개 수집
#    → 누적 댓글 5396개
#
# ▶️ [466/500] 롯데카드 해킹 사태! 보안주 소프트캠프 상한가 관련주 지니어스 주가 분석
#    └ 댓글 1개 수집
#    → 누적 댓글 5397개
#
# ▶️ [467/500] 롯데카드 개인정보 유출, 보상금은 얼마 받을까? #손해배상청구 #손해배상
#    └ 댓글 0개 수집
#    → 누적 댓글 5397개
#
# ▶️ [468/500] 롯데카드 해킹사고... 297만명 정보유출 #롯데카드 #해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 5397개
#
# ▶️ [469/500] KT 소액결제 피해·롯데카드 해킹 297만명 개인정보 유출… 내 정보도
#    └ 댓글 0개 수집
#    → 누적 댓글 5397개
#
# ▶️ [470/500] 롯데카드 해킹 사고...&quot;고객 정보 유출 확인 중&quot; /
#    └ 댓글 0개 수집
#    → 누적 댓글 5397개
#
# ▶️ [471/500] 한싹, 롯데카드 297만명 정보유출 &quot;추가솔루션&quot;확대발
#    └ 댓글 0개 수집
#    → 누적 댓글 5397개
#
# ▶️ [472/500] &quot;롯데카드 해킹 297만 명 정보 유출! 연회비 면제? 실효성
#    └ 댓글 0개 수집
#    → 누적 댓글 5397개
#
# ▶️ [473/500] 롯데카드 960만 회원 해킹! 지금 당장 확인하세요 #롯데
#    └ 댓글 0개 수집
#    → 누적 댓글 5397개
#
# ▶️ [474/500] #롯데카드 #생활정보 #롯데카드해킹 #해킹범죄 #개인정보보호
#    └ 댓글 0개 수집
#    → 누적 댓글 5397개
#
# ▶️ [475/500] &quot;롯데카드 297만명 정보 유출 전말 | 카드 재발급·보상·해킹
#    └ 댓글 0개 수집
#    → 누적 댓글 5397개
#
# ▶️ [476/500] &quot;언발에 오줌이라도 누어라&quot;... 마지막까지 MBK에
#    └ 댓글 0개 수집
#    → 누적 댓글 5397개
#
# ▶️ [477/500] 롯데카드 개인정보 유출…알고 보니 롯데그룹 계열사 아냐
#    └ 댓글 1개 수집
#    → 누적 댓글 5398개
#
# ▶️ [478/500] KT·LGT·롯데카드까지··해킹사고 빈발하는 이유는?(250903주요경제
#    └ 댓글 0개 수집
#    → 누적 댓글 5398개
#
# ▶️ [479/500] [1분사설] 통신 이어 롯데카드까지 해킹사고, 보안투자 확 늘려야 #사설
#    └ 댓글 0개 수집
#    → 누적 댓글 5398개
#
# ▶️ [480/500] 롯데카드도 해킹…960만 고객 정보 유출│ABC 뉴스룸(25.09.17)
#    └ 댓글 1개 수집
#    → 누적 댓글 5399개
#
# ▶️ [481/500] 2025년 9월 18일 오늘의 기록... 롯데카드 297만명 해킹, 조좌
#    └ 댓글 0개 수집
#    → 누적 댓글 5399개
#
# ▶️ [482/500] [원영섭 변호사] 롯데카드 해킹피해 손배소 원고모집
#    └ 댓글 3개 수집
#    → 누적 댓글 5402개
#
# ▶️ [483/500] KT·롯데카드 SKT 해킹, 소액결제 먼저 막아야 하는 이유#KT해킹 #
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [484/500] 297만명 정보 유출? 롯데카드 해킹 사상 초유 사태! (그놈의돈)
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [485/500] 9월 18일 1편｜롯데카드 해킹·임신중절 살인·우상혁 은메달 외 10가지
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [486/500] 롯데카드 해킹 사건, 17일간 몰랐다? 고객 정보 1.7GB 유출 충격!
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [487/500] &quot;롯데카드 정보유출 고객에게 안내 메시지 발송&quot; #오늘
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [488/500] 롯데카드, 297만명 회원정보 대방출 이벤트?! #롯데카드 #정보유출 #
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [489/500] 롯데카드 해킹사건 요약
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [490/500] 롯데카드 해킹 사고 발생
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [491/500] 롯데카드 297만명 정보 유출…비밀번호·CVC까지 털렸다!
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [492/500] KT법인검거 롯데카드 해킹피해
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [493/500] 💳 297만명 정보 유출…롯데카드 사상 초유 사태🚨
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [494/500] 해킹사고로 겹악재를 맞은 롯데카드! 조좌진 대표의 기업가치 제고 전략은?
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [495/500] [한싹] 롯데, KT 해킹사태에 대한 일시적 관심인가!? 더 큰 시세를
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 5402개
#
# ▶️ [496/500] 🚨롯데카드 해킹… 내 정보 털렸을까? 지금 확인하세요!🚨
#    └ 댓글 1개 수집
#    → 누적 댓글 5403개
#
# ▶️ [497/500] 롯데카드 해킹 피해, 최대 수백만 명 가능성… 이번 주 대표 사과 예정
#    └ 댓글 0개 수집
#    → 누적 댓글 5403개
#
# ▶️ [498/500] 롯데카드 해킹 피해 297만명…5700명 집단소송 나선다
#    └ 댓글 0개 수집
#    → 누적 댓글 5403개
#
# ▶️ [499/500] 2025년 9월 19일 한겨레 헤드라인 뉴스 요약 ( #롯데카드 #개인정
#    └ 댓글 0개 수집
#    → 누적 댓글 5403개
#
# ▶️ [500/500] 297만 명 개인정보 유출...롯데카드 사태, 금융당국 칼 빼 들었다
#    └ 댓글 0개 수집
#    → 누적 댓글 5403개
#
# 🎯 완료 — 영상 500건, 댓글 5403건 저장됨.

# %%
from googleapiclient.discovery import build
import pandas as pd
from datetime import datetime
import os
from time import sleep

# ---------------------------------------
# 1️⃣ 환경설정 및 API 초기화
# ---------------------------------------
API_KEY = ""

def get_youtube():
    return build("youtube", "v3", developerKey=API_KEY)

youtube = get_youtube()

def safe_execute(request, retry=3):
    """API 요청 실행 (에러 발생 시 재시도 및 스킵)"""
    for attempt in range(retry):
        try:
            return request.execute()
        except Exception as e:
            msg = str(e)
            if "commentsDisabled" in msg:
                print("🚫 댓글 비활성화 영상 건너뜀")
                return {"items": []}
            elif "notFound" in msg:
                print("⚠️ 삭제/비공개 영상 건너뜀")
                return {"items": []}
            elif "quotaExceeded" in msg:
                print("❌ API 쿼터 초과 — 키 교체 필요")
                raise e
            else:
                print(f"❌ 오류 ({attempt+1}/{retry})회차 재시도 중: {e}")
                sleep(1)
    return {"items": []}


# ---------------------------------------
# 2️⃣ 영상 수집 함수 (최대 500건)
# ---------------------------------------
def collect_youtube_videos(query, start_date, end_date, max_total=500):
    all_videos = []
    next_page_token = None
    fetched = 0

    print(f"\n🚀 [{query}] 영상 수집 시작 ({start_date} ~ {end_date})")

    while fetched < max_total:
        req = youtube.search().list(
            part="snippet",
            q=query,
            type="video",
            order="viewCount",
            maxResults=50,
            publishedAfter=f"{start_date}T00:00:00Z",
            publishedBefore=f"{end_date}T23:59:59Z",
            pageToken=next_page_token
        )
        res = safe_execute(req)
        items = res.get("items", [])
        if not items:
            print("⚠️ 더 이상 영상 없음.")
            break

        for item in items:
            vid = item["id"]["videoId"]
            snippet = item["snippet"]
            all_videos.append({
                "videoId": vid,
                "title": snippet["title"],
                "description": snippet.get("description", ""),
                "channelTitle": snippet["channelTitle"],
                "channelId": snippet["channelId"],
                "publishedAt": snippet["publishedAt"],
                "url": f"https://www.youtube.com/watch?v={vid}"
            })

        fetched += len(items)
        print(f"✅ 누적 {fetched}건 수집 완료")

        next_page_token = res.get("nextPageToken")
        if not next_page_token:
            break

        sleep(0.3)  # API 요청 간 간격

    print(f"🎯 총 {len(all_videos)}건 영상 수집 완료\n")

    # ▶️ 영상 통계 및 채널 구독자 수 추가
    all_videos = enrich_video_stats(all_videos)
    return pd.DataFrame(all_videos)


# ---------------------------------------
# 3️⃣ 영상 통계 + 구독자 수
# ---------------------------------------
def enrich_video_stats(all_videos):
    for i in range(0, len(all_videos), 50):
        ids = [v["videoId"] for v in all_videos[i:i+50]]
        stats_req = youtube.videos().list(part="statistics,snippet", id=",".join(ids))
        stats_res = safe_execute(stats_req)
        stats_dict = {item["id"]: item for item in stats_res.get("items", [])}

        # 채널 ID 모으기
        channel_ids = []
        video_to_channel = {}
        for v in all_videos[i:i+50]:
            vid_stat = stats_dict.get(v["videoId"], {})
            cid = vid_stat.get("snippet", {}).get("channelId", "")
            video_to_channel[v["videoId"]] = cid
            if cid and cid not in channel_ids:
                channel_ids.append(cid)

        # 채널 구독자 수 조회
        channel_subs_dict = {}
        for j in range(0, len(channel_ids), 50):
            c_batch = channel_ids[j:j+50]
            channel_req = youtube.channels().list(part="statistics", id=",".join(c_batch))
            channel_res = safe_execute(channel_req)
            for item in channel_res.get("items", []):
                channel_subs_dict[item["id"]] = int(item["statistics"].get("subscriberCount", 0))

        # 통계 값 추가
        for v in all_videos[i:i+50]:
            stat = stats_dict.get(v["videoId"], {}).get("statistics", {})
            v["viewCount"] = int(stat.get("viewCount", 0))
            v["likeCount"] = int(stat.get("likeCount", 0))
            v["commentCount"] = int(stat.get("commentCount", 0))
            cid = video_to_channel.get(v["videoId"], "")
            v["subscriberCount"] = channel_subs_dict.get(cid, 0)

        sleep(0.3)
    return all_videos


# ---------------------------------------
# 4️⃣ 댓글 수집 (영상당 최대 100개)
# ---------------------------------------
def collect_comments(video_id, max_comments=100):
    comments = []
    next_page_token = None
    total = 0

    while True:
        req = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            pageToken=next_page_token,
            textFormat="plainText"
        )
        res = safe_execute(req)
        if not res.get("items"):
            break

        for item in res["items"]:
            snippet = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "videoId": video_id,
                "author": snippet.get("authorDisplayName", ""),
                "text": snippet.get("textDisplay", ""),
                "publishedAt": snippet.get("publishedAt", "")
            })
            total += 1
            if total >= max_comments:
                return comments

        next_page_token = res.get("nextPageToken")
        if not next_page_token:
            break
        sleep(0.3)

    return comments


# ---------------------------------------
# 5️⃣ 실행부
# ---------------------------------------
topic = {
    "name": "GS리테일_정보유출",
    "query": "(GS OR GS리테일) AND (정보 OR 개인정보 ) AND (유출) ",
    "start": "2024-12-23",
    "end": "2025-04-06"
}

os.makedirs("YouTube_결과", exist_ok=True)

df_videos = collect_youtube_videos(topic["query"], topic["start"], topic["end"], max_total=500)
print(f"✅ 영상 {len(df_videos)}건 수집 완료")

# 💬 댓글 수집
all_comments = []
print(f"\n💬 총 {len(df_videos)}개 영상 댓글 수집 시작 (영상당 최대 100개)")

for idx, row in df_videos.iterrows():
    vid = row["videoId"]
    title = row["title"][:40]
    print(f"\n▶️ [{idx+1}/{len(df_videos)}] {title}")
    comments = collect_comments(vid, max_comments=100)
    print(f"   └ 댓글 {len(comments)}개 수집")
    all_comments.extend(comments)
    print(f"   → 누적 댓글 {len(all_comments)}개")

# 저장
ts = datetime.now().strftime("%Y%m%d_%H%M%S")
df_videos.to_excel(f"YouTube_결과/{topic['name']}_videos_{ts}.xlsx", index=False)
pd.DataFrame(all_comments).to_excel(f"YouTube_결과/{topic['name']}_comments_{ts}.xlsx", index=False)

print(f"\n🎯 완료 — 영상 {len(df_videos)}건, 댓글 {len(all_comments)}건 저장됨.")
# Out:
# 🚀 [(GS OR GS리테일) AND (정보 OR 개인정보 ) AND (유출) ] 영상 수집 시작 (2024-12-23 ~ 2025-04-06)
# ✅ 누적 22건 수집 완료
# 🎯 총 22건 영상 수집 완료
#
# ✅ 영상 22건 수집 완료
#
# 💬 총 22개 영상 댓글 수집 시작 (영상당 최대 100개)
#
# ▶️ [1/22] 주소에 통관번호까지…GS리테일, 158만명 정보 유출 확인 / JTBC
#    └ 댓글 100개 수집
#    → 누적 댓글 100개
#
# ▶️ [2/22] GS리테일 고객 정보 9만여 건 해킹 피해…3일 만에 알렸다 / SBS
#    └ 댓글 37개 수집
#    → 누적 댓글 137개
#
# ▶️ [3/22] GS리테일 고객 9만 명 개인정보 유출…해킹 공격 / SBS 8뉴스
#    └ 댓글 9개 수집
#    → 누적 댓글 146개
#
# ▶️ [4/22] GS리테일, 편의점에 홈쇼핑도 해킹‥158만 건 추가 유출 (2025.0
#    └ 댓글 15개 수집
#    → 누적 댓글 161개
#
# ▶️ [5/22] GS리테일 고객 9만명 해킹..&#39;겨울별미&#39; 대구 씨 말랐다
#    └ 댓글 0개 수집
#    → 누적 댓글 161개
#
# ▶️ [6/22] 편의점 이어 홈쇼핑도 털렸다…GS샵, 고객 개인정보 158만건 유출 [뉴
#    └ 댓글 18개 수집
#    → 누적 댓글 179개
#
# ▶️ [7/22] GS25·GS홈쇼핑 사용하면 위험한 이유...&quot;또 개인정보 제대
#    └ 댓글 5개 수집
#    → 누적 댓글 184개
#
# ▶️ [8/22] GS리테일, 해킹 공격에 9만 명 고객 개인정보 유출 / YTN
#    └ 댓글 0개 수집
#    → 누적 댓글 184개
#
# ▶️ [9/22] GS리테일, 편의점 이어 홈쇼핑도 해킹...개인정보 158만 건 유출 /
#    └ 댓글 1개 수집
#    → 누적 댓글 185개
#
# ▶️ [10/22] GS리테일, 총수일가 경영 논란 주가 60% 급락
#    └ 댓글 1개 수집
#    → 누적 댓글 186개
#
# ▶️ [11/22] GS 홈쇼핑 개인정보 158만건 유출 #shorts
#    └ 댓글 0개 수집
#    → 누적 댓글 186개
#
# ▶️ [12/22] GS샵, 고객 158만명 개인정보 유출... 내 정보도 털렸나?
#    └ 댓글 0개 수집
#    → 누적 댓글 186개
#
# ▶️ [13/22] GS리테일, IT 시스템 &#39;연이은 구멍&#39;…허서홍 대표 위기
#    └ 댓글 0개 수집
#    → 누적 댓글 186개
#
# ▶️ [14/22] GS리테일, 편의점 이어 홈쇼핑도 해킹...개인정보 158만 건 유출 /
#    └ 댓글 1개 수집
#    → 누적 댓글 187개
#
# ▶️ [15/22] [세이프타임즈TV] &#39;개인정보 유출&#39; GS리테일, 고객 보
#    └ 댓글 0개 수집
#    → 누적 댓글 187개
#
# ▶️ [16/22] &quot;GS샵, 158만 명 개인정보 유출! 과연 누가 공격했나?&q
#    └ 댓글 0개 수집
#    → 누적 댓글 187개
#
# ▶️ [17/22] [메디컬투데이TV] GS리테일, GS25에 이어 GS샵까지…고객정보 15
#    └ 댓글 0개 수집
#    → 누적 댓글 187개
#
# ▶️ [18/22] GS리테일 개인정보 유출! 158만 건 피해, 당신의 정보도 안전할까?
#    └ 댓글 0개 수집
#    → 누적 댓글 187개
#
# ▶️ [19/22] 9만명 개인정보 유출! GS리테일 해킹 사건의 전말은?
#    └ 댓글 1개 수집
#    → 누적 댓글 188개
#
# ▶️ [20/22] 해킹 당한 GS리테일…9만명 개인정보 유출
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 188개
#
# ▶️ [21/22] GS리테일, 홈쇼핑 고객정보 158만건 유출 정황 추가 확인하다  #GS
#    └ 댓글 0개 수집
#    → 누적 댓글 188개
#
# ▶️ [22/22] GS리테일 개인정보 158만 건 유출?! 보안 조치 강화!
#    └ 댓글 0개 수집
#    → 누적 댓글 188개
#
# 🎯 완료 — 영상 22건, 댓글 188건 저장됨.

# %%
from googleapiclient.discovery import build
import pandas as pd
from datetime import datetime
import os
from time import sleep

# ---------------------------------------
# 1️⃣ 환경설정 및 API 초기화
# ---------------------------------------
API_KEY = ""

def get_youtube():
    return build("youtube", "v3", developerKey=API_KEY)

youtube = get_youtube()

def safe_execute(request, retry=3):
    """API 요청 실행 (에러 발생 시 재시도 및 스킵)"""
    for attempt in range(retry):
        try:
            return request.execute()
        except Exception as e:
            msg = str(e)
            if "commentsDisabled" in msg:
                print("🚫 댓글 비활성화 영상 건너뜀")
                return {"items": []}
            elif "notFound" in msg:
                print("⚠️ 삭제/비공개 영상 건너뜀")
                return {"items": []}
            elif "quotaExceeded" in msg:
                print("❌ API 쿼터 초과 — 키 교체 필요")
                raise e
            else:
                print(f"❌ 오류 ({attempt+1}/{retry})회차 재시도 중: {e}")
                sleep(1)
    return {"items": []}


# ---------------------------------------
# 2️⃣ 영상 수집 함수 (최대 500건)
# ---------------------------------------
def collect_youtube_videos(query, start_date, end_date, max_total=500):
    all_videos = []
    next_page_token = None
    fetched = 0

    print(f"\n🚀 [{query}] 영상 수집 시작 ({start_date} ~ {end_date})")

    while fetched < max_total:
        req = youtube.search().list(
            part="snippet",
            q=query,
            type="video",
            order="viewCount",
            maxResults=50,
            publishedAfter=f"{start_date}T00:00:00Z",
            publishedBefore=f"{end_date}T23:59:59Z",
            pageToken=next_page_token
        )
        res = safe_execute(req)
        items = res.get("items", [])
        if not items:
            print("⚠️ 더 이상 영상 없음.")
            break

        for item in items:
            vid = item["id"]["videoId"]
            snippet = item["snippet"]
            all_videos.append({
                "videoId": vid,
                "title": snippet["title"],
                "description": snippet.get("description", ""),
                "channelTitle": snippet["channelTitle"],
                "channelId": snippet["channelId"],
                "publishedAt": snippet["publishedAt"],
                "url": f"https://www.youtube.com/watch?v={vid}"
            })

        fetched += len(items)
        print(f"✅ 누적 {fetched}건 수집 완료")

        next_page_token = res.get("nextPageToken")
        if not next_page_token:
            break

        sleep(0.3)  # API 요청 간 간격

    print(f"🎯 총 {len(all_videos)}건 영상 수집 완료\n")

    # ▶️ 영상 통계 및 채널 구독자 수 추가
    all_videos = enrich_video_stats(all_videos)
    return pd.DataFrame(all_videos)


# ---------------------------------------
# 3️⃣ 영상 통계 + 구독자 수
# ---------------------------------------
def enrich_video_stats(all_videos):
    for i in range(0, len(all_videos), 50):
        ids = [v["videoId"] for v in all_videos[i:i+50]]
        stats_req = youtube.videos().list(part="statistics,snippet", id=",".join(ids))
        stats_res = safe_execute(stats_req)
        stats_dict = {item["id"]: item for item in stats_res.get("items", [])}

        # 채널 ID 모으기
        channel_ids = []
        video_to_channel = {}
        for v in all_videos[i:i+50]:
            vid_stat = stats_dict.get(v["videoId"], {})
            cid = vid_stat.get("snippet", {}).get("channelId", "")
            video_to_channel[v["videoId"]] = cid
            if cid and cid not in channel_ids:
                channel_ids.append(cid)

        # 채널 구독자 수 조회
        channel_subs_dict = {}
        for j in range(0, len(channel_ids), 50):
            c_batch = channel_ids[j:j+50]
            channel_req = youtube.channels().list(part="statistics", id=",".join(c_batch))
            channel_res = safe_execute(channel_req)
            for item in channel_res.get("items", []):
                channel_subs_dict[item["id"]] = int(item["statistics"].get("subscriberCount", 0))

        # 통계 값 추가
        for v in all_videos[i:i+50]:
            stat = stats_dict.get(v["videoId"], {}).get("statistics", {})
            v["viewCount"] = int(stat.get("viewCount", 0))
            v["likeCount"] = int(stat.get("likeCount", 0))
            v["commentCount"] = int(stat.get("commentCount", 0))
            cid = video_to_channel.get(v["videoId"], "")
            v["subscriberCount"] = channel_subs_dict.get(cid, 0)

        sleep(0.3)
    return all_videos


# ---------------------------------------
# 4️⃣ 댓글 수집 (영상당 최대 100개)
# ---------------------------------------
def collect_comments(video_id, max_comments=100):
    comments = []
    next_page_token = None
    total = 0

    while True:
        req = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            pageToken=next_page_token,
            textFormat="plainText"
        )
        res = safe_execute(req)
        if not res.get("items"):
            break

        for item in res["items"]:
            snippet = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "videoId": video_id,
                "author": snippet.get("authorDisplayName", ""),
                "text": snippet.get("textDisplay", ""),
                "publishedAt": snippet.get("publishedAt", "")
            })
            total += 1
            if total >= max_comments:
                return comments

        next_page_token = res.get("nextPageToken")
        if not next_page_token:
            break
        sleep(0.3)

    return comments


# ---------------------------------------
# 5️⃣ 실행부
# ---------------------------------------
topic = {
    "name": "카카오_개인정보_유출출",
    "query": "(카카오 OR Kakao) AND (오픈채팅 OR 오픈 채팅 OR 오픈챗) AND (유출 OR 정보유출 OR 해킹 OR 보안사고) ",
    "start": "2024-05-09",
    "end": "2024-07-23"
}

os.makedirs("YouTube_결과", exist_ok=True)

df_videos = collect_youtube_videos(topic["query"], topic["start"], topic["end"], max_total=500)
print(f"✅ 영상 {len(df_videos)}건 수집 완료")

# 💬 댓글 수집
all_comments = []
print(f"\n💬 총 {len(df_videos)}개 영상 댓글 수집 시작 (영상당 최대 100개)")

for idx, row in df_videos.iterrows():
    vid = row["videoId"]
    title = row["title"][:40]
    print(f"\n▶️ [{idx+1}/{len(df_videos)}] {title}")
    comments = collect_comments(vid, max_comments=100)
    print(f"   └ 댓글 {len(comments)}개 수집")
    all_comments.extend(comments)
    print(f"   → 누적 댓글 {len(all_comments)}개")

# 저장
ts = datetime.now().strftime("%Y%m%d_%H%M%S")
df_videos.to_excel(f"YouTube_결과/{topic['name']}_videos_{ts}.xlsx", index=False)
pd.DataFrame(all_comments).to_excel(f"YouTube_결과/{topic['name']}_comments_{ts}.xlsx", index=False)

print(f"\n🎯 완료 — 영상 {len(df_videos)}건, 댓글 {len(all_comments)}건 저장됨.")
# Out:
# 🚀 [(카카오 OR Kakao) AND (오픈채팅 OR 오픈 채팅 OR 오픈챗) AND (유출 OR 정보유출 OR 해킹 OR 보안사고) ] 영상 수집 시작 (2024-05-09 ~ 2024-07-23)
# ✅ 누적 27건 수집 완료
# 🎯 총 27건 영상 수집 완료
#
# ✅ 영상 27건 수집 완료
#
# 💬 총 27개 영상 댓글 수집 시작 (영상당 최대 100개)
#
# ▶️ [1/27] 친구 구하는 카톡 오픈채팅방 특징
#    └ 댓글 8개 수집
#    → 누적 댓글 8개
#
# ▶️ [2/27] [속보] &#39;오픈채팅방 개인정보 유출&#39; 카카오에 &#39;과
#    └ 댓글 5개 수집
#    → 누적 댓글 13개
#
# ▶️ [3/27] &#39;개인정보 유출&#39; 과징금 151억 원 철퇴‥카카오는 불복
#    └ 댓글 36개 수집
#    → 누적 댓글 49개
#
# ▶️ [4/27] &quot;최소 6만 5천 명 개인정보 유출&quot;…카카오에 151억
#    └ 댓글 21개 수집
#    → 누적 댓글 70개
#
# ▶️ [5/27] 카카오, 개인정보 유출로 과징금 151억 (2024.05.23/뉴스외전/
#    └ 댓글 35개 수집
#    → 누적 댓글 105개
#
# ▶️ [6/27] 카카오 151억 &#39;역대 최대&#39; 과징금…강력 반발 / SBS
#    └ 댓글 16개 수집
#    → 누적 댓글 121개
#
# ▶️ [7/27] &#39;오픈채팅방&#39; 뚫린 카카오…&quot;151억 내라고?&q
#    └ 댓글 6개 수집
#    → 누적 댓글 127개
#
# ▶️ [8/27] &quot;6만5천 명 정보 유출&quot;...카카오에 151억 원 과
#    └ 댓글 22개 수집
#    → 누적 댓글 149개
#
# ▶️ [9/27] 6만 5천 건↑ 개인정보 유출…카카오에 &#39;역대 최대&#39; 과징
#    └ 댓글 14개 수집
#    → 누적 댓글 163개
#
# ▶️ [10/27] &quot;6만5천 명 정보 유출&quot;...카카오에 151억 원 과
#    └ 댓글 13개 수집
#    → 누적 댓글 176개
#
# ▶️ [11/27] [한눈에 이슈] 살인·사기·성범죄 등에 악용되는 &#39;오픈채팅방&#3
#    └ 댓글 1개 수집
#    → 누적 댓글 177개
#
# ▶️ [12/27] &#39;오픈 채팅방 개인정보 유출&#39; 카카오 과징금 151억 원
#    └ 댓글 5개 수집
#    → 누적 댓글 182개
#
# ▶️ [13/27] &quot;6만5천 명 정보 유출&quot;...카카오에 151억 원 과
#    └ 댓글 2개 수집
#    → 누적 댓글 184개
#
# ▶️ [14/27] 카카오, 해외 진출로 반전 도모 [말하는 기자들_테크지식산업_0611]
#    └ 댓글 2개 수집
#    → 누적 댓글 186개
#
# ▶️ [15/27] [이슈5] 오픈채팅 개인정보 유출…카카오 151억 최고 과징금 外 / 연
#    └ 댓글 0개 수집
#    → 누적 댓글 186개
#
# ▶️ [16/27] 오픈채팅 개인정보 유출…카카오 151억 최고 과징금 / 연합뉴스TV (Y
#    └ 댓글 1개 수집
#    → 누적 댓글 187개
#
# ▶️ [17/27] 개인정보위 &quot;카카오의 개인정보 유출 부인 주장 수긍 어려워&qu
#    └ 댓글 0개 수집
#    → 누적 댓글 187개
#
# ▶️ [18/27] ‘오픈채팅방 개인정보 유출’ 카카오, 과징금 151억…카카오 “소송 검토
#    └ 댓글 1개 수집
#    → 누적 댓글 188개
#
# ▶️ [19/27] &#39;오픈채팅방 개인정보 유출&#39; … 151억 과징금 맞은 카카
#    └ 댓글 1개 수집
#    → 누적 댓글 189개
#
# ▶️ [20/27] 오픈채팅방 이용 개인정보 유출…카카오 151억 과징금 / 연합뉴스TV (
#    └ 댓글 2개 수집
#    → 누적 댓글 191개
#
# ▶️ [21/27] &#39;개인정보 유출&#39; 카카오 과징금 151억…&quot;행정
#    └ 댓글 1개 수집
#    → 누적 댓글 192개
#
# ▶️ [22/27] “익명 채팅인데 내 이름이?”…카카오에 과징금 151억 / KBS  20
#    └ 댓글 1개 수집
#    → 누적 댓글 193개
#
# ▶️ [23/27] &#39;오픈 채팅방 개인정보 유출&#39; 카카오 과징금 151억 원
#    └ 댓글 0개 수집
#    → 누적 댓글 193개
#
# ▶️ [24/27] “최소 6만5000명 정보 유출” 카카오에 151억원 과징금 [말하는 기
#    └ 댓글 0개 수집
#    → 누적 댓글 193개
#
# ▶️ [25/27] &quot;6만5천 명 정보 유출&quot;...카카오에 151억 원 과
#    └ 댓글 0개 수집
#    → 누적 댓글 193개
#
# ▶️ [26/27] &#39;오픈채팅방 개인정보 유출&#39; 카카오, 제재 수위는?
#    └ 댓글 0개 수집
#    → 누적 댓글 193개
#
# ▶️ [27/27] 010인증 털래@NEXONid 네이버해킹아이디판매 카카오톡오픈채팅하트찜매
# 🚫 댓글 비활성화 영상 건너뜀
#    └ 댓글 0개 수집
#    → 누적 댓글 193개
#
# 🎯 완료 — 영상 27건, 댓글 193건 저장됨.

# %%
import os
import pandas as pd

# 데이터 폴더 내 각 이슈별 병합 엑셀 파일에서 데이터 개수를 카운트하는 요약 테이블 출력
# YouTube_결과 폴더 내에 저장된 영상 및 댓글 엑셀 파일 리스트업 및 요약

data_folder = "YouTube_결과"
excel_files = [f for f in os.listdir(data_folder) if f.endswith('.xlsx')]

video_files = [f for f in excel_files if 'videos' in f]
comment_files = [f for f in excel_files if 'comments' in f]

print(f"▶️ YouTube_결과 폴더 내 영상 엑셀 파일: {video_files}")
print(f"💬 YouTube_결과 폴더 내 댓글 엑셀 파일: {comment_files}")

summary = []

for file in excel_files:
    file_path = os.path.join(data_folder, file)
    issue_name = file.replace("merged_output_", "").replace(".xlsx", "")
    if os.path.exists(file_path):
        df = pd.read_excel(file_path)
        count = len(df)
    else:
        count = 0
    summary.append({"이슈": issue_name, "데이터수": count})

summary_df = pd.DataFrame(summary)
print("이슈별 데이터 개수 요약:")
print(summary_df)
# Out:
# ▶️ YouTube_결과 폴더 내 영상 엑셀 파일: ['GS리테일_정보유출_videos_20251103_154830.xlsx', 'KT_펨토셀_해킹_videos_20251103_152106.xlsx', 'SKT_유심칩_유출_videos_20251103_165204.xlsx', '롯데카드_정보유출_videos_20251103_165555.xlsx', '카카오_개인정보_유출_videos_20251103_160134.xlsx']
# 💬 YouTube_결과 폴더 내 댓글 엑셀 파일: ['GS리테일_정보유출_comments_20251103_154830.xlsx', 'KT_펨토셀_해킹_comments_20251103_152106.xlsx', 'SKT_유심칩_유출_comments_20251103_165204.xlsx', '롯데카드_정보유출_comments_20251103_165555.xlsx', '카카오_개인정보_유출_comments_20251103_160134.xlsx']
# 이슈별 데이터 개수 요약:
#                                      이슈  데이터수
# 0   GS리테일_정보유출_comments_20251103_154830   188
# 1     GS리테일_정보유출_videos_20251103_154830    22
# 2    KT_펨토셀_해킹_comments_20251103_152106  6527
# 3      KT_펨토셀_해킹_videos_20251103_152106   349
# 4   SKT_유심칩_유출_comments_20251103_165204  7279
# 5     SKT_유심칩_유출_videos_20251103_165204   500
# 6    롯데카드_정보유출_comments_20251103_165555  5403
# 7      롯데카드_정보유출_videos_20251103_165555   500
# 8  카카오_개인정보_유출_comments_20251103_160134   193
# 9    카카오_개인정보_유출_videos_20251103_160134    27
